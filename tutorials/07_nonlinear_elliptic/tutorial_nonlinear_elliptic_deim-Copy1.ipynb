# %% [markdown]
# ## Tutorial 07 - Non linear Elliptic problem
# **_Keywords: DEIM, POD-Galerkin_**
#
# ### 1. Introduction
#
# In this tutorial, we consider a non linear elliptic problem in a two-dimensional spatial domain $\Omega=(0,1)^2$. We impose a homogeneous Dirichlet condition on the boundary $\partial\Omega$. The source term is characterized by the following expression
# $$
# g(\boldsymbol{x}; \boldsymbol{\mu}) = 100\sin(2\pi x_0)cos(2\pi x_1) \quad \forall \boldsymbol{x} = (x_0, x_1) \in \Omega.
# $$
#
# This problem is characterized by two parameters. The first parameter $\mu_0$ controls the strength of the sink term and the second parameter $\mu_1$ the strength of the nonlinearity. The range of the two parameters is the following:
# $$
# \mu_0,\mu_1\in[0.01,10.0]
# $$
# The parameter vector $\boldsymbol{\mu}$ is thus given by
# $$
# \boldsymbol{\mu} = (\mu_0,\mu_1)
# $$
# on the parameter domain
# $$
# \mathbb{P}=[0.01,10]^2.
# $$
#
#
# In order to obtain a faster approximation of the problem, we pursue a model reduction by means of a POD-Galerkin reduced order method. In order to preserve the affinity assumption the discrete empirical interpolation method will be used on the forcing term $g(\boldsymbol{x}; \boldsymbol{\mu})$.

# %% [markdown]
# ### 2. Parametrized formulation
#
# Let $u(\boldsymbol{\mu})$ be the solution in the domain $\Omega$.
#
# The strong formulation of the parametrized problem is given by: for a given parameter $\boldsymbol{\mu}\in\mathbb{P}$, find $u(\boldsymbol{\mu})$ such that
#
# $$ -\nabla^2u(\boldsymbol{\mu})+\frac{\mu_0}{\mu_1}(\exp\{\mu_1u(\boldsymbol{\mu})\}-1)=g(\boldsymbol{x}; \boldsymbol{\mu})$$
# <br>
#
# The corresponding weak formulation reads: for a given parameter $\boldsymbol{\mu}\in\mathbb{P}$, find $u(\boldsymbol{\mu})\in\mathbb{V}$ such that
#
# $$a\left(u(\boldsymbol{\mu}),v;\boldsymbol{\mu}\right)+c\left(u(\boldsymbol{\mu}),v;\boldsymbol{\mu}\right)=f(v;\boldsymbol{\mu})\quad \forall v\in\mathbb{V}$$
#
# where
#
# * the function space $\mathbb{V}$ is defined as
# $$
# \mathbb{V} = \{v\in H_1(\Omega) : v|_{\partial\Omega}=0\}
# $$
# * the parametrized bilinear form $a(\cdot, \cdot; \boldsymbol{\mu}): \mathbb{V} \times \mathbb{V} \to \mathbb{R}$ is defined by
# $$a(u, v;\boldsymbol{\mu})=\int_{\Omega} \nabla u\cdot \nabla v \ d\boldsymbol{x},$$
# * the parametrized bilinear form $c(\cdot, \cdot; \boldsymbol{\mu}): \mathbb{V} \times \mathbb{V} \to \mathbb{R}$ is defined by
# $$c(u, v;\boldsymbol{\mu})=\mu_0\int_{\Omega} \frac{1}{\mu_1}\big(\exp\{\mu_1u\} - 1\big)v \ d\boldsymbol{x},$$
# * the parametrized linear form $f(\cdot; \boldsymbol{\mu}): \mathbb{V} \to \mathbb{R}$ is defined by
# $$f(v; \boldsymbol{\mu})= \int_{\Omega}g(\boldsymbol{x}; \boldsymbol{\mu})v \ d\boldsymbol{x}.$$
#
# The output of interest $s(\boldsymbol{\mu})$ is given by
# $$s(\boldsymbol{\mu}) = \int_{\Omega} v \ d\boldsymbol{x}$$
# is computed for each $\boldsymbol{\mu}$.

# %%
import os
import sys
sys.path.append('../../')

from mlnics import NN, Losses, Normalization, RONNData, IO, Training, ErrorAnalysis
from dolfin import *
from rbnics import *
import torch
import numpy as np

torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ### 3. Affine Decomposition
#
# For this problem the affine decomposition is straightforward:
# $$a(u,v;\boldsymbol{\mu})=\underbrace{1}_{\Theta^{a}_0(\boldsymbol{\mu})}\underbrace{\int_{\Omega}\nabla u \cdot \nabla v \ d\boldsymbol{x}}_{a_0(u,v)},$$
# $$c(u,v;\boldsymbol{\mu})=\underbrace{\mu_0}_{\Theta^{c}_0(\boldsymbol{\mu})}\underbrace{\int_{\Omega}\frac{1}{\mu_1}\big(\exp\{\mu_1u\} - 1\big)v \ d\boldsymbol{x}}_{c_0(u,v)},$$
# $$f(v; \boldsymbol{\mu}) = \underbrace{100}_{\Theta^{f}_0(\boldsymbol{\mu})} \underbrace{\int_{\Omega}\sin(2\pi x_0)cos(2\pi x_1)v \ d\boldsymbol{x}}_{f_0(v)}.$$
# We will implement the numerical discretization of the problem in the class
# ```
# class NonlinearElliptic(NonlinearEllipticProblem):
# ```
# by specifying the coefficients $\Theta^{a}_*(\boldsymbol{\mu})$, $\Theta^{c}_*(\boldsymbol{\mu})$ and $\Theta^{f}_*(\boldsymbol{\mu})$ in the method
# ```
#     def compute_theta(self, term):
# ```
# and the bilinear forms $a_*(u, v)$, $c_*(u, v)$ and linear forms $f_*(v)$ in
# ```
#     def assemble_operator(self, term):
# ```

# %%
@ExactParametrizedFunctions()
class NonlinearElliptic(NonlinearEllipticProblem):

    # Default initialization of members
    def __init__(self, V, **kwargs):
        # Call the standard initialization
        NonlinearEllipticProblem.__init__(self, V, **kwargs)
        # ... and also store FEniCS data structures for assembly
        assert "subdomains" in kwargs
        assert "boundaries" in kwargs
        self.subdomains, self.boundaries = kwargs["subdomains"], kwargs["boundaries"]
        self.du = TrialFunction(V)
        self.u = self._solution
        self.v = TestFunction(V)
        self.dx = Measure("dx")(subdomain_data=self.subdomains)
        self.ds = Measure("ds")(subdomain_data=self.boundaries)
        # Store the forcing term expression
        self.f = Expression("sin(2*pi*x[0])*sin(2*pi*x[1])", element=self.V.ufl_element())
        # Customize nonlinear solver parameters
        self._nonlinear_solver_parameters.update({
            "linear_solver": "mumps",
            "maximum_iterations": 20,
            "report": True
        })

    # Return custom problem name
    def name(self):
        return "NonlinearEllipticExact"

    # Return theta multiplicative terms of the affine expansion of the problem.
    @compute_theta_for_derivatives
    def compute_theta(self, term):
        mu = self.mu
        if term == "a":
            theta_a0 = 1.
            return (theta_a0,)
        elif term == "c":
            theta_c0 = mu[0]
            return (theta_c0,)
        elif term == "f":
            theta_f0 = 100.
            return (theta_f0,)
        elif term == "s":
            theta_s0 = 1.0
            return (theta_s0,)
        else:
            raise ValueError("Invalid term for compute_theta().")

    # Return forms resulting from the discretization of the affine expansion of the problem operators.
    @assemble_operator_for_derivatives
    def assemble_operator(self, term):
        v = self.v
        dx = self.dx
        if term == "a":
            du = self.du
            a0 = inner(grad(du), grad(v)) * dx
            return (a0,)
        elif term == "c":
            u = self.u
            mu = self.mu
            c0 = (exp(mu[1] * u) - 1) / mu[1] * v * dx
            return (c0,)
        elif term == "f":
            f = self.f
            f0 = f * v * dx
            return (f0,)
        elif term == "s":
            s0 = v * dx
            return (s0,)
        elif term == "dirichlet_bc":
            bc0 = [DirichletBC(self.V, Constant(0.0), self.boundaries, 1)]
            return (bc0,)
        elif term == "inner_product":
            du = self.du
            x0 = inner(grad(du), grad(v)) * dx
            return (x0,)
        else:
            raise ValueError("Invalid term for assemble_operator().")


# Customize the resulting reduced problem
@CustomizeReducedProblemFor(NonlinearEllipticProblem)
def CustomizeReducedNonlinearElliptic(ReducedNonlinearElliptic_Base):
    class ReducedNonlinearElliptic(ReducedNonlinearElliptic_Base):
        def __init__(self, truth_problem, **kwargs):
            ReducedNonlinearElliptic_Base.__init__(self, truth_problem, **kwargs)
            self._nonlinear_solver_parameters.update({
                "report": True,
                "line_search": "wolfe"
            })

    return ReducedNonlinearElliptic

# %% [markdown]
# ## 4. Main program
#
# ### 4.1. Read the mesh for this problem
# The mesh was generated by the [data/generate_mesh.ipynb](data/generate_mesh.ipynb) notebook.

# %%
mesh = Mesh("data/square.xml")
subdomains = MeshFunction("size_t", mesh, "data/square_physical_region.xml")
boundaries = MeshFunction("size_t", mesh, "data/square_facet_region.xml")

# %% [markdown]
# ### 4.2. Create Finite Element space (Lagrange P1)

# %%
V = FunctionSpace(mesh, "Lagrange", 1)

# %% [markdown]
# ### 4.3. Allocate an object of the NonlinearElliptic class

# %%
problem = NonlinearElliptic(V, subdomains=subdomains, boundaries=boundaries)
mu_range = [(0.01, 10.0), (0.01, 10.0)]
problem.set_mu_range(mu_range)

# %% [markdown]
# ### 4.4. Prepare reduction with a POD-Galerkin method

# %%
reduction_method = PODGalerkin(problem)
reduction_method.set_Nmax(20, DEIM=21)
reduction_method.set_tolerance(1e-8, DEIM=1e-4)

# %% [markdown]
# ### 4.5. Perform the offline phase

# %% [markdown]
# #### 4.5.1 Fit Reduction Method

# %%
reduction_method.initialize_training_set(50, DEIM=60)
reduced_problem = reduction_method.offline()

# %% [markdown]
# #### 4.5.2 Train PINN
#
# Given a training set $X_{PINN} = (\boldsymbol{\mu}^{(1)}, \dots, \boldsymbol{\mu}^{(n)})$ of parameters for the PDE, we train a Physics-Informed Neural Network (PINN) $\operatorname{N}_W(\boldsymbol{\mu})$ dependent on the weights and biases $W$ of the network to minimize the loss function
#
# $$L_{PINN}(X_{PINN}; W) = \frac1n \sum_{i=1}^n \left\|A(\boldsymbol{\mu^{(i)}}) \operatorname{N}_W(\boldsymbol{\mu}^{(i)}) - \boldsymbol{f}(\boldsymbol{\mu}^{(i)}) + \boldsymbol{c}(\boldsymbol{\mu}^{(i)})\right\|_2^2$$
#
# over $W$, where for a given $\boldsymbol{\mu}$, $A(\boldsymbol{\mu})$ is the assembled matrix corresponding to the bilinear form $a$, $\boldsymbol{f}(\boldsymbol{\mu})$ is the assembled vector corresponding to the linear form $f$, and $\boldsymbol{c}(\boldsymbol{\mu})$ is a vector corresponding to the nonlinear form $c$.

# %%
input_normalization_pinn = Normalization.StandardNormalization(input_normalization=True)
output_normalization_pinn = Normalization.StandardNormalization()

pinn_net  = NN.RONN("PINN", problem, reduction_method, n_hidden=2, n_neurons=40)
pinn_loss = Losses.PINN_Loss(pinn_net, output_normalization_pinn)
data      = RONNData.RONNDataLoader(pinn_net, validation_proportion=0.2, 
                                    num_without_snapshots=100)
optimizer = torch.optim.Adam(pinn_net.parameters(), lr=0.001)
scheduler = None

pinn_trainer = Training.PINNTrainer(
    pinn_net, data, pinn_loss, optimizer, scheduler,
    input_normalization_pinn, num_epochs=10000
)

loaded, starting_epoch = IO.initialize_parameters(
    pinn_net, data, pinn_trainer, optimizer
)

# %%
pinn_trainer.train()
# Out:
# 0:  |F(x)| = 0.512965; step 1
# 1:  |F(x)| = 0.045468; step 1
# 2:  |F(x)| = 0.000401457; step 1
# 3:  |F(x)| = 3.15358e-08; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 's' not implemented. Continuing without operator 's'...
# 0:  |F(x)| = 2.88643; step 0.280019
# 1:  |F(x)| = 0.37946; step 1
# 2:  |F(x)| = 0.0330969; step 1
# 3:  |F(x)| = 0.000464268; step 1
# 4:  |F(x)| = 9.41442e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.68059; step 0.317493
# 1:  |F(x)| = 1.55599; step 1
# 2:  |F(x)| = 0.214355; step 1
# 3:  |F(x)| = 0.00693668; step 1
# 4:  |F(x)| = 8.15768e-06; step 1
# 5:  |F(x)| = 1.16429e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.40997; step 0.208308
# 1:  |F(x)| = 0.675447; step 1
# 2:  |F(x)| = 0.0942879; step 1
# 3:  |F(x)| = 0.00339271; step 1
# 4:  |F(x)| = 5.20798e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.66796; step 0.310799
# 1:  |F(x)| = 2.08022; step 0.406455
# 2:  |F(x)| = 0.207459; step 1
# 3:  |F(x)| = 0.00720945; step 1
# 4:  |F(x)| = 1.02926e-05; step 1
# 5:  |F(x)| = 2.16763e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 2.4947; step 0.321396
# 1:  |F(x)| = 0.34727; step 1
# 2:  |F(x)| = 0.0276032; step 1
# 3:  |F(x)| = 0.000328287; step 1
# 4:  |F(x)| = 4.48732e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.91438; step 0.276576
# 1:  |F(x)| = 0.424008; step 1
# 2:  |F(x)| = 0.042761; step 1
# 3:  |F(x)| = 0.000860345; step 1
# 4:  |F(x)| = 3.35062e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.71182; step 0.305116
# 1:  |F(x)| = 1.59517; step 1
# 2:  |F(x)| = 0.211531; step 1
# 3:  |F(x)| = 0.00655914; step 1
# 4:  |F(x)| = 7.15832e-06; step 1
# 5:  |F(x)| = 8.9476e-12; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 2.24993; step 0.442474
# 1:  |F(x)| = 0.162999; step 1
# 2:  |F(x)| = 0.00612679; step 1
# 3:  |F(x)| = 1.31925e-05; step 1
# 4:  |F(x)| = 5.857e-11; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.22778; step 0.31573
# 1:  |F(x)| = 0.53146; step 1
# 2:  |F(x)| = 0.0390549; step 1
# 3:  |F(x)| = 0.000365201; step 1
# 4:  |F(x)| = 3.91463e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.27568; step 0.316341
# 1:  |F(x)| = 0.574405; step 1
# 2:  |F(x)| = 0.0434968; step 1
# 3:  |F(x)| = 0.000369508; step 1
# 4:  |F(x)| = 2.90249e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.70155; step 0.310659
# 1:  |F(x)| = 2.39313; step 0.335088
# 2:  |F(x)| = 0.39498; step 1
# 3:  |F(x)| = 0.0252865; step 1
# 4:  |F(x)| = 0.000129679; step 1
# 5:  |F(x)| = 3.54101e-09; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.63357; step 0.307903
# 1:  |F(x)| = 1.42675; step 1
# 2:  |F(x)| = 0.194049; step 1
# 3:  |F(x)| = 0.00606787; step 1
# 4:  |F(x)| = 6.67648e-06; step 1
# 5:  |F(x)| = 8.42212e-12; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 2.54247; step 0.321994
# 1:  |F(x)| = 0.310475; step 1
# 2:  |F(x)| = 0.0217119; step 1
# 3:  |F(x)| = 0.000190984; step 1
# 4:  |F(x)| = 1.50156e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.71087; step 0.306044
# 1:  |F(x)| = 1.63187; step 1
# 2:  |F(x)| = 0.229298; step 1
# 3:  |F(x)| = 0.0079191; step 1
# 4:  |F(x)| = 1.07497e-05; step 1
# 5:  |F(x)| = 2.06461e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.71211; step 0.306066
# 1:  |F(x)| = 1.6304; step 1
# 2:  |F(x)| = 0.227753; step 1
# 3:  |F(x)| = 0.00778054; step 1
# 4:  |F(x)| = 1.03298e-05; step 1
# 5:  |F(x)| = 1.89853e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 2.9564; step 0.269234
# 1:  |F(x)| = 0.516803; step 1
# 2:  |F(x)| = 0.0656161; step 1
# 3:  |F(x)| = 0.00224802; step 1
# 4:  |F(x)| = 2.41431e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.08394; step 0.23399
# 1:  |F(x)| = 0.597641; step 1
# 2:  |F(x)| = 0.0887057; step 1
# 3:  |F(x)| = 0.00423334; step 1
# 4:  |F(x)| = 9.21517e-06; step 1
# 5:  |F(x)| = 3.76302e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.56153; step 0.339583
# 1:  |F(x)| = 1.25253; step 1
# 2:  |F(x)| = 0.141212; step 1
# 3:  |F(x)| = 0.00294562; step 1
# 4:  |F(x)| = 1.40315e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.67689; step 0.309707
# 1:  |F(x)| = 1.92845; step 0.445715
# 2:  |F(x)| = 0.149969; step 1
# 3:  |F(x)| = 0.00363984; step 1
# 4:  |F(x)| = 2.5123e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.67857; step 0.309526
# 1:  |F(x)| = 1.90469; step 0.451933
# 2:  |F(x)| = 0.142481; step 1
# 3:  |F(x)| = 0.0032618; step 1
# 4:  |F(x)| = 2.00242e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.85795; step 0.288889
# 1:  |F(x)| = 0.355362; step 1
# 2:  |F(x)| = 0.0288266; step 1
# 3:  |F(x)| = 0.000340404; step 1
# 4:  |F(x)| = 4.94458e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.08322; step 0.22531
# 1:  |F(x)| = 0.512831; step 1
# 2:  |F(x)| = 0.0529438; step 1
# 3:  |F(x)| = 0.000803147; step 1
# 4:  |F(x)| = 1.86139e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.16634; step 0.316796
# 1:  |F(x)| = 0.467462; step 1
# 2:  |F(x)| = 0.0328837; step 1
# 3:  |F(x)| = 0.000277675; step 1
# 4:  |F(x)| = 2.39342e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.70786; step 0.307785
# 1:  |F(x)| = 1.6342; step 0.526006
# 2:  |F(x)| = 0.0824372; step 1
# 3:  |F(x)| = 0.00100136; step 1
# 4:  |F(x)| = 1.84696e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.35789; step 0.175058
# 1:  |F(x)| = 0.771; step 1
# 2:  |F(x)| = 0.130672; step 1
# 3:  |F(x)| = 0.00694094; step 1
# 4:  |F(x)| = 2.33316e-05; step 1
# 5:  |F(x)| = 2.6211e-10; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.13636; step 0.219263
# 1:  |F(x)| = 0.534646; step 1
# 2:  |F(x)| = 0.0621038; step 1
# 3:  |F(x)| = 0.00145461; step 1
# 4:  |F(x)| = 9.17375e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.10331; step 0.216699
# 1:  |F(x)| = 0.538695; step 1
# 2:  |F(x)| = 0.059117; step 1
# 3:  |F(x)| = 0.00108374; step 1
# 4:  |F(x)| = 3.95982e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.16402; step 0.443014
# 1:  |F(x)| = 0.263538; step 1
# 2:  |F(x)| = 0.0151043; step 1
# 3:  |F(x)| = 7.65472e-05; step 1
# 4:  |F(x)| = 1.9353e-09; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.31942; step 0.381224
# 1:  |F(x)| = 0.874724; step 1
# 2:  |F(x)| = 0.0756492; step 1
# 3:  |F(x)| = 0.000866511; step 1
# 4:  |F(x)| = 1.21276e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.02867; step 0.429548
# 1:  |F(x)| = 0.574781; step 1
# 2:  |F(x)| = 0.0286883; step 1
# 3:  |F(x)| = 0.000112178; step 1
# 4:  |F(x)| = 1.85459e-09; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.14343; step 0.316414
# 1:  |F(x)| = 0.465721; step 1
# 2:  |F(x)| = 0.0341712; step 1
# 3:  |F(x)| = 0.000344433; step 1
# 4:  |F(x)| = 4.14346e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.56322; step 0.166925
# 1:  |F(x)| = 0.909851; step 1
# 2:  |F(x)| = 0.168844; step 1
# 3:  |F(x)| = 0.0105468; step 1
# 4:  |F(x)| = 5.11981e-05; step 1
# 5:  |F(x)| = 1.24618e-09; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.13902; step 0.238427
# 1:  |F(x)| = 0.471807; step 1
# 2:  |F(x)| = 0.0473942; step 1
# 3:  |F(x)| = 0.000743126; step 1
# 4:  |F(x)| = 2.08644e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.11856; step 0.236499
# 1:  |F(x)| = 0.521267; step 1
# 2:  |F(x)| = 0.0630562; step 1
# 3:  |F(x)| = 0.00182097; step 1
# 4:  |F(x)| = 1.58558e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.20424; step 0.1778
# 1:  |F(x)| = 0.7279; step 1
# 2:  |F(x)| = 0.105883; step 1
# 3:  |F(x)| = 0.00377802; step 1
# 4:  |F(x)| = 5.39506e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.30537; step 0.186299
# 1:  |F(x)| = 0.694583; step 1
# 2:  |F(x)| = 0.104155; step 1
# 3:  |F(x)| = 0.00416155; step 1
# 4:  |F(x)| = 7.79006e-06; step 1
# 5:  |F(x)| = 2.85648e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 2.98499; step 0.317507
# 1:  |F(x)| = 0.398296; step 1
# 2:  |F(x)| = 0.0317755; step 1
# 3:  |F(x)| = 0.000394974; step 1
# 4:  |F(x)| = 6.24476e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.91896; step 0.289328
# 1:  |F(x)| = 0.44687; step 1
# 2:  |F(x)| = 0.0476133; step 1
# 3:  |F(x)| = 0.00109957; step 1
# 4:  |F(x)| = 5.4281e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.1339; step 0.235778
# 1:  |F(x)| = 0.576547; step 1
# 2:  |F(x)| = 0.0800797; step 1
# 3:  |F(x)| = 0.00326628; step 1
# 4:  |F(x)| = 5.35033e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.44233; step 0.205031
# 1:  |F(x)| = 0.731709; step 1
# 2:  |F(x)| = 0.112016; step 1
# 3:  |F(x)| = 0.00524691; step 1
# 4:  |F(x)| = 1.3494e-05; step 1
# 5:  |F(x)| = 8.29097e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.15487; step 0.250807
# 1:  |F(x)| = 0.517989; step 1
# 2:  |F(x)| = 0.0605845; step 1
# 3:  |F(x)| = 0.00166066; step 1
# 4:  |F(x)| = 1.28865e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.26856; step 0.219946
# 1:  |F(x)| = 0.64828; step 1
# 2:  |F(x)| = 0.0980025; step 1
# 3:  |F(x)| = 0.00471889; step 1
# 4:  |F(x)| = 1.14327e-05; step 1
# 5:  |F(x)| = 5.87708e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 2.95826; step 0.235235
# 1:  |F(x)| = 0.501516; step 1
# 2:  |F(x)| = 0.0575403; step 1
# 3:  |F(x)| = 0.00152786; step 1
# 4:  |F(x)| = 1.12387e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.66532; step 0.359904
# 1:  |F(x)| = 0.206112; step 1
# 2:  |F(x)| = 0.00899953; step 1
# 3:  |F(x)| = 2.11547e-05; step 1
# 4:  |F(x)| = 1.25475e-10; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.02782; step 0.317398
# 1:  |F(x)| = 0.404535; step 1
# 2:  |F(x)| = 0.0307623; step 1
# 3:  |F(x)| = 0.000341983; step 1
# 4:  |F(x)| = 4.5387e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.92018; step 0.279081
# 1:  |F(x)| = 0.427851; step 1
# 2:  |F(x)| = 0.0436235; step 1
# 3:  |F(x)| = 0.000901966; step 1
# 4:  |F(x)| = 3.67611e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.6598; step 0.349088
# 1:  |F(x)| = 0.232529; step 1
# 2:  |F(x)| = 0.0119129; step 1
# 3:  |F(x)| = 4.76526e-05; step 1
# 4:  |F(x)| = 8.34268e-10; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.04574; step 0.235205
# 1:  |F(x)| = 0.519589; step 1
# 2:  |F(x)| = 0.0636816; step 1
# 3:  |F(x)| = 0.00194219; step 1
# 4:  |F(x)| = 1.83725e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.35192; step 0.213074
# 1:  |F(x)| = 0.626632; step 1
# 2:  |F(x)| = 0.0827628; step 1
# 3:  |F(x)| = 0.00259479; step 1
# 4:  |F(x)| = 2.98923e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.92549; step 0.278146
# 1:  |F(x)| = 0.436137; step 1
# 2:  |F(x)| = 0.0454804; step 1
# 3:  |F(x)| = 0.000991423; step 1
# 4:  |F(x)| = 4.46405e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.09905; step 0.289125
# 1:  |F(x)| = 0.486126; step 1
# 2:  |F(x)| = 0.0489323; step 1
# 3:  |F(x)| = 0.00103174; step 1
# 4:  |F(x)| = 4.62334e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.33659; step 0.17989
# 1:  |F(x)| = 0.731029; step 1
# 2:  |F(x)| = 0.113777; step 1
# 3:  |F(x)| = 0.00482008; step 1
# 4:  |F(x)| = 1.01525e-05; step 1
# 5:  |F(x)| = 4.82039e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.49056; step 0.20099
# 1:  |F(x)| = 0.756085; step 1
# 2:  |F(x)| = 0.114313; step 1
# 3:  |F(x)| = 0.00501722; step 1
# 4:  |F(x)| = 1.17061e-05; step 1
# 5:  |F(x)| = 6.22156e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.31517; step 0.183054
# 1:  |F(x)| = 0.745044; step 1
# 2:  |F(x)| = 0.106915; step 1
# 3:  |F(x)| = 0.00337914; step 1
# 4:  |F(x)| = 3.37647e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.35627; step 0.168359
# 1:  |F(x)| = 0.822217; step 1
# 2:  |F(x)| = 0.154183; step 1
# 3:  |F(x)| = 0.0104678; step 1
# 4:  |F(x)| = 5.77414e-05; step 1
# 5:  |F(x)| = 1.643e-09; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.27631; step 0.188625
# 1:  |F(x)| = 0.687574; step 1
# 2:  |F(x)| = 0.0935929; step 1
# 3:  |F(x)| = 0.00264226; step 1
# 4:  |F(x)| = 2.11879e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.00443; step 0.237435
# 1:  |F(x)| = 0.46245; step 1
# 2:  |F(x)| = 0.0448724; step 1
# 3:  |F(x)| = 0.000679274; step 1
# 4:  |F(x)| = 1.79743e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.24358; step 0.193069
# 1:  |F(x)| = 0.663377; step 1
# 2:  |F(x)| = 0.0870303; step 1
# 3:  |F(x)| = 0.00226013; step 1
# 4:  |F(x)| = 1.52221e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.15235; step 0.236888
# 1:  |F(x)| = 0.561759; step 1
# 2:  |F(x)| = 0.0745372; step 1
# 3:  |F(x)| = 0.00272089; step 1
# 4:  |F(x)| = 3.64784e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.69992; step 0.314139
# 1:  |F(x)| = 1.72433; step 0.501958
# 2:  |F(x)| = 0.103832; step 1
# 3:  |F(x)| = 0.00155209; step 1
# 4:  |F(x)| = 4.21064e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.92466; step 0.272239
# 1:  |F(x)| = 0.457202; step 1
# 2:  |F(x)| = 0.050557; step 1
# 3:  |F(x)| = 0.00126332; step 1
# 4:  |F(x)| = 7.38996e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.34132; step 0.183541
# 1:  |F(x)| = 0.745181; step 1
# 2:  |F(x)| = 0.126991; step 1
# 3:  |F(x)| = 0.00720321; step 1
# 4:  |F(x)| = 2.68411e-05; step 1
# 5:  |F(x)| = 3.45563e-10; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.34776; step 0.18687
# 1:  |F(x)| = 0.773273; step 1
# 2:  |F(x)| = 0.142532; step 1
# 3:  |F(x)| = 0.00997617; step 1
# 4:  |F(x)| = 5.47469e-05; step 1
# 5:  |F(x)| = 1.4362e-09; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 2.94576; step 0.322513
# 1:  |F(x)| = 0.295703; step 1
# 2:  |F(x)| = 0.0178225; step 1
# 3:  |F(x)| = 7.57465e-05; step 1
# 4:  |F(x)| = 1.30222e-09; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.54566; step 0.30994
# 1:  |F(x)| = 1.11607; step 1
# 2:  |F(x)| = 0.125135; step 1
# 3:  |F(x)| = 0.00256449; step 1
# 4:  |F(x)| = 1.18122e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.65789; step 0.32245
# 1:  |F(x)| = 1.55957; step 1
# 2:  |F(x)| = 0.227973; step 1
# 3:  |F(x)| = 0.00817258; step 1
# 4:  |F(x)| = 1.17939e-05; step 1
# 5:  |F(x)| = 2.52012e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.09027; step 0.420891
# 1:  |F(x)| = 0.70117; step 1
# 2:  |F(x)| = 0.062972; step 1
# 3:  |F(x)| = 0.000702584; step 1
# 4:  |F(x)| = 9.14532e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.36577; step 0.313225
# 1:  |F(x)| = 0.716868; step 1
# 2:  |F(x)| = 0.059507; step 1
# 3:  |F(x)| = 0.000693551; step 1
# 4:  |F(x)| = 1.13171e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.25329; step 0.178049
# 1:  |F(x)| = 0.724777; step 1
# 2:  |F(x)| = 0.110065; step 1
# 3:  |F(x)| = 0.0044594; step 1
# 4:  |F(x)| = 8.54062e-06; step 1
# 5:  |F(x)| = 3.41498e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.48953; step 0.352177
# 1:  |F(x)| = 1.12065; step 1
# 2:  |F(x)| = 0.115825; step 1
# 3:  |F(x)| = 0.00198772; step 1
# 4:  |F(x)| = 6.34888e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.96659; step 0.237227
# 1:  |F(x)| = 0.465108; step 1
# 2:  |F(x)| = 0.0452357; step 1
# 3:  |F(x)| = 0.000712998; step 1
# 4:  |F(x)| = 2.06454e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.29881; step 0.315357
# 1:  |F(x)| = 0.60865; step 1
# 2:  |F(x)| = 0.0470181; step 1
# 3:  |F(x)| = 0.00043807; step 1
# 4:  |F(x)| = 4.34073e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.03714; step 0.233386
# 1:  |F(x)| = 0.592499; step 1
# 2:  |F(x)| = 0.0877229; step 1
# 3:  |F(x)| = 0.00418999; step 1
# 4:  |F(x)| = 9.04966e-06; step 1
# 5:  |F(x)| = 3.6435e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.04619; step 0.235389
# 1:  |F(x)| = 0.513186; step 1
# 2:  |F(x)| = 0.061661; step 1
# 3:  |F(x)| = 0.00178644; step 1
# 4:  |F(x)| = 1.54277e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.89253; step 0.317936
# 1:  |F(x)| = 0.387743; step 1
# 2:  |F(x)| = 0.0333612; step 1
# 3:  |F(x)| = 0.000482717; step 1
# 4:  |F(x)| = 9.64968e-08; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.5796; step 0.383573
# 1:  |F(x)| = 0.240932; step 1
# 2:  |F(x)| = 0.0128434; step 1
# 3:  |F(x)| = 6.21391e-05; step 1
# 4:  |F(x)| = 1.40212e-09; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.18654; step 0.179959
# 1:  |F(x)| = 0.718557; step 1
# 2:  |F(x)| = 0.101869; step 1
# 3:  |F(x)| = 0.00339606; step 1
# 4:  |F(x)| = 4.15239e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.11655; step 0.255032
# 1:  |F(x)| = 0.506759; step 1
# 2:  |F(x)| = 0.0589821; step 1
# 3:  |F(x)| = 0.00161577; step 1
# 4:  |F(x)| = 1.22263e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.68124; step 0.361653
# 1:  |F(x)| = 0.23362; step 1
# 2:  |F(x)| = 0.0117063; step 1
# 3:  |F(x)| = 4.65379e-05; step 1
# 4:  |F(x)| = 7.84575e-10; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.78739; step 0.299029
# 1:  |F(x)| = 0.304664; step 1
# 2:  |F(x)| = 0.0196643; step 1
# 3:  |F(x)| = 0.000117397; step 1
# 4:  |F(x)| = 4.78383e-09; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.71018; step 0.313921
# 1:  |F(x)| = 2.36169; step 0.344971
# 2:  |F(x)| = 0.387842; step 1
# 3:  |F(x)| = 0.0242795; step 1
# 4:  |F(x)| = 0.000118441; step 1
# 5:  |F(x)| = 2.916e-09; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 's' not implemented. Continuing without operator 's'...
# 0:  |F(x)| = 3.17166; step 0.208743
# 1:  |F(x)| = 0.600988; step 1
# 2:  |F(x)| = 0.0829633; step 1
# 3:  |F(x)| = 0.00310822; step 1
# 4:  |F(x)| = 4.78549e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.18314; step 0.239768
# 1:  |F(x)| = 0.523431; step 1
# 2:  |F(x)| = 0.061298; step 1
# 3:  |F(x)| = 0.00161215; step 1
# 4:  |F(x)| = 1.20473e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.32243; step 0.21586
# 1:  |F(x)| = 0.591028; step 1
# 2:  |F(x)| = 0.0727011; step 1
# 3:  |F(x)| = 0.00181861; step 1
# 4:  |F(x)| = 1.3264e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.33666; step 0.179901
# 1:  |F(x)| = 0.73108; step 1
# 2:  |F(x)| = 0.113848; step 1
# 3:  |F(x)| = 0.00483252; step 1
# 4:  |F(x)| = 1.02217e-05; step 1
# 5:  |F(x)| = 4.89013e-11; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.24747; step 0.276671
# 1:  |F(x)| = 0.565189; step 1
# 2:  |F(x)| = 0.0586463; step 1
# 3:  |F(x)| = 0.00135001; step 1
# 4:  |F(x)| = 7.83808e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.19218; step 0.243527
# 1:  |F(x)| = 0.550812; step 1
# 2:  |F(x)| = 0.0686332; step 1
# 3:  |F(x)| = 0.00217143; step 1
# 4:  |F(x)| = 2.25023e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.35708; step 0.175472
# 1:  |F(x)| = 0.767932; step 1
# 2:  |F(x)| = 0.129394; step 1
# 3:  |F(x)| = 0.00677394; step 1
# 4:  |F(x)| = 2.21064e-05; step 1
# 5:  |F(x)| = 2.34956e-10; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.71227; step 0.314902
# 1:  |F(x)| = 2.65221; step 0.273515
# 2:  |F(x)| = 0.678285; step 1
# 3:  |F(x)| = 0.0707193; step 1
# 4:  |F(x)| = 0.00103802; step 1
# 5:  |F(x)| = 2.35896e-07; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.15598; step 0.203322
# 1:  |F(x)| = 0.634319; step 1
# 2:  |F(x)| = 0.0776702; step 1
# 3:  |F(x)| = 0.00173548; step 1
# 4:  |F(x)| = 8.66871e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.34674; step 0.183352
# 1:  |F(x)| = 0.755369; step 1
# 2:  |F(x)| = 0.131772; step 1
# 3:  |F(x)| = 0.00793442; step 1
# 4:  |F(x)| = 3.3146e-05; step 1
# 5:  |F(x)| = 5.27746e-10; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.22535; step 0.197802
# 1:  |F(x)| = 0.715555; step 1
# 2:  |F(x)| = 0.126721; step 1
# 3:  |F(x)| = 0.00846829; step 1
# 4:  |F(x)| = 3.95523e-05; step 1
# 5:  |F(x)| = 7.38713e-10; step 1
# scipy solver converged in 7 iterations.
# 0:  |F(x)| = 3.16234; step 0.199034
# 1:  |F(x)| = 0.626457; step 1
# 2:  |F(x)| = 0.0878602; step 1
# 3:  |F(x)| = 0.00333091; step 1
# 4:  |F(x)| = 5.4262e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.89801; step 0.23747
# 1:  |F(x)| = 0.470363; step 1
# 2:  |F(x)| = 0.0447714; step 1
# 3:  |F(x)| = 0.000676836; step 1
# 4:  |F(x)| = 1.83801e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.16649; step 0.181539
# 1:  |F(x)| = 0.716037; step 1
# 2:  |F(x)| = 0.0993766; step 1
# 3:  |F(x)| = 0.00312165; step 1
# 4:  |F(x)| = 3.30098e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 2.89727; step 0.284372
# 1:  |F(x)| = 0.39976; step 1
# 2:  |F(x)| = 0.0376544; step 1
# 3:  |F(x)| = 0.000646064; step 1
# 4:  |F(x)| = 1.84889e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.15905; step 0.20189
# 1:  |F(x)| = 0.599453; step 1
# 2:  |F(x)| = 0.0755397; step 1
# 3:  |F(x)| = 0.00203767; step 1
# 4:  |F(x)| = 1.71255e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.12704; step 0.237304
# 1:  |F(x)| = 0.497932; step 1
# 2:  |F(x)| = 0.0557275; step 1
# 3:  |F(x)| = 0.00128719; step 1
# 4:  |F(x)| = 7.54905e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.19582; step 0.240409
# 1:  |F(x)| = 0.497122; step 1
# 2:  |F(x)| = 0.050754; step 1
# 3:  |F(x)| = 0.00069638; step 1
# 4:  |F(x)| = 1.28697e-07; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.19957; step 0.224915
# 1:  |F(x)| = 0.563217; step 1
# 2:  |F(x)| = 0.0723689; step 1
# 3:  |F(x)| = 0.00232513; step 1
# 4:  |F(x)| = 2.59879e-06; step 1
# scipy solver converged in 6 iterations.
# 0:  |F(x)| = 3.39483; step 0.208983
# 1:  |F(x)| = 0.711313; step 1
# 2:  |F(x)| = 0.110144; step 1
# 3:  |F(x)| = 0.00543181; step 1
# 4:  |F(x)| = 1.49168e-05; step 1
# 5:  |F(x)| = 1.01179e-10; step 1
# scipy solver converged in 7 iterations.
# 0 2.3275921884096493 	Loss(validation) = 2.802661022509413
# 100 0.03564533696983798 	Loss(validation) = 0.043215511058597736
# 200 0.010938846931796076 	Loss(validation) = 0.013159854963626604
# 300 0.007553327180857447 	Loss(validation) = 0.00848681964083019
# 400 0.006095032698555255 	Loss(validation) = 0.006325627734583944
# 500 0.005240619898293294 	Loss(validation) = 0.005118452482069113
# 600 0.00460659120597254 	Loss(validation) = 0.004288095263773358

# %%
fig, ax = Training.plot_loss(pinn_trainer, pinn_net)

# %% [markdown]
# #### 4.5.3 Train PDNN
#
# Given a training set $X_{PDNN} = ((\boldsymbol{\mu}^{(1)}, \operatorname{HF}(\boldsymbol{\mu}^{(1)})), \dots, (\boldsymbol{\mu}^{(n)}, \operatorname{HF}(\boldsymbol{\mu}^{(n)})))$ of parameter and high fidelity solution pairs for the PDE, we train a Projection-Driven Neural Network (PDNN) $\operatorname{N}_W(\boldsymbol{\mu})$ dependent on the weights and biases $W$ of the network to minimize the loss function
# $$L_{PDNN}(X_{PDNN}; W) = \frac1n \sum_{i=1}^n \|\operatorname{N}_W(\boldsymbol{\mu}^{(i)}) - \tilde{\operatorname{HF}}(\boldsymbol{\mu}^{(i)})\|_2^2,$$
# where for a given $\boldsymbol{\mu}$, $\tilde{\operatorname{HF}}(\boldsymbol{\mu})$ is the projection of $\operatorname{HF}(\boldsymbol{\mu})$ onto the reduced order solution space.

# %%
input_normalization_pdnn = Normalization.StandardNormalization(input_normalization=True)
output_normalization_pdnn = Normalization.StandardNormalization()

pdnn_net  = NN.RONN("PDNN", problem, reduction_method, n_hidden=2, n_neurons=40)
pdnn_loss = Losses.PDNN_Loss(pdnn_net, output_normalization_pdnn)
data      = RONNData.RONNDataLoader(pdnn_net, validation_proportion=0.2)
optimizer = torch.optim.Adam(pdnn_net.parameters(), lr=0.001)

pdnn_trainer = Training.PDNNTrainer(
    pdnn_net, data, pdnn_loss, optimizer,
    input_normalization_pdnn, num_epochs=10000
)

loaded, starting_epoch = IO.initialize_parameters(
    pdnn_net, data, pdnn_trainer, optimizer
)

# %%
pdnn_trainer.train()

# %%
fig, ax = Training.plot_loss(pdnn_trainer, pdnn_net)

# %% [markdown]
# #### 4.5.4 Train PRNN
#
# We train a Physics-Reinforced Neural Network (PRNN) $N_W(\boldsymbol{\mu})$ dependnent on the weights and biases $W$ of the network to minimize the loss function
#
# $$L_{PRNN}(X_{PINN}, X_{PDNN}; W) = L_{PINN}(X_{PINN}; W) + \omega L_{PDNN}(X_{PDNN}; W),$$
#
# where $\omega$ is a scaling parameter which can be chosen freely.

# %%
input_normalization_prnn = Normalization.StandardNormalization(input_normalization=True)
output_normalization_prnn = Normalization.StandardNormalization()

omega = 1.
prnn_net  = NN.RONN(f"PRNN_{omega}", problem, reduction_method, n_hidden=2, n_neurons=40)
prnn_loss = Losses.PRNN_Loss(prnn_net, output_normalization_prnn, omega=omega)
data      = RONNData.RONNDataLoader(prnn_net, validation_proportion=0.2,
                                    num_without_snapshots=100)
optimizer = torch.optim.Adam(prnn_net.parameters(), lr=0.001)

prnn_trainer = Training.PRNNTrainer(
    prnn_net, data, prnn_loss, optimizer,
    input_normalization_prnn, num_epochs=1000
)

loaded, starting_epoch = IO.initialize_parameters(
    prnn_net, data, prnn_trainer, optimizer
)

# %%
prnn_trainer.train()

# %%
fig, ax = Training.plot_loss(prnn_trainer, prnn_net, separate=True)

# %% [markdown]
# ### 4.6. Perform an error analysis

# %% [markdown]
# #### 4.6.1 Reduction Method Error Analysis

# %%
reduction_method.initialize_testing_set(50, DEIM=60)
#reduction_method.error_analysis()

# %% [markdown]
# #### 4.6.2 PINN Error Analysis

# %%
test_mu = torch.tensor(reduction_method.testing_set)

# %%
_ = ErrorAnalysis.error_analysis_fixed_net(
    pinn_net, test_mu, input_normalization_pinn, output_normalization_pinn, relative=False
)

# %%
ErrorAnalysis.plot_solution_difference(
    pinn_net, (5., 5.), input_normalization_pinn, output_normalization_pinn, colorbar=True
)

# %% [markdown]
# #### 4.6.3 PDNN Error Analysis

# %%
_ = ErrorAnalysis.error_analysis_fixed_net(
    pdnn_net, test_mu, input_normalization_pdnn, output_normalization_pdnn, relative=False
)

# %%
ErrorAnalysis.plot_solution_difference(
    pdnn_net, (5., 5.), input_normalization_pdnn, output_normalization_pdnn
)

# %% [markdown]
# #### 4.6.4 PRNN Error Analysis

# %%
_ = ErrorAnalysis.error_analysis_fixed_net(
    prnn_net, test_mu, input_normalization_prnn, output_normalization_prnn, relative=False
)

# %%
ErrorAnalysis.plot_solution_difference(
    prnn_net, (5., 5.), input_normalization_prnn, output_normalization_prnn
)

# %% [markdown]
# #### 4.6.5 Neural Network Error Comparison

# %%
nets = dict()
nets["pinn_net"] = pinn_net
nets["pdnn_net"] = pdnn_net
nets["prnn_net"] = prnn_net

input_normalizations = dict()
input_normalizations["pinn_net"] = input_normalization_pinn
input_normalizations["pdnn_net"] = input_normalization_pdnn
input_normalizations["prnn_net"] = input_normalization_prnn

output_normalizations = dict()
output_normalizations["pinn_net"] = output_normalization_pinn
output_normalizations["pdnn_net"] = output_normalization_pdnn
output_normalizations["prnn_net"] = output_normalization_prnn

_ = ErrorAnalysis.error_analysis_by_network(
    nets, test_mu, input_normalizations, output_normalizations, relative=False
)

# %% [markdown]
# ### 4.7. Perform a speedup analysis

# %%
reduction_method.speedup_analysis()

# %%
from rbnics.backends.dolfin.evaluate import evaluate
for Cj in reduced_problem.assemble_operator('c'):
    print(Cj)

# %%
np.array(evaluate(Cj._args[1]))

# %%
np.array([v.vector() for v in Cj._args[0]]).shape

# %%
Cj

# %%
from rbnics.backends.basic.wrapping.delayed_transpose import DelayedTranspose
