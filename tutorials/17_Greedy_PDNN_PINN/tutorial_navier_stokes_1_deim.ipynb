# %% [markdown]
# ## Tutorial 17 - Navier Stokes equations
# **_Keywords: DEIM, supremizer operator_**
#
# ### 1. Introduction
#
# In this tutorial, we will study the Navier-Stokes equations over a two-dimensional backward-facing step domain $\Omega$.
#
# A Poiseuille flow profile is imposed on the inlet boundary, and a no-flow (zero velocity) condition is imposed on the walls. A homogeneous Neumann condition of the Cauchy stress tensor is applied at the outflow boundary.
#
# The inflow velocity boundary condition is characterized by $$\boldsymbol{u}(\boldsymbol{x};\mu)=\mu\bigg \{\frac{1}{2.25}(x_1-2)(5-x_1),0\bigg \} \quad \forall \boldsymbol{x}=(x_0,x_1) \in \Omega$$
#
# This problem is characterized by one parameter $\mu$, which characterizes the inlet velocity. The range of $\mu$ is the following $$\mu \in [1.0, 80.0].$$
#
# Thus, the parameter domain is $$\mathbb{P}=[1.0,80.0].$$
#
# In order to obtain a faster approximation of the problem, we pursue a model reduction by means of a POD-Galerkin reduced order method.

# %% [markdown]
# ### 2. Parametrized formulation
#
# Let $\boldsymbol{u}(\mu)$ be the velocity vector and $p(\mu)$ be the pressure in the domain $\Omega$.
#
# We will directly provide a weak formulation for this problem: for a given parameter $\mu \in \mathbb{P},$ find $u(\mu) \in \mathbb{V}(\mu), \; p \in\mathbb{M}$ such that
#
# <center>
#     $
#     \begin{cases}
#         \nu \int_{\Omega} \nabla \boldsymbol{u} : \nabla \boldsymbol{v} \ d\Omega + \int_{\Omega} [(\boldsymbol{u} \cdot \nabla) \boldsymbol{u}] \cdot \boldsymbol{v} \ d\Omega - \int_{\Omega} p \nabla \cdot \boldsymbol{v} \ d\Omega = \int_{\Omega} \boldsymbol{f} \cdot \boldsymbol{v} \ d\Omega, \quad \forall \boldsymbol{v} \in\mathbb{V},  \\
#         \int_{\Omega} q \nabla \cdot \boldsymbol{u} \ d\Omega = 0, \quad \forall q \in\mathbb{M}
#     \end{cases}
#     $
# </center>
# where
#
# * $\nu$ represents kinematic viscosity
# * the functional space $\mathbb{V}(\mu)$ is defined as $\mathbb{V}=[H^1_{\Gamma_{wall}}(\Omega)]^2$
# * the functional space $\mathbb{M}(\mu)$ is defined as $\mathbb{M}=L^2(\Omega)$
#
#
# Since this problem utilizes mixed finite element discretization with the velocity and pressure as solution variables, the inf-sup condition is necessary for the well posedness of this problem. Thus, the supremizer operator $T^{\mu}: \mathbb{M}_h \rightarrow \mathbb{V}_h$ will be used.

# %%
import os
import sys
sys.path.append('../../')

from mlnics import NN, Losses, Normalization, RONNData, IO, Training, ErrorAnalysis
from dolfin import *
from rbnics import *
from ufl import transpose
import torch
import numpy as np
import matplotlib.pyplot as plt

torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ### 3. Affine Decomposition

# %%
@DEIM("online", basis_generation="Greedy")
@ExactParametrizedFunctions("offline")
class NavierStokes(NavierStokesProblem):

    # Default initialization of members
    def __init__(self, V, **kwargs):
        # Call the standard initialization
        NavierStokesProblem.__init__(self, V, **kwargs)
        # ... and also store FEniCS data structures for assembly
        assert "subdomains" in kwargs
        assert "boundaries" in kwargs
        self.subdomains, self.boundaries = kwargs["subdomains"], kwargs["boundaries"]
        dup = TrialFunction(V)
        (self.du, self.dp) = split(dup)
        (self.u, _) = split(self._solution)
        vq = TestFunction(V)
        (self.v, self.q) = split(vq)
        self.dx = Measure("dx")(subdomain_data=self.subdomains)
        self.ds = Measure("ds")(subdomain_data=self.boundaries)
        #
        self.inlet = Expression(("1. / 2.25 * (x[1] - 2) * (5 - x[1])", "0."), degree=2)
        self.f = Constant((0.0, 0.0))
        self.g = Constant(0.0)
        # Customize nonlinear solver parameters
        self._nonlinear_solver_parameters.update({
            "linear_solver": "mumps",
            "maximum_iterations": 20,
            "report": True
        })

    # Return custom problem name
    def name(self):
        return "NavierStokesDEIM1"

    # Return theta multiplicative terms of the affine expansion of the problem.
    @compute_theta_for_derivatives
    @compute_theta_for_supremizers
    def compute_theta(self, term):
        mu = self.mu
        if term == "a":
            theta_a0 = 1.
            return (theta_a0,)
        elif term in ("b", "bt"):
            theta_b0 = 1.
            return (theta_b0,)
        elif term == "c":
            theta_c0 = 1.
            return (theta_c0,)
        elif term == "f":
            theta_f0 = 1.
            return (theta_f0,)
        elif term == "g":
            theta_g0 = 1.
            return (theta_g0,)
        elif term == "dirichlet_bc_u":
            theta_bc00 = mu[0]
            return (theta_bc00,)
        else:
            raise ValueError("Invalid term for compute_theta().")

    # Return forms resulting from the discretization of the affine expansion of the problem operators.
    @assemble_operator_for_derivatives
    @assemble_operator_for_supremizers
    def assemble_operator(self, term):
        dx = self.dx
        if term == "a":
            u = self.du
            v = self.v
            a0 = inner(grad(u) + transpose(grad(u)), grad(v)) * dx
            return (a0,)
        elif term == "b":
            u = self.du
            q = self.q
            b0 = - q * div(u) * dx
            return (b0,)
        elif term == "bt":
            p = self.dp
            v = self.v
            bt0 = - p * div(v) * dx
            return (bt0,)
        elif term == "c":
            u = self.u
            v = self.v
            c0 = inner(grad(u) * u, v) * dx
            return (c0,)
        elif term == "f":
            v = self.v
            f0 = inner(self.f, v) * dx
            return (f0,)
        elif term == "g":
            q = self.q
            g0 = self.g * q * dx
            return (g0,)
        elif term == "dirichlet_bc_u":
            bc0 = [DirichletBC(self.V.sub(0), self.inlet, self.boundaries, 1),
                   DirichletBC(self.V.sub(0), Constant((0.0, 0.0)), self.boundaries, 2)]
            return (bc0,)
        elif term == "inner_product_u":
            u = self.du
            v = self.v
            x0 = inner(grad(u), grad(v)) * dx
            return (x0,)
        elif term == "inner_product_p":
            p = self.dp
            q = self.q
            x0 = inner(p, q) * dx
            return (x0,)
        else:
            raise ValueError("Invalid term for assemble_operator().")


# Customize the resulting reduced problem
@CustomizeReducedProblemFor(NavierStokesProblem)
def CustomizeReducedNavierStokes(ReducedNavierStokes_Base):
    class ReducedNavierStokes(ReducedNavierStokes_Base):
        def __init__(self, truth_problem, **kwargs):
            ReducedNavierStokes_Base.__init__(self, truth_problem, **kwargs)
            self._nonlinear_solver_parameters.update({
                "report": True,
                "line_search": "wolfe"
            })

    return ReducedNavierStokes

# %% [markdown]
# ## 4. Main program
#
# ### 4.1. Read the mesh for this problem
# The mesh was generated by the [data/generate_mesh.ipynb](data/generate_mesh.ipynb) notebook.

# %%
mesh = Mesh("data/backward_facing_step.xml")
subdomains = MeshFunction("size_t", mesh, "data/backward_facing_step_physical_region.xml")
boundaries = MeshFunction("size_t", mesh, "data/backward_facing_step_facet_region.xml")

# %% [markdown]
# ### 4.2. Create Finite Element Space (Taylor-Hood P2-P1)

# %%
element_u = VectorElement("Lagrange", mesh.ufl_cell(), 2)
element_p = FiniteElement("Lagrange", mesh.ufl_cell(), 1)
element = MixedElement(element_u, element_p)
V = FunctionSpace(mesh, element, components=[["u", "s"], "p"])

# %% [markdown]
# ### 4.3. Allocate an object of the NavierStokes class

# %%
problem = NavierStokes(V, subdomains=subdomains, boundaries=boundaries)
mu_range = [(1.0, 80.0)]
problem.set_mu_range(mu_range)

# %% [markdown]
# ### 4.4. Prepare reduction with a POD-Galerkin method

# %%
reduction_method = PODGalerkin(problem)
reduction_method.set_Nmax(10, DEIM=20)

# %% [markdown]
# ### 4.5. Perform the offline phase

# %% [markdown]
# #### 4.5.1 Fit Reduction Method

# %%
lifting_mu = (1.0,)
problem.set_mu(lifting_mu)
reduction_method.initialize_training_set(100, DEIM=144, sampling=EquispacedDistribution())
reduced_problem = reduction_method.offline()

# %% [markdown]
# #### 4.5.2 Train Greedy PDNN-PINN

# %%
input_normalization_pdnn = Normalization.MinMaxNormalization(input_normalization=True)
output_normalization_pdnn = Normalization.MinMaxNormalization()

pdnn_net  = NN.RONN("PDNN", problem, reduction_method, n_hidden=2, n_neurons=60)
pdnn_loss = Losses.PDNN_Loss(pdnn_net, output_normalization_pdnn)
data      = RONNData.RONNDataLoader(pdnn_net, validation_proportion=0.2)
optimizer = torch.optim.Adam(pdnn_net.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.9999)

pdnn_trainer = Training.PDNNTrainer(
    pdnn_net, data, pdnn_loss, optimizer, scheduler,
    input_normalization_pdnn, num_epochs=10000
)

loaded, starting_epoch = IO.initialize_parameters(
    pdnn_net, data, pdnn_trainer, optimizer
)

# %%
n = 1000 # number of parameters for which we compute residuals each iteration
num_new_params = 5 # number of parameters with which we augment data each iteration
assert num_new_params <= n

# train PDNN
print("Initial training...")
pdnn_trainer.train()

reduction_method.initialize_testing_set(n, DEIM=25, sampling=EquispacedDistribution())
new_parameters = pdnn_net.augment_parameters_with_time(
        torch.tensor(reduction_method.testing_set)
)

print("Assembling residuals...")
residuals, _, loss_functions = ErrorAnalysis.get_residuals(
    pdnn_net, data, new_parameters, 
    input_normalization_pdnn, output_normalization_pdnn,
    plot_residuals=False
)


print("Beginning data augmentation cycles...")
for i in range(10):
    probabilities = residuals
    probabilities /= np.sum(probabilities)
    sample_indices = np.random.choice(residuals.shape[0], size=residuals.shape[0],
                                      replace=False, p=probabilities)
    cumulative_probs = np.cumsum(probabilities[sample_indices])
    #last_index = np.searchsorted(cumulative_probs, 0.25) + 1
    #sample_indices = sample_indices[:last_index]
    sample_indices = sample_indices[:num_new_params]
    high_residual_params = new_parameters[sample_indices]
    
    # solve reduced PDE system for parameters found above and augment training data
    for j, mu in enumerate(high_residual_params):
        reduced_problem.set_mu(tuple(np.array(mu)))
        reduced_problem.solve()
        solution = torch.tensor(np.array(reduced_problem._solution.vector()[:])).view(-1, 1)
        pdnn_loss.concatenate_snapshots(solution)
        
    data.train_data = torch.cat([data.train_data, high_residual_params])
    
    # train PDNN
    pdnn_trainer.train()
    
    residuals, _, _ = ErrorAnalysis.get_residuals(
        pdnn_net, data, new_parameters, 
        input_normalization_pdnn, output_normalization_pdnn,
        loss_functions, plot_residuals=False
    )
# Out:
# Initial training...
# 0 0.2191089988838061 	Loss(validation) = 0.37025675586486156
# 100 0.08320665724600469 	Loss(validation) = 0.4399661690858219
# 200 0.04541358046410435 	Loss(validation) = 0.5002313213838012
# 300 0.02457689429567231 	Loss(validation) = 0.5611208727642331
# 400 0.010059079361811617 	Loss(validation) = 0.6344533053605408
# 500 0.004974481328987108 	Loss(validation) = 0.6458921739633996
# 600 0.0031378213662228665 	Loss(validation) = 0.6369222289984606
# 700 0.0022521830233023002 	Loss(validation) = 0.6291200719299554
# 800 0.0017154104248027198 	Loss(validation) = 0.6255726612699885
# 900 0.0013378490441778297 	Loss(validation) = 0.627523585927758
# 1000 0.0010501056569385552 	Loss(validation) = 0.6350339598365996
# 1100 0.0008244389777155515 	Loss(validation) = 0.6455153647819117
# 1200 0.0006461166930605676 	Loss(validation) = 0.6566906848600432
# 1300 0.0005042511349512128 	Loss(validation) = 0.6679156003280251
# 1400 0.00039080638176539073 	Loss(validation) = 0.6787832643704602
# 1500 0.0003011692668737143 	Loss(validation) = 0.6894328439945105
# 1600 0.00023172015518980264 	Loss(validation) = 0.6996697611656787
# 1700 0.00017946752821089684 	Loss(validation) = 0.7091967647885768
# 1800 0.00014077584962023527 	Loss(validation) = 0.7179786029716251
# 1900 0.00011253279916154232 	Loss(validation) = 0.7257880975414552
# 2000 9.174849440377796e-05 	Loss(validation) = 0.7327606690140821
# 2100 7.631170456231299e-05 	Loss(validation) = 0.7386646977059125
# 2200 6.468663603402307e-05 	Loss(validation) = 0.7439663868726714
# 2300 5.8206763856371416e-05 	Loss(validation) = 0.7486245325837587
# 2400 4.847824902893994e-05 	Loss(validation) = 0.7527406371689336
# 2500 4.279064284228769e-05 	Loss(validation) = 0.7561180733734787
# 2600 3.874453488059451e-05 	Loss(validation) = 0.7583359173310266
# 2700 3.628760047752035e-05 	Loss(validation) = 0.7612630605742607
# 2800 3.1089405481496775e-05 	Loss(validation) = 0.7643052082313112
# 2900 2.9115794758191622e-05 	Loss(validation) = 0.7655466502200825
# 3000 2.596782843467454e-05 	Loss(validation) = 0.7683590735196694
# 3100 2.3928081534984112e-05 	Loss(validation) = 0.7700503065550788
# 3200 2.216930808684058e-05 	Loss(validation) = 0.7716251289251809
# 3300 2.0641944388240072e-05 	Loss(validation) = 0.7726590271538769
# 3400 1.9214241766385594e-05 	Loss(validation) = 0.7740567936729565
# 3500 1.796671014146989e-05 	Loss(validation) = 0.774907208545879
# 3600 1.6846413492440653e-05 	Loss(validation) = 0.775790450625856
# 3700 1.6081550750310653e-05 	Loss(validation) = 0.7765684415905496
# 3800 1.6066288908605974e-05 	Loss(validation) = 0.7758470916338154
# 3900 1.4055963318728545e-05 	Loss(validation) = 0.7775667887771135
# 4000 1.3278546928710872e-05 	Loss(validation) = 0.7779160578405386
# 4100 1.736563540474835e-05 	Loss(validation) = 0.7800569262213696
# 4200 1.1914943637591253e-05 	Loss(validation) = 0.7786387322374153
# 4300 1.1280423011744333e-05 	Loss(validation) = 0.7787281772776115
# 4400 1.1164019324819314e-05 	Loss(validation) = 0.7781138757694364
# 4500 1.0167001603167778e-05 	Loss(validation) = 0.7789053397407683
# 4600 9.769659645818128e-06 	Loss(validation) = 0.7791843094920888
# 4700 9.194518012740447e-06 	Loss(validation) = 0.7790267743917192
# 4800 8.758995559381912e-06 	Loss(validation) = 0.7789874152469118
# 4900 8.445156059392336e-06 	Loss(validation) = 0.7787960553866163
# 5000 1.520022530518887e-05 	Loss(validation) = 0.7761357682087467
# 5100 7.5896788893694e-06 	Loss(validation) = 0.7787906937432135
# 5200 7.2538819154687335e-06 	Loss(validation) = 0.7786634273160477
# 5300 8.908868158303744e-06 	Loss(validation) = 0.7771606739326355
# 5400 7.053378470955533e-06 	Loss(validation) = 0.7789048598089984
# 5500 6.337010631432093e-06 	Loss(validation) = 0.7783951521826563
# 5600 6.131693918934396e-06 	Loss(validation) = 0.7778331309295138
# 5700 6.0613075578879015e-06 	Loss(validation) = 0.7785302227392366
# 5800 5.5749239720947795e-06 	Loss(validation) = 0.7781253313413651
# 5900 5.553331221993346e-06 	Loss(validation) = 0.7777361561570552
# 6000 5.137735543819467e-06 	Loss(validation) = 0.777960559044735
# 6100 4.941943918521217e-06 	Loss(validation) = 0.7778748451422001
# 6200 4.7515831403797314e-06 	Loss(validation) = 0.7778607347811027
# 6300 4.577057586276735e-06 	Loss(validation) = 0.7777541595544145
# 6400 5.392958881041563e-06 	Loss(validation) = 0.7771367982666286
# 6500 4.248458460725735e-06 	Loss(validation) = 0.7776768544883892
# 6600 4.105363680925596e-06 	Loss(validation) = 0.7775930172864007
# 6700 5.536521047200576e-06 	Loss(validation) = 0.7785017507665845
# 6800 4.945624633314016e-06 	Loss(validation) = 0.7786694910352473
# 6900 3.7047497268646703e-06 	Loss(validation) = 0.7776397084514596
# 7000 4.866582217464369e-06 	Loss(validation) = 0.7771428959169634
# 7100 3.479671527392428e-06 	Loss(validation) = 0.777620282788353
# 7200 1.077785020894809e-05 	Loss(validation) = 0.7766506179736712
# 7300 3.5188552687261578e-06 	Loss(validation) = 0.7772733203451696
# 7400 3.1877496203117157e-06 	Loss(validation) = 0.7778582348971086
# 7500 3.197531473043367e-06 	Loss(validation) = 0.7780330801808651
# 7600 3.1825801392118987e-06 	Loss(validation) = 0.7775330838917666
# 7700 2.95458620167803e-06 	Loss(validation) = 0.7779099109586144
# 7800 2.873688475616929e-06 	Loss(validation) = 0.7780380617564499
# 7900 4.272445695762722e-06 	Loss(validation) = 0.7781881496554198
# 8000 2.7446005202376666e-06 	Loss(validation) = 0.778222385072573
# 8100 3.0568889358654547e-06 	Loss(validation) = 0.7786797584017324
# 8200 2.861208166121295e-06 	Loss(validation) = 0.7788701183117872
# 8300 2.5802123302160454e-06 	Loss(validation) = 0.7785152739198674
# 8400 5.330580781972184e-06 	Loss(validation) = 0.7782392811817239
# 8500 2.672885713110489e-06 	Loss(validation) = 0.7791573286292856
# 8600 2.4678410860319938e-06 	Loss(validation) = 0.7790737902340942
# 8700 2.4761286750471677e-06 	Loss(validation) = 0.778915934622862
# 8800 2.4175810006809934e-06 	Loss(validation) = 0.7789251562243232
# 8900 2.326920878291386e-06 	Loss(validation) = 0.7792954776824343
# 9000 2.303412111145836e-06 	Loss(validation) = 0.7794374236934329
# 9100 2.5971799226606036e-06 	Loss(validation) = 0.7795585051118221
# 9200 2.2288421565340096e-06 	Loss(validation) = 0.7797032335981353
# 9300 2.208415083220551e-06 	Loss(validation) = 0.7797932922564794
# 9400 2.530062125460694e-06 	Loss(validation) = 0.7802657174464392
# 9500 2.1454768337229894e-06 	Loss(validation) = 0.7801138057601439
# 9600 2.1502429713542193e-06 	Loss(validation) = 0.7803682552821727
# 9700 4.509575567530038e-06 	Loss(validation) = 0.778802650459676
# 9800 2.2204812186598336e-06 	Loss(validation) = 0.7807033188236745
# 9900 2.9747425627602448e-06 	Loss(validation) = 0.7811083677982429
# Assembling residuals...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 6.53221e-13; step 1
# scipy solver converged in 2 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 2.55058e-10; step 1
# scipy solver converged in 2 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 1.07431e-05; step 1
# 1:  |F(x)| = 4.05261e-07; step 1
# scipy solver converged in 3 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 1.0743e-05; step 1
# 1:  |F(x)| = 4.05259e-07; step 1
# scipy solver converged in 3 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 2.29129e-05; step 1
# 1:  |F(x)| = 9.46552e-07; step 1
# scipy solver converged in 3 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 2.29131e-05; step 1
# 1:  |F(x)| = 9.46561e-07; step 1
# scipy solver converged in 3 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 4.18849e-05; step 1
# 1:  |F(x)| = 1.6325e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 4.18846e-05; step 1
# 1:  |F(x)| = 1.63249e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 6.74768e-05; step 1
# 1:  |F(x)| = 2.46836e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 6.74765e-05; step 1
# 1:  |F(x)| = 2.46835e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.000101101; step 1
# 1:  |F(x)| = 3.45592e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.000101101; step 1
# 1:  |F(x)| = 3.45593e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.000144338; step 1
# 1:  |F(x)| = 4.59346e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.000144338; step 1
# 1:  |F(x)| = 4.59343e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.000198944; step 1
# 1:  |F(x)| = 5.87585e-06; step 1
# scipy solver converged in 3 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.000266844; step 1
# 1:  |F(x)| = 7.29468e-06; step 1
# 2:  |F(x)| = 1.36745e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.000266842; step 1
# 1:  |F(x)| = 7.29464e-06; step 1
# 2:  |F(x)| = 1.36744e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00035014; step 1
# 1:  |F(x)| = 8.8384e-06; step 1
# 2:  |F(x)| = 1.73608e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.000350138; step 1
# 1:  |F(x)| = 8.83836e-06; step 1
# 2:  |F(x)| = 1.73607e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.000451099; step 1
# 1:  |F(x)| = 1.04925e-05; step 1
# 2:  |F(x)| = 2.15341e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.000451099; step 1
# 1:  |F(x)| = 1.04925e-05; step 1
# 2:  |F(x)| = 2.15341e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.000572162; step 1
# 1:  |F(x)| = 1.22399e-05; step 1
# 2:  |F(x)| = 2.61733e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.000572164; step 1
# 1:  |F(x)| = 1.22399e-05; step 1
# 2:  |F(x)| = 2.61734e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.000715927; step 1
# 1:  |F(x)| = 1.40607e-05; step 1
# 2:  |F(x)| = 3.71856e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.000715924; step 1
# 1:  |F(x)| = 1.40607e-05; step 1
# 2:  |F(x)| = 3.71854e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.000885151; step 1
# 1:  |F(x)| = 1.59329e-05; step 1
# 2:  |F(x)| = 6.21035e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.000885152; step 1
# 1:  |F(x)| = 1.59329e-05; step 1
# 2:  |F(x)| = 6.21036e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00108274; step 1
# 1:  |F(x)| = 1.7832e-05; step 1
# 2:  |F(x)| = 9.63716e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00108274; step 1
# 1:  |F(x)| = 1.7832e-05; step 1
# 2:  |F(x)| = 9.6372e-07; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00131175; step 1
# 1:  |F(x)| = 2.00664e-05; step 1
# 2:  |F(x)| = 1.42293e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00131174; step 1
# 1:  |F(x)| = 2.00664e-05; step 1
# 2:  |F(x)| = 1.42292e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00157535; step 1
# 1:  |F(x)| = 2.44688e-05; step 1
# 2:  |F(x)| = 2.02551e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00157535; step 1
# 1:  |F(x)| = 2.44689e-05; step 1
# 2:  |F(x)| = 2.02551e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00187686; step 1
# 1:  |F(x)| = 2.96414e-05; step 1
# 2:  |F(x)| = 2.80249e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00187686; step 1
# 1:  |F(x)| = 2.96415e-05; step 1
# 2:  |F(x)| = 2.80251e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00221969; step 1
# 1:  |F(x)| = 3.56896e-05; step 1
# 2:  |F(x)| = 3.78952e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0022197; step 1
# 1:  |F(x)| = 3.56898e-05; step 1
# 2:  |F(x)| = 3.78955e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00260737; step 1
# 1:  |F(x)| = 4.27287e-05; step 1
# 2:  |F(x)| = 5.0273e-06; step 1
# scipy solver converged in 4 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00304351; step 1
# 1:  |F(x)| = 5.0884e-05; step 1
# 2:  |F(x)| = 6.56208e-06; step 1
# 3:  |F(x)| = 2.45475e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0030435; step 1
# 1:  |F(x)| = 5.08837e-05; step 1
# 2:  |F(x)| = 6.56203e-06; step 1
# 3:  |F(x)| = 2.45474e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00353183; step 1
# 1:  |F(x)| = 6.02908e-05; step 1
# 2:  |F(x)| = 8.4461e-06; step 1
# 3:  |F(x)| = 2.71748e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00353182; step 1
# 1:  |F(x)| = 6.02907e-05; step 1
# 2:  |F(x)| = 8.44608e-06; step 1
# 3:  |F(x)| = 2.71748e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00407608; step 1
# 1:  |F(x)| = 7.10949e-05; step 1
# 2:  |F(x)| = 1.07381e-05; step 1
# 3:  |F(x)| = 2.95817e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00407609; step 1
# 1:  |F(x)| = 7.1095e-05; step 1
# 2:  |F(x)| = 1.07381e-05; step 1
# 3:  |F(x)| = 2.95817e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00468011; step 1
# 1:  |F(x)| = 8.34524e-05; step 1
# 2:  |F(x)| = 1.35038e-05; step 1
# 3:  |F(x)| = 3.63147e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00468012; step 1
# 1:  |F(x)| = 8.34526e-05; step 1
# 2:  |F(x)| = 1.35039e-05; step 1
# 3:  |F(x)| = 3.63148e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00534778; step 1
# 1:  |F(x)| = 9.75298e-05; step 1
# 2:  |F(x)| = 1.68165e-05; step 1
# 3:  |F(x)| = 4.56011e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00534777; step 1
# 1:  |F(x)| = 9.75295e-05; step 1
# 2:  |F(x)| = 1.68165e-05; step 1
# 3:  |F(x)| = 4.5601e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00608303; step 1
# 1:  |F(x)| = 0.000113504; step 1
# 2:  |F(x)| = 2.07575e-05; step 1
# 3:  |F(x)| = 5.67818e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00608304; step 1
# 1:  |F(x)| = 0.000113504; step 1
# 2:  |F(x)| = 2.07576e-05; step 1
# 3:  |F(x)| = 5.67819e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0068898; step 1
# 1:  |F(x)| = 0.000131562; step 1
# 2:  |F(x)| = 2.54169e-05; step 1
# 3:  |F(x)| = 7.0154e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00688978; step 1
# 1:  |F(x)| = 0.000131561; step 1
# 2:  |F(x)| = 2.54168e-05; step 1
# 3:  |F(x)| = 7.01536e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00777206; step 1
# 1:  |F(x)| = 0.000151901; step 1
# 2:  |F(x)| = 3.08936e-05; step 1
# 3:  |F(x)| = 8.60478e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00777205; step 1
# 1:  |F(x)| = 0.000151901; step 1
# 2:  |F(x)| = 3.08936e-05; step 1
# 3:  |F(x)| = 8.60477e-07; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00873377; step 1
# 1:  |F(x)| = 0.000174729; step 1
# 2:  |F(x)| = 3.72965e-05; step 1
# 3:  |F(x)| = 1.04829e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.00977892; step 1
# 1:  |F(x)| = 0.000200263; step 1
# 2:  |F(x)| = 4.47447e-05; step 1
# 3:  |F(x)| = 1.269e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.00977894; step 1
# 1:  |F(x)| = 0.000200263; step 1
# 2:  |F(x)| = 4.47449e-05; step 1
# 3:  |F(x)| = 1.269e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0109115; step 1
# 1:  |F(x)| = 0.000228729; step 1
# 2:  |F(x)| = 5.33681e-05; step 1
# 3:  |F(x)| = 1.52702e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0109114; step 1
# 1:  |F(x)| = 0.000228729; step 1
# 2:  |F(x)| = 5.3368e-05; step 1
# 3:  |F(x)| = 1.52702e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0121353; step 1
# 1:  |F(x)| = 0.000260366; step 1
# 2:  |F(x)| = 6.3308e-05; step 1
# 3:  |F(x)| = 1.82719e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0121353; step 1
# 1:  |F(x)| = 0.000260366; step 1
# 2:  |F(x)| = 6.33081e-05; step 1
# 3:  |F(x)| = 1.8272e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0134544; step 1
# 1:  |F(x)| = 0.000295416; step 1
# 2:  |F(x)| = 7.47175e-05; step 1
# 3:  |F(x)| = 2.17477e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0134544; step 1
# 1:  |F(x)| = 0.000295416; step 1
# 2:  |F(x)| = 7.47173e-05; step 1
# 3:  |F(x)| = 2.17477e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0148727; step 1
# 1:  |F(x)| = 0.000334137; step 1
# 2:  |F(x)| = 8.77624e-05; step 1
# 3:  |F(x)| = 2.57547e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0148727; step 1
# 1:  |F(x)| = 0.000334137; step 1
# 2:  |F(x)| = 8.77622e-05; step 1
# 3:  |F(x)| = 2.57546e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0163939; step 1
# 1:  |F(x)| = 0.00037679; step 1
# 2:  |F(x)| = 0.000102621; step 1
# 3:  |F(x)| = 3.03545e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0163939; step 1
# 1:  |F(x)| = 0.000376791; step 1
# 2:  |F(x)| = 0.000102621; step 1
# 3:  |F(x)| = 3.03545e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0180218; step 1
# 1:  |F(x)| = 0.000423648; step 1
# 2:  |F(x)| = 0.000119486; step 1
# 3:  |F(x)| = 3.56135e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0180219; step 1
# 1:  |F(x)| = 0.000423649; step 1
# 2:  |F(x)| = 0.000119487; step 1
# 3:  |F(x)| = 3.56136e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0197603; step 1
# 1:  |F(x)| = 0.000474989; step 1
# 2:  |F(x)| = 0.000138563; step 1
# 3:  |F(x)| = 4.16031e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0197603; step 1
# 1:  |F(x)| = 0.000474989; step 1
# 2:  |F(x)| = 0.000138563; step 1
# 3:  |F(x)| = 4.1603e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0216128; step 1
# 1:  |F(x)| = 0.000531101; step 1
# 2:  |F(x)| = 0.000160074; step 1
# 3:  |F(x)| = 4.83996e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0216129; step 1
# 1:  |F(x)| = 0.000531102; step 1
# 2:  |F(x)| = 0.000160074; step 1
# 3:  |F(x)| = 4.83997e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0235832; step 1
# 1:  |F(x)| = 0.000592278; step 1
# 2:  |F(x)| = 0.000184252; step 1
# 3:  |F(x)| = 5.60843e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0235831; step 1
# 1:  |F(x)| = 0.000592277; step 1
# 2:  |F(x)| = 0.000184252; step 1
# 3:  |F(x)| = 5.60841e-06; step 1
# scipy solver converged in 5 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0256748; step 1
# 1:  |F(x)| = 0.000658822; step 1
# 2:  |F(x)| = 0.00021135; step 1
# 3:  |F(x)| = 6.47439e-06; step 1
# 4:  |F(x)| = 3.13803e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0256748; step 1
# 1:  |F(x)| = 0.000658822; step 1
# 2:  |F(x)| = 0.00021135; step 1
# 3:  |F(x)| = 6.47438e-06; step 1
# 4:  |F(x)| = 3.13803e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0278911; step 1
# 1:  |F(x)| = 0.000731041; step 1
# 2:  |F(x)| = 0.000241635; step 1
# 3:  |F(x)| = 7.44698e-06; step 1
# 4:  |F(x)| = 3.70721e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0278912; step 1
# 1:  |F(x)| = 0.000731042; step 1
# 2:  |F(x)| = 0.000241635; step 1
# 3:  |F(x)| = 7.447e-06; step 1
# 4:  |F(x)| = 3.70722e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0302356; step 1
# 1:  |F(x)| = 0.000809247; step 1
# 2:  |F(x)| = 0.000275388; step 1
# 3:  |F(x)| = 8.53591e-06; step 1
# 4:  |F(x)| = 4.36137e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0302357; step 1
# 1:  |F(x)| = 0.00080925; step 1
# 2:  |F(x)| = 0.000275389; step 1
# 3:  |F(x)| = 8.53594e-06; step 1
# 4:  |F(x)| = 4.3614e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0327115; step 1
# 1:  |F(x)| = 0.000893761; step 1
# 2:  |F(x)| = 0.000312911; step 1
# 3:  |F(x)| = 9.75135e-06; step 1
# 4:  |F(x)| = 5.1105e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0353861; step 1
# 1:  |F(x)| = 0.000984908; step 1
# 2:  |F(x)| = 0.000354518; step 1
# 3:  |F(x)| = 1.1104e-05; step 1
# 4:  |F(x)| = 5.96538e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0353861; step 1
# 1:  |F(x)| = 0.000984909; step 1
# 2:  |F(x)| = 0.000354518; step 1
# 3:  |F(x)| = 1.1104e-05; step 1
# 4:  |F(x)| = 5.96539e-06; step 1
# scipy solver converged in 6 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0385228; step 1
# 1:  |F(x)| = 0.00108302; step 1
# 2:  |F(x)| = 0.000400544; step 1
# 3:  |F(x)| = 1.31027e-05; step 1
# 4:  |F(x)| = 6.93766e-06; step 1
# 5:  |F(x)| = 3.965e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0385228; step 1
# 1:  |F(x)| = 0.00108301; step 1
# 2:  |F(x)| = 0.000400543; step 1
# 3:  |F(x)| = 1.31026e-05; step 1
# 4:  |F(x)| = 6.93764e-06; step 1
# 5:  |F(x)| = 3.96498e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.041857; step 1
# 1:  |F(x)| = 0.00118842; step 1
# 2:  |F(x)| = 0.00045134; step 1
# 3:  |F(x)| = 1.59039e-05; step 1
# 4:  |F(x)| = 8.03987e-06; step 1
# 5:  |F(x)| = 4.96887e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0453959; step 1
# 1:  |F(x)| = 0.00130146; step 1
# 2:  |F(x)| = 0.000507275; step 1
# 3:  |F(x)| = 1.91724e-05; step 1
# 4:  |F(x)| = 9.28542e-06; step 1
# 5:  |F(x)| = 6.17948e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.045396; step 1
# 1:  |F(x)| = 0.00130146; step 1
# 2:  |F(x)| = 0.000507276; step 1
# 3:  |F(x)| = 1.91725e-05; step 1
# 4:  |F(x)| = 9.28544e-06; step 1
# 5:  |F(x)| = 6.17951e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0491467; step 1
# 1:  |F(x)| = 0.00142247; step 1
# 2:  |F(x)| = 0.000568734; step 1
# 3:  |F(x)| = 2.297e-05; step 1
# 4:  |F(x)| = 1.06886e-05; step 1
# 5:  |F(x)| = 7.63168e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0491467; step 1
# 1:  |F(x)| = 0.00142247; step 1
# 2:  |F(x)| = 0.000568733; step 1
# 3:  |F(x)| = 2.297e-05; step 1
# 4:  |F(x)| = 1.06886e-05; step 1
# 5:  |F(x)| = 7.63166e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0531168; step 1
# 1:  |F(x)| = 0.00155179; step 1
# 2:  |F(x)| = 0.000636124; step 1
# 3:  |F(x)| = 2.7365e-05; step 1
# 4:  |F(x)| = 1.22648e-05; step 1
# 5:  |F(x)| = 9.36499e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0531167; step 1
# 1:  |F(x)| = 0.00155179; step 1
# 2:  |F(x)| = 0.000636123; step 1
# 3:  |F(x)| = 2.7365e-05; step 1
# 4:  |F(x)| = 1.22648e-05; step 1
# 5:  |F(x)| = 9.36497e-07; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0573133; step 1
# 1:  |F(x)| = 0.00168979; step 1
# 2:  |F(x)| = 0.000709866; step 1
# 3:  |F(x)| = 3.24323e-05; step 1
# 4:  |F(x)| = 1.403e-05; step 1
# 5:  |F(x)| = 1.14241e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0573133; step 1
# 1:  |F(x)| = 0.00168979; step 1
# 2:  |F(x)| = 0.000709867; step 1
# 3:  |F(x)| = 3.24324e-05; step 1
# 4:  |F(x)| = 1.40301e-05; step 1
# 5:  |F(x)| = 1.14241e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0617436; step 1
# 1:  |F(x)| = 0.00183678; step 1
# 2:  |F(x)| = 0.000790402; step 1
# 3:  |F(x)| = 3.82539e-05; step 1
# 4:  |F(x)| = 1.60015e-05; step 1
# 5:  |F(x)| = 1.38593e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0617435; step 1
# 1:  |F(x)| = 0.00183678; step 1
# 2:  |F(x)| = 0.000790401; step 1
# 3:  |F(x)| = 3.82538e-05; step 1
# 4:  |F(x)| = 1.60015e-05; step 1
# 5:  |F(x)| = 1.38593e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.066415; step 1
# 1:  |F(x)| = 0.00199314; step 1
# 2:  |F(x)| = 0.000878191; step 1
# 3:  |F(x)| = 4.49195e-05; step 1
# 4:  |F(x)| = 1.81973e-05; step 1
# 5:  |F(x)| = 1.67272e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0664151; step 1
# 1:  |F(x)| = 0.00199314; step 1
# 2:  |F(x)| = 0.000878192; step 1
# 3:  |F(x)| = 4.49196e-05; step 1
# 4:  |F(x)| = 1.81973e-05; step 1
# 5:  |F(x)| = 1.67272e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.071335; step 1
# 1:  |F(x)| = 0.00215921; step 1
# 2:  |F(x)| = 0.000973712; step 1
# 3:  |F(x)| = 5.25272e-05; step 1
# 4:  |F(x)| = 2.06363e-05; step 1
# 5:  |F(x)| = 2.0091e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.071335; step 1
# 1:  |F(x)| = 0.00215921; step 1
# 2:  |F(x)| = 0.000973713; step 1
# 3:  |F(x)| = 5.25273e-05; step 1
# 4:  |F(x)| = 2.06363e-05; step 1
# 5:  |F(x)| = 2.0091e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0765107; step 1
# 1:  |F(x)| = 0.00233533; step 1
# 2:  |F(x)| = 0.00107746; step 1
# 3:  |F(x)| = 6.11834e-05; step 1
# 4:  |F(x)| = 2.33384e-05; step 1
# 5:  |F(x)| = 2.40212e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0765106; step 1
# 1:  |F(x)| = 0.00233533; step 1
# 2:  |F(x)| = 0.00107746; step 1
# 3:  |F(x)| = 6.11832e-05; step 1
# 4:  |F(x)| = 2.33384e-05; step 1
# 5:  |F(x)| = 2.40211e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0819497; step 1
# 1:  |F(x)| = 0.00252186; step 1
# 2:  |F(x)| = 0.00118995; step 1
# 3:  |F(x)| = 7.10037e-05; step 1
# 4:  |F(x)| = 2.63244e-05; step 1
# 5:  |F(x)| = 2.85963e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0876591; step 1
# 1:  |F(x)| = 0.00271913; step 1
# 2:  |F(x)| = 0.00131171; step 1
# 3:  |F(x)| = 8.21133e-05; step 1
# 4:  |F(x)| = 2.96156e-05; step 1
# 5:  |F(x)| = 3.39033e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0876592; step 1
# 1:  |F(x)| = 0.00271914; step 1
# 2:  |F(x)| = 0.00131171; step 1
# 3:  |F(x)| = 8.21135e-05; step 1
# 4:  |F(x)| = 2.96157e-05; step 1
# 5:  |F(x)| = 3.39034e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0936464; step 1
# 1:  |F(x)| = 0.0029275; step 1
# 2:  |F(x)| = 0.0014433; step 1
# 3:  |F(x)| = 9.46475e-05; step 1
# 4:  |F(x)| = 3.32346e-05; step 1
# 5:  |F(x)| = 4.00383e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.0936464; step 1
# 1:  |F(x)| = 0.0029275; step 1
# 2:  |F(x)| = 0.00144329; step 1
# 3:  |F(x)| = 9.46474e-05; step 1
# 4:  |F(x)| = 3.32345e-05; step 1
# 5:  |F(x)| = 4.00382e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.0999189; step 1
# 1:  |F(x)| = 0.00315296; step 1
# 2:  |F(x)| = 0.00158527; step 1
# 3:  |F(x)| = 0.000108752; step 1
# 4:  |F(x)| = 3.72042e-05; step 1
# 5:  |F(x)| = 4.71074e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.106484; step 1
# 1:  |F(x)| = 0.003405; step 1
# 2:  |F(x)| = 0.00173823; step 1
# 3:  |F(x)| = 0.000124585; step 1
# 4:  |F(x)| = 4.15482e-05; step 1
# 5:  |F(x)| = 5.52272e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.106484; step 1
# 1:  |F(x)| = 0.003405; step 1
# 2:  |F(x)| = 0.00173823; step 1
# 3:  |F(x)| = 0.000124585; step 1
# 4:  |F(x)| = 4.15483e-05; step 1
# 5:  |F(x)| = 5.52273e-06; step 1
# scipy solver converged in 7 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.113349; step 1
# 1:  |F(x)| = 0.00367219; step 1
# 2:  |F(x)| = 0.00190276; step 1
# 3:  |F(x)| = 0.000142315; step 1
# 4:  |F(x)| = 4.62909e-05; step 1
# 5:  |F(x)| = 6.45255e-06; step 1
# 6:  |F(x)| = 1.49206e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.113349; step 1
# 1:  |F(x)| = 0.00367218; step 1
# 2:  |F(x)| = 0.00190276; step 1
# 3:  |F(x)| = 0.000142314; step 1
# 4:  |F(x)| = 4.62909e-05; step 1
# 5:  |F(x)| = 6.45253e-06; step 1
# 6:  |F(x)| = 1.49206e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.120521; step 1
# 1:  |F(x)| = 0.00395509; step 1
# 2:  |F(x)| = 0.0020795; step 1
# 3:  |F(x)| = 0.000162122; step 1
# 4:  |F(x)| = 5.1457e-05; step 1
# 5:  |F(x)| = 7.51422e-06; step 1
# 6:  |F(x)| = 1.67878e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.120521; step 1
# 1:  |F(x)| = 0.00395509; step 1
# 2:  |F(x)| = 0.0020795; step 1
# 3:  |F(x)| = 0.000162122; step 1
# 4:  |F(x)| = 5.14571e-05; step 1
# 5:  |F(x)| = 7.51422e-06; step 1
# 6:  |F(x)| = 1.67878e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.128007; step 1
# 1:  |F(x)| = 0.00425429; step 1
# 2:  |F(x)| = 0.00226907; step 1
# 3:  |F(x)| = 0.0001842; step 1
# 4:  |F(x)| = 5.70717e-05; step 1
# 5:  |F(x)| = 8.72298e-06; step 1
# 6:  |F(x)| = 1.88277e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.128007; step 1
# 1:  |F(x)| = 0.00425428; step 1
# 2:  |F(x)| = 0.00226906; step 1
# 3:  |F(x)| = 0.0001842; step 1
# 4:  |F(x)| = 5.70716e-05; step 1
# 5:  |F(x)| = 8.72295e-06; step 1
# 6:  |F(x)| = 1.88277e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.135815; step 1
# 1:  |F(x)| = 0.00457037; step 1
# 2:  |F(x)| = 0.00247212; step 1
# 3:  |F(x)| = 0.000208758; step 1
# 4:  |F(x)| = 6.31604e-05; step 1
# 5:  |F(x)| = 1.00955e-05; step 1
# 6:  |F(x)| = 2.10479e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.135815; step 1
# 1:  |F(x)| = 0.00457036; step 1
# 2:  |F(x)| = 0.00247212; step 1
# 3:  |F(x)| = 0.000208757; step 1
# 4:  |F(x)| = 6.31602e-05; step 1
# 5:  |F(x)| = 1.00954e-05; step 1
# 6:  |F(x)| = 2.10478e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.143952; step 1
# 1:  |F(x)| = 0.00490391; step 1
# 2:  |F(x)| = 0.00268933; step 1
# 3:  |F(x)| = 0.000236014; step 1
# 4:  |F(x)| = 6.97485e-05; step 1
# 5:  |F(x)| = 1.16497e-05; step 1
# 6:  |F(x)| = 2.34549e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.143952; step 1
# 1:  |F(x)| = 0.00490391; step 1
# 2:  |F(x)| = 0.00268933; step 1
# 3:  |F(x)| = 0.000236014; step 1
# 4:  |F(x)| = 6.97485e-05; step 1
# 5:  |F(x)| = 1.16497e-05; step 1
# 6:  |F(x)| = 2.34549e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.152425; step 1
# 1:  |F(x)| = 0.0052555; step 1
# 2:  |F(x)| = 0.00292138; step 1
# 3:  |F(x)| = 0.000266206; step 1
# 4:  |F(x)| = 7.68617e-05; step 1
# 5:  |F(x)| = 1.34051e-05; step 1
# 6:  |F(x)| = 2.60544e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.152426; step 1
# 1:  |F(x)| = 0.00525551; step 1
# 2:  |F(x)| = 0.00292139; step 1
# 3:  |F(x)| = 0.000266206; step 1
# 4:  |F(x)| = 7.68619e-05; step 1
# 5:  |F(x)| = 1.34052e-05; step 1
# 6:  |F(x)| = 2.60545e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.161242; step 1
# 1:  |F(x)| = 0.00562574; step 1
# 2:  |F(x)| = 0.00316897; step 1
# 3:  |F(x)| = 0.000299582; step 1
# 4:  |F(x)| = 8.45255e-05; step 1
# 5:  |F(x)| = 1.5383e-05; step 1
# 6:  |F(x)| = 2.88507e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.161242; step 1
# 1:  |F(x)| = 0.00562573; step 1
# 2:  |F(x)| = 0.00316896; step 1
# 3:  |F(x)| = 0.000299581; step 1
# 4:  |F(x)| = 8.45254e-05; step 1
# 5:  |F(x)| = 1.5383e-05; step 1
# 6:  |F(x)| = 2.88507e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.170408; step 1
# 1:  |F(x)| = 0.0060152; step 1
# 2:  |F(x)| = 0.0034328; step 1
# 3:  |F(x)| = 0.000336408; step 1
# 4:  |F(x)| = 9.27649e-05; step 1
# 5:  |F(x)| = 1.7606e-05; step 1
# 6:  |F(x)| = 3.18461e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.170408; step 1
# 1:  |F(x)| = 0.00601521; step 1
# 2:  |F(x)| = 0.0034328; step 1
# 3:  |F(x)| = 0.000336408; step 1
# 4:  |F(x)| = 9.2765e-05; step 1
# 5:  |F(x)| = 1.76061e-05; step 1
# 6:  |F(x)| = 3.18462e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.179932; step 1
# 1:  |F(x)| = 0.00642449; step 1
# 2:  |F(x)| = 0.0037136; step 1
# 3:  |F(x)| = 0.000376965; step 1
# 4:  |F(x)| = 0.000101605; step 1
# 5:  |F(x)| = 2.00987e-05; step 1
# 6:  |F(x)| = 3.50413e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.179932; step 1
# 1:  |F(x)| = 0.00642448; step 1
# 2:  |F(x)| = 0.00371359; step 1
# 3:  |F(x)| = 0.000376963; step 1
# 4:  |F(x)| = 0.000101604; step 1
# 5:  |F(x)| = 2.00987e-05; step 1
# 6:  |F(x)| = 3.50412e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.189821; step 1
# 1:  |F(x)| = 0.0068542; step 1
# 2:  |F(x)| = 0.00401211; step 1
# 3:  |F(x)| = 0.00042155; step 1
# 4:  |F(x)| = 0.000111069; step 1
# 5:  |F(x)| = 2.28874e-05; step 1
# 6:  |F(x)| = 3.84346e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.18982; step 1
# 1:  |F(x)| = 0.00685419; step 1
# 2:  |F(x)| = 0.00401211; step 1
# 3:  |F(x)| = 0.00042155; step 1
# 4:  |F(x)| = 0.000111069; step 1
# 5:  |F(x)| = 2.28874e-05; step 1
# 6:  |F(x)| = 3.84346e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.200081; step 1
# 1:  |F(x)| = 0.00730492; step 1
# 2:  |F(x)| = 0.00432908; step 1
# 3:  |F(x)| = 0.000470479; step 1
# 4:  |F(x)| = 0.00012118; step 1
# 5:  |F(x)| = 2.60003e-05; step 1
# 6:  |F(x)| = 4.20215e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.200081; step 1
# 1:  |F(x)| = 0.00730492; step 1
# 2:  |F(x)| = 0.00432909; step 1
# 3:  |F(x)| = 0.000470479; step 1
# 4:  |F(x)| = 0.00012118; step 1
# 5:  |F(x)| = 2.60003e-05; step 1
# 6:  |F(x)| = 4.20216e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.210719; step 1
# 1:  |F(x)| = 0.00777724; step 1
# 2:  |F(x)| = 0.00466528; step 1
# 3:  |F(x)| = 0.000524082; step 1
# 4:  |F(x)| = 0.000131961; step 1
# 5:  |F(x)| = 2.94675e-05; step 1
# 6:  |F(x)| = 4.57946e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.210719; step 1
# 1:  |F(x)| = 0.00777725; step 1
# 2:  |F(x)| = 0.00466529; step 1
# 3:  |F(x)| = 0.000524084; step 1
# 4:  |F(x)| = 0.000131961; step 1
# 5:  |F(x)| = 2.94676e-05; step 1
# 6:  |F(x)| = 4.57948e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.221743; step 1
# 1:  |F(x)| = 0.00827175; step 1
# 2:  |F(x)| = 0.00502146; step 1
# 3:  |F(x)| = 0.000582709; step 1
# 4:  |F(x)| = 0.000143432; step 1
# 5:  |F(x)| = 3.33212e-05; step 1
# 6:  |F(x)| = 4.9743e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.233159; step 1
# 1:  |F(x)| = 0.00878904; step 1
# 2:  |F(x)| = 0.00539842; step 1
# 3:  |F(x)| = 0.000646728; step 1
# 4:  |F(x)| = 0.000155612; step 1
# 5:  |F(x)| = 3.75957e-05; step 1
# 6:  |F(x)| = 5.38519e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.233159; step 1
# 1:  |F(x)| = 0.00878904; step 1
# 2:  |F(x)| = 0.00539842; step 1
# 3:  |F(x)| = 0.000646728; step 1
# 4:  |F(x)| = 0.000155612; step 1
# 5:  |F(x)| = 3.75957e-05; step 1
# 6:  |F(x)| = 5.38519e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.244974; step 1
# 1:  |F(x)| = 0.0093297; step 1
# 2:  |F(x)| = 0.00579695; step 1
# 3:  |F(x)| = 0.000716525; step 1
# 4:  |F(x)| = 0.000168519; step 1
# 5:  |F(x)| = 4.23274e-05; step 1
# 6:  |F(x)| = 5.81018e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.244973; step 1
# 1:  |F(x)| = 0.00932968; step 1
# 2:  |F(x)| = 0.00579694; step 1
# 3:  |F(x)| = 0.000716523; step 1
# 4:  |F(x)| = 0.000168519; step 1
# 5:  |F(x)| = 4.23273e-05; step 1
# 6:  |F(x)| = 5.81017e-06; step 1
# scipy solver converged in 8 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.257195; step 1
# 1:  |F(x)| = 0.0098943; step 1
# 2:  |F(x)| = 0.00621783; step 1
# 3:  |F(x)| = 0.000792504; step 1
# 4:  |F(x)| = 0.000182168; step 1
# 5:  |F(x)| = 4.75551e-05; step 1
# 6:  |F(x)| = 6.24689e-06; step 1
# 7:  |F(x)| = 3.08529e-06; step 1
# scipy solver converged in 9 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.257195; step 1
# 1:  |F(x)| = 0.0098943; step 1
# 2:  |F(x)| = 0.00621783; step 1
# 3:  |F(x)| = 0.000792504; step 1
# 4:  |F(x)| = 0.000182168; step 1
# 5:  |F(x)| = 4.75551e-05; step 1
# 6:  |F(x)| = 6.24688e-06; step 1
# 7:  |F(x)| = 3.08529e-06; step 1
# scipy solver converged in 9 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.269828; step 1
# 1:  |F(x)| = 0.0104834; step 1
# 2:  |F(x)| = 0.00666189; step 1
# 3:  |F(x)| = 0.000875091; step 1
# 4:  |F(x)| = 0.000196572; step 1
# 5:  |F(x)| = 5.33197e-05; step 1
# 6:  |F(x)| = 6.69233e-06; step 1
# 7:  |F(x)| = 3.50429e-06; step 1
# scipy solver converged in 9 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.269828; step 1
# 1:  |F(x)| = 0.0104834; step 1
# 2:  |F(x)| = 0.0066619; step 1
# 3:  |F(x)| = 0.000875092; step 1
# 4:  |F(x)| = 0.000196572; step 1
# 5:  |F(x)| = 5.33198e-05; step 1
# 6:  |F(x)| = 6.69233e-06; step 1
# 7:  |F(x)| = 3.5043e-06; step 1
# scipy solver converged in 9 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.282881; step 1
# 1:  |F(x)| = 0.0110977; step 1
# 2:  |F(x)| = 0.00712994; step 1
# 3:  |F(x)| = 0.00096473; step 1
# 4:  |F(x)| = 0.000211741; step 1
# 5:  |F(x)| = 5.96646e-05; step 1
# 6:  |F(x)| = 7.14295e-06; step 1
# 7:  |F(x)| = 3.97084e-06; step 1
# scipy solver converged in 9 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.282881; step 1
# 1:  |F(x)| = 0.0110976; step 1
# 2:  |F(x)| = 0.00712993; step 1
# 3:  |F(x)| = 0.000964729; step 1
# 4:  |F(x)| = 0.000211741; step 1
# 5:  |F(x)| = 5.96644e-05; step 1
# 6:  |F(x)| = 7.14294e-06; step 1
# 7:  |F(x)| = 3.97083e-06; step 1
# scipy solver converged in 9 iterations.
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 0.296359; step 1
# 1:  |F(x)| = 0.0117375; step 1
# 2:  |F(x)| = 0.00762278; step 1
# 3:  |F(x)| = 0.00106189; step 1
# 4:  |F(x)| = 0.000227683; step 1
# 5:  |F(x)| = 6.66353e-05; step 1
# 6:  |F(x)| = 7.59453e-06; step 1
# 7:  |F(x)| = 4.48918e-06; step 1
# scipy solver converged in 9 iterations.
# Operator 'dc' not implemented. Continuing without operator 'dc'...
# 0:  |F(x)| = 0.296359; step 1
# 1:  |F(x)| = 0.0117375; step 1
# 2:  |F(x)| = 0.00762277; step 1
# 3:  |F(x)| = 0.00106189; step 1
# 4:  |F(x)| = 0.000227683; step 1
# 5:  |F(x)| = 6.66352e-05; step 1
# 6:  |F(x)| = 7.59453e-06; step 1
# 7:  |F(x)| = 4.48918e-06; step 1
# ...
# 86300 0.0019445672602342663 	Loss(validation) = 0.38639738706038756
# 86400 0.0019441021663950057 	Loss(validation) = 0.3863641997676075
# 86500 0.0019436447646128028 	Loss(validation) = 0.38633198705085603
# 86600 0.0019431944538104758 	Loss(validation) = 0.3863007429353535
# 86700 0.0019427521466482993 	Loss(validation) = 0.3862700054325437
# 86800 0.001942314758188395 	Loss(validation) = 0.38623976051480396
# 86900 0.0019418847302669477 	Loss(validation) = 0.38621036768274636
# 87000 0.0019414613707599043 	Loss(validation) = 0.3861809014726077
# 87100 0.0019410456515251162 	Loss(validation) = 0.3861519036989348
# 87200 0.001940638940817402 	Loss(validation) = 0.3861234319368997
# 87300 0.0019402387874394799 	Loss(validation) = 0.3860953535825694
# 87400 0.0019398465850661286 	Loss(validation) = 0.38606718532746687
# 87500 0.0019394630334269628 	Loss(validation) = 0.3860394101691273
# 87600 0.001939084658475236 	Loss(validation) = 0.38601201894839937
# 87700 0.001938711783968574 	Loss(validation) = 0.3859846337058984
# 87800 0.001938345705582746 	Loss(validation) = 0.38595754122121195
# 87900 0.001937984329503787 	Loss(validation) = 0.38593090074954467
# 88000 0.0019376283555459562 	Loss(validation) = 0.38590497981911503
# 88100 0.001937277895587977 	Loss(validation) = 0.3858796144601384
# 88200 0.0019369332769703033 	Loss(validation) = 0.385854946651621
# 88300 0.0019365929507045145 	Loss(validation) = 0.38583079430355555
# 88400 0.0019362574553686877 	Loss(validation) = 0.385807140977936
# 88500 0.0019359272150576525 	Loss(validation) = 0.385784502104083
# 88600 0.0019356019570502044 	Loss(validation) = 0.38576254008975686
# 88700 0.0019352822759019397 	Loss(validation) = 0.38574065432572113
# 88800 0.0019349666732049377 	Loss(validation) = 0.3857194652536283
# 88900 0.0019346538577334088 	Loss(validation) = 0.3856992140781208
# 89000 0.0019343472345559672 	Loss(validation) = 0.38567999284257065
# 89100 0.0019340451919617743 	Loss(validation) = 0.38566199852841493
# 89200 0.0019337500169445815 	Loss(validation) = 0.3856439990034054
# 89300 0.0019334596522564546 	Loss(validation) = 0.38562615751830714
# 89400 0.0019331738304963256 	Loss(validation) = 0.3856089922976674
# 89500 0.0019328899218318072 	Loss(validation) = 0.3855926009645252
# 89600 0.0019326105250406433 	Loss(validation) = 0.3855768967816239
# 89700 0.001932335186214046 	Loss(validation) = 0.3855618087735358
# 89800 0.001932062349233949 	Loss(validation) = 0.38554700471393305
# 89900 0.0019317954809615883 	Loss(validation) = 0.3855324953529482
# 90000 0.003536950555742084 	Loss(validation) = 0.38403856695243116
# 90100 0.0035247661399136995 	Loss(validation) = 0.38321387756801817
# 90200 0.0035157918650942747 	Loss(validation) = 0.3825883214029055
# 90300 0.0035084132256470754 	Loss(validation) = 0.38206926182333273
# 90400 0.003502112885254978 	Loss(validation) = 0.3816173394597377
# 90500 0.0034965106831322964 	Loss(validation) = 0.3812121852853561
# 90600 0.003491446776528377 	Loss(validation) = 0.38084186570038914
# 90700 0.0034867824495005313 	Loss(validation) = 0.38049897137032834
# 90800 0.0034824435605358204 	Loss(validation) = 0.38017847717845743
# 90900 0.003478377197274304 	Loss(validation) = 0.3798767917221832
# 91000 0.0034745414695301824 	Loss(validation) = 0.3795924854270036
# 91100 0.003470894714109271 	Loss(validation) = 0.379321106260494
# 91200 0.0034674051194826033 	Loss(validation) = 0.3790617601669562
# 91300 0.0034640538381565432 	Loss(validation) = 0.3788126590608191
# 91400 0.003460830593738097 	Loss(validation) = 0.378572988724537
# 91500 0.003457716735428477 	Loss(validation) = 0.3783427295542471
# 91600 0.003454715113423575 	Loss(validation) = 0.37812011443187216
# 91700 0.003451814313092747 	Loss(validation) = 0.3779051017250243
# 91800 0.0034490049078947514 	Loss(validation) = 0.3776967669023436
# 91900 0.0034462821356611253 	Loss(validation) = 0.37749499295619665
# 92000 0.0034436441662747223 	Loss(validation) = 0.37729962056688027
# 92100 0.003441074543286448 	Loss(validation) = 0.37710923670177193
# 92200 0.0034385756928729905 	Loss(validation) = 0.3769238909853509
# 92300 0.003436134431066796 	Loss(validation) = 0.3767430661481232
# 92400 0.003433747768654777 	Loss(validation) = 0.376566481457393
# 92500 0.003431420332871813 	Loss(validation) = 0.3763945632427821
# 92600 0.0034291464461502314 	Loss(validation) = 0.3762269745369149
# 92700 0.0034269179657506962 	Loss(validation) = 0.37606348774485376
# 92800 0.003424730508074261 	Loss(validation) = 0.3759040382541654
# 92900 0.0034225822616515875 	Loss(validation) = 0.37574747599375385
# 93000 0.003420473658075056 	Loss(validation) = 0.3755943461842177
# 93100 0.003418410249747665 	Loss(validation) = 0.3754451110358017
# 93200 0.003416389920899213 	Loss(validation) = 0.3752990269028936
# 93300 0.003414405326012625 	Loss(validation) = 0.3751558903270921
# 93400 0.003412454191009894 	Loss(validation) = 0.3750155050426955
# 93500 0.003410537225440304 	Loss(validation) = 0.3748779145094389
# 93600 0.0034086525072918885 	Loss(validation) = 0.3747425382161538
# 93700 0.003406797417203202 	Loss(validation) = 0.3746097924417399
# 93800 0.003404973221618161 	Loss(validation) = 0.3744800611504259
# 93900 0.003403183285329897 	Loss(validation) = 0.3743526733816089
# 94000 0.003401428495988742 	Loss(validation) = 0.37422722115611085
# 94100 0.0033996982255594227 	Loss(validation) = 0.37410410015310064
# 94200 0.003397996079784217 	Loss(validation) = 0.3739832515827738
# 94300 0.0033963177528815677 	Loss(validation) = 0.37386452408570564
# 94400 0.003394665912637631 	Loss(validation) = 0.3737476420304282
# 94500 0.003393042704124901 	Loss(validation) = 0.3736333248766653
# 94600 0.0033914444852749335 	Loss(validation) = 0.37352131998644866
# 94700 0.0033898710619305033 	Loss(validation) = 0.37341149769724447
# 94800 0.0033883239138239474 	Loss(validation) = 0.373303630324666
# 94900 0.003386802429848548 	Loss(validation) = 0.3731975690765189
# 95000 0.003385309051181432 	Loss(validation) = 0.37309362858371675
# 95100 0.003383837914977871 	Loss(validation) = 0.3729918558525252
# 95200 0.0033823884095377857 	Loss(validation) = 0.37289147752029106
# 95300 0.0033809605449174945 	Loss(validation) = 0.37279281686120164
# 95400 0.0033795528659026205 	Loss(validation) = 0.37269590870131775
# 95500 0.003378162763598821 	Loss(validation) = 0.3726007467814349
# 95600 0.0033767932368481044 	Loss(validation) = 0.3725071582163424
# 95700 0.0033754445020289475 	Loss(validation) = 0.3724151583273439
# 95800 0.003374111000568007 	Loss(validation) = 0.37232408539115514
# 95900 0.003372800218258744 	Loss(validation) = 0.37223403747807204
# 96000 0.00337150925788409 	Loss(validation) = 0.37214532692077273
# 96100 0.0033702361000117593 	Loss(validation) = 0.37205822298281227
# 96200 0.003368984420971257 	Loss(validation) = 0.37197276629689946
# 96300 0.0033677560861220092 	Loss(validation) = 0.3718886677473246
# 96400 0.0033665445732879704 	Loss(validation) = 0.37180544196082077
# 96500 0.003365352350260866 	Loss(validation) = 0.3717231440569382
# 96600 0.003364175975064926 	Loss(validation) = 0.3716418212651826
# 96700 0.003363011626994954 	Loss(validation) = 0.3715614601119846
# 96800 0.003361856329464748 	Loss(validation) = 0.3714819197547232
# 96900 0.0033607106431667623 	Loss(validation) = 0.371403224682387
# 97000 0.003359575672954834 	Loss(validation) = 0.37132528330227216
# 97100 0.003358450911915908 	Loss(validation) = 0.37124827204143973
# 97200 0.003357336818030489 	Loss(validation) = 0.3711722246262722
# 97300 0.0033562399078624645 	Loss(validation) = 0.3710967734077546
# 97400 0.0033551653012818382 	Loss(validation) = 0.3710213516546123
# 97500 0.003354106041863376 	Loss(validation) = 0.37094665826747514
# 97600 0.003353057961551708 	Loss(validation) = 0.37087289390777395
# 97700 0.0033520215802798382 	Loss(validation) = 0.37079984682596573
# 97800 0.003350996255956208 	Loss(validation) = 0.37072789433452197
# 97900 0.003349982098678598 	Loss(validation) = 0.3706571847243032
# 98000 0.003348977973789801 	Loss(validation) = 0.3705872226560516
# 98100 0.003347987635729391 	Loss(validation) = 0.37051825044537867
# 98200 0.003347013183760518 	Loss(validation) = 0.3704503760345085
# 98300 0.003346052168831898 	Loss(validation) = 0.3703830800649693
# 98400 0.0033451041490066462 	Loss(validation) = 0.37031644350734666
# 98500 0.0033441702575091703 	Loss(validation) = 0.37025087612067625
# 98600 0.0033432452354491236 	Loss(validation) = 0.37018629664510433
# 98700 0.0033423288770085217 	Loss(validation) = 0.37012222255092475
# 98800 0.0033414220435678795 	Loss(validation) = 0.3700591395042015
# 98900 0.0033405293418063906 	Loss(validation) = 0.3699972806832371
# 99000 0.003339648609229861 	Loss(validation) = 0.36993644246634366
# 99100 0.003338776426547586 	Loss(validation) = 0.36987633661339797
# 99200 0.0033379144949798423 	Loss(validation) = 0.3698166754228317
# 99300 0.0033370626356317252 	Loss(validation) = 0.36975785821228513
# 99400 0.0033362184650816387 	Loss(validation) = 0.3696999525948735
# 99500 0.00333538388848279 	Loss(validation) = 0.369642757986378
# 99600 0.003334558789523048 	Loss(validation) = 0.36958630894294686
# 99700 0.00333374449485304 	Loss(validation) = 0.3695307214725478
# 99800 0.0033329495165611268 	Loss(validation) = 0.36947596668498056
# 99900 0.0033321684265563557 	Loss(validation) = 0.369422082580601
# 100000 0.0034226221768594626 	Loss(validation) = 0.369419951407458
# 100100 0.0034208672283523324 	Loss(validation) = 0.3693886793077842
# 100200 0.0034193600983656726 	Loss(validation) = 0.36935205640975055
# 100300 0.0034179877430451644 	Loss(validation) = 0.3693134119007247
# 100400 0.003416706958055309 	Loss(validation) = 0.36927364866799944
# 100500 0.0034154912714969795 	Loss(validation) = 0.36923333216063553
# 100600 0.003414334434051873 	Loss(validation) = 0.3691927750659356
# 100700 0.003413225802197996 	Loss(validation) = 0.36915288003748903
# 100800 0.00341215842519165 	Loss(validation) = 0.3691136161778766
# 100900 0.003411124557988672 	Loss(validation) = 0.36907459572040385
# 101000 0.0034101259216338456 	Loss(validation) = 0.3690360627722663
# 101100 0.003409156234733285 	Loss(validation) = 0.3689981576225622
# 101200 0.0034082065280369163 	Loss(validation) = 0.3689612463237965
# 101300 0.0034072744215520845 	Loss(validation) = 0.3689243823978808
# 101400 0.0034063669357653516 	Loss(validation) = 0.36888802304900187
# 101500 0.00340547392335029 	Loss(validation) = 0.36885171523899746
# 101600 0.003404595836980888 	Loss(validation) = 0.3688157236109301
# 101700 0.0034037340184076914 	Loss(validation) = 0.36878054115481285
# 101800 0.003402883723118609 	Loss(validation) = 0.3687463293032343
# 101900 0.003402046997463181 	Loss(validation) = 0.36871277930131774
# 102000 0.0034012323884240717 	Loss(validation) = 0.3686798265055163
# 102100 0.003400431967418005 	Loss(validation) = 0.3686471613170619
# 102200 0.0033996442034619047 	Loss(validation) = 0.3686151945303296
# 102300 0.0033988651677886936 	Loss(validation) = 0.36858368270968594
# 102400 0.003398098479086223 	Loss(validation) = 0.368552204162965
# 102500 0.0033973395002340765 	Loss(validation) = 0.3685211203722711
# 102600 0.0033965873315140974 	Loss(validation) = 0.3684904410420086
# 102700 0.0033958438047281434 	Loss(validation) = 0.3684603745129908
# 102800 0.003395116139715058 	Loss(validation) = 0.36843100149067826
# 102900 0.0033943978385867508 	Loss(validation) = 0.3684018669193651
# 103000 0.003393688973416611 	Loss(validation) = 0.36837289945147633
# 103100 0.003392986110278704 	Loss(validation) = 0.36834420943340473
# 103200 0.0033922887161145837 	Loss(validation) = 0.36831551916295613
# 103300 0.0033915985702646437 	Loss(validation) = 0.36828700241814993
# 103400 0.0033909156062535725 	Loss(validation) = 0.36825877324413736
# 103500 0.003390236561766699 	Loss(validation) = 0.3682306449963502
# 103600 0.003389562897683081 	Loss(validation) = 0.3682027770507288
# 103700 0.003388894029961081 	Loss(validation) = 0.36817505748073004
# 103800 0.0033882307419248383 	Loss(validation) = 0.36814735230780066
# 103900 0.0033875752309067268 	Loss(validation) = 0.36811988901898035
# 104000 0.003386934398084719 	Loss(validation) = 0.36809271474232114
# 104100 0.003386311229738193 	Loss(validation) = 0.3680655804790688
# 104200 0.0033857032726149847 	Loss(validation) = 0.36803846505703985
# 104300 0.003385102027887471 	Loss(validation) = 0.3680112609332725
# 104400 0.0033845086924245795 	Loss(validation) = 0.36798411592307945
# 104500 0.0033839211524145916 	Loss(validation) = 0.36795720746511584
# 104600 0.0033833381082811064 	Loss(validation) = 0.3679303142678801
# 104700 0.003382759767902801 	Loss(validation) = 0.36790367198090856
# 104800 0.0033821857169030983 	Loss(validation) = 0.3678771537800228
# 104900 0.0033816157626769313 	Loss(validation) = 0.36785087734815863
# 105000 0.0033810495349920785 	Loss(validation) = 0.3678248017432897
# 105100 0.003380487444809892 	Loss(validation) = 0.3677988200985687
# 105200 0.003379936014508159 	Loss(validation) = 0.3677734107755098
# 105300 0.0033793942241321048 	Loss(validation) = 0.367748335469371
# 105400 0.0033788611226834653 	Loss(validation) = 0.36772364559973053
# 105500 0.0033783354079470287 	Loss(validation) = 0.36769915517894014
# 105600 0.0033778154498280625 	Loss(validation) = 0.36767496843388625
# 105700 0.0033772983518327478 	Loss(validation) = 0.3676509870255739
# 105800 0.003376785394501225 	Loss(validation) = 0.3676270964912847
# 105900 0.003376276153074171 	Loss(validation) = 0.3676033773645251
# 106000 0.00337577040323324 	Loss(validation) = 0.36757992364163744
# 106100 0.003375268441391621 	Loss(validation) = 0.36755682419050106
# 106200 0.003374769765611114 	Loss(validation) = 0.3675339774258515
# 106300 0.003374274734168971 	Loss(validation) = 0.36751117174622144
# 106400 0.003373781803895946 	Loss(validation) = 0.3674884514406604
# 106500 0.003373292930375095 	Loss(validation) = 0.3674657141639158
# 106600 0.003372811594127226 	Loss(validation) = 0.36744338594968345
# 106700 0.003372332874886549 	Loss(validation) = 0.36742149925400014
# 106800 0.003371865158989785 	Loss(validation) = 0.3674001444328446
# 106900 0.0033714121930280842 	Loss(validation) = 0.36737968659706094
# 107000 0.003370978307192756 	Loss(validation) = 0.36735987535799786
# 107100 0.0033705543872934274 	Loss(validation) = 0.36734038395183577
# 107200 0.0033701364161345263 	Loss(validation) = 0.36732105836310447
# 107300 0.0033697238171999976 	Loss(validation) = 0.36730198462844466
# 107400 0.0033693131213455973 	Loss(validation) = 0.36728324751541724
# 107500 0.0033689038194332937 	Loss(validation) = 0.3672646081470454
# 107600 0.0033684970504455603 	Loss(validation) = 0.3672460794566843
# 107700 0.003368093771682069 	Loss(validation) = 0.36722773728549707
# 107800 0.003367694459394012 	Loss(validation) = 0.3672095400623258
# 107900 0.003367298898627381 	Loss(validation) = 0.3671914515371519
# 108000 0.0033669047746965374 	Loss(validation) = 0.3671735224869474
# 108100 0.003366513716365477 	Loss(validation) = 0.36715564940118467
# 108200 0.00336612282942538 	Loss(validation) = 0.3671378860218702
# 108300 0.003365735116528638 	Loss(validation) = 0.36712030210238905
# 108400 0.003365348515883129 	Loss(validation) = 0.36710288063984087
# 108500 0.0033649640314141168 	Loss(validation) = 0.3670855307537984
# 108600 0.0033645828500788173 	Loss(validation) = 0.36706833392439675
# 108700 0.003364214880642427 	Loss(validation) = 0.36705189744470207
# 108800 0.0033638595016284665 	Loss(validation) = 0.3670360808303047
# 108900 0.003363510569883059 	Loss(validation) = 0.36702041795726004
# 109000 0.0033631655145548427 	Loss(validation) = 0.36700482041618204
# 109100 0.0033628230834348407 	Loss(validation) = 0.36698921536222595
# 109200 0.0033624818025849395 	Loss(validation) = 0.36697360767877873
# 109300 0.0033621415839363298 	Loss(validation) = 0.3669580406390216
# 109400 0.0033618027770977396 	Loss(validation) = 0.36694243918229713
# 109500 0.003361465476853974 	Loss(validation) = 0.36692686156500476
# 109600 0.003361129326018153 	Loss(validation) = 0.36691130220072976
# 109700 0.0033607951884284896 	Loss(validation) = 0.36689584540835074
# 109800 0.003360465089395354 	Loss(validation) = 0.3668806405864975
# 109900 0.003360139259425352 	Loss(validation) = 0.36686571761588727

# %%
fig, ax = Training.plot_loss(pdnn_trainer, pdnn_net)

# %% [markdown]
# #### 4.5.3 Train PRNN

# %%
input_normalization_prnn = Normalization.MinMaxNormalization(input_normalization=True)
output_normalization_prnn = Normalization.MinMaxNormalization()

omega = 1.
prnn_net  = NN.RONN(f"PRNN_{omega}", problem, reduction_method, n_hidden=2, n_neurons=60)
prnn_loss = Losses.PRNN_Loss(prnn_net, output_normalization_prnn, omega=omega)
data      = RONNData.RONNDataLoader(prnn_net, validation_proportion=0.2,
                                    num_without_snapshots=225)
optimizer = torch.optim.Adam(prnn_net.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.99999)

prnn_trainer = Training.PRNNTrainer(
    prnn_net, data, prnn_loss, optimizer, scheduler,
    input_normalization_prnn, num_epochs=110000
)

loaded, starting_epoch = IO.initialize_parameters(
    prnn_net, data, prnn_trainer, optimizer
)

# %%
prnn_trainer.train()
# Out:
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 234.576; step 0.358402
# 1:  |F(x)| = 125.615; step 1
# 2:  |F(x)| = 49.2163; step 1
# 3:  |F(x)| = 37.0405; step 1
# 4:  |F(x)| = 27.3224; step 1
# 5:  |F(x)| = 6.70208; step 1
# 6:  |F(x)| = 4.07486; step 0.433509
# 7:  |F(x)| = 4.04412; step 0.024388
# 8:  |F(x)| = 4.03194; step 0.01
# 9:  |F(x)| = 8.53649; step 1
# 10:  |F(x)| = 9.01796; step 1
# 11:  |F(x)| = 3.9374; step 1
# 12:  |F(x)| = 1.47068; step 1
# 13:  |F(x)| = 1.62166; step 1
# 14:  |F(x)| = 1.33624; step 1
# 15:  |F(x)| = 0.585479; step 1
# 16:  |F(x)| = 0.186083; step 1
# 17:  |F(x)| = 0.413167; step 1
# 18:  |F(x)| = 0.351023; step 1
# 19:  |F(x)| = 0.127233; step 1
# 20:  |F(x)| = 0.0604585; step 1
# 21:  |F(x)| = 0.0584507; step 0.396029
# 22:  |F(x)| = 0.0653172; step 0.486879
# 23:  |F(x)| = 0.0666867; step 1
# 24:  |F(x)| = 0.0332032; step 1
# 25:  |F(x)| = 0.00967637; step 1
# 26:  |F(x)| = 0.0100634; step 0.515615
# 27:  |F(x)| = 0.0126753; step 1
# 28:  |F(x)| = 0.0087681; step 1
# 29:  |F(x)| = 0.00211353; step 1
# 30:  |F(x)| = 0.00227382; step 1
# 31:  |F(x)| = 0.00240526; step 0.131941
# 32:  |F(x)| = 0.00260693; step 0.281414
# 33:  |F(x)| = 0.0027897; step 1
# 34:  |F(x)| = 0.00152439; step 1
# 35:  |F(x)| = 0.000412615; step 1
# 36:  |F(x)| = 0.000468219; step 1
# 37:  |F(x)| = 0.000523111; step 1
# 38:  |F(x)| = 0.000271803; step 1
# 39:  |F(x)| = 7.46258e-05; step 1
# 40:  |F(x)| = 6.94718e-05; step 0.413268
# 41:  |F(x)| = 7.16266e-05; step 0.321919
# 42:  |F(x)| = 7.89118e-05; step 0.443674
# 43:  |F(x)| = 8.66234e-05; step 1
# 44:  |F(x)| = 4.42375e-05; step 1
# 45:  |F(x)| = 1.14687e-05; step 1
# 46:  |F(x)| = 9.52992e-06; step 0.266057
# 47:  |F(x)| = 9.82768e-06; step 0.0998817
# 48:  |F(x)| = 9.92878e-06; step 0.0471804
# 49:  |F(x)| = 9.97373e-06; step 0.0252261
# 50:  |F(x)| = 9.99681e-06; step 0.0144494
# 51:  |F(x)| = 1.00118e-05; step 0.01
# 52:  |F(x)| = 1.97871e-05; step 1
# 53:  |F(x)| = 1.57992e-05; step 1
# 54:  |F(x)| = 6.29465e-06; step 1
# 55:  |F(x)| = 2.78891e-06; step 1
# scipy solver converged in 57 iterations.
# 0:  |F(x)| = 230.395; step 0.361359
# 1:  |F(x)| = 121.268; step 1
# 2:  |F(x)| = 48.1963; step 1
# 3:  |F(x)| = 35.9443; step 1
# 4:  |F(x)| = 26.3824; step 1
# 5:  |F(x)| = 6.52715; step 1
# 6:  |F(x)| = 4.06109; step 0.426776
# 7:  |F(x)| = 4.0349; step 0.0200238
# 8:  |F(x)| = 4.02217; step 0.01
# 9:  |F(x)| = 8.38741; step 1
# 10:  |F(x)| = 8.81264; step 1
# 11:  |F(x)| = 3.79628; step 1
# 12:  |F(x)| = 1.45006; step 1
# 13:  |F(x)| = 1.60714; step 1
# 14:  |F(x)| = 1.30501; step 1
# 15:  |F(x)| = 0.56104; step 1
# 16:  |F(x)| = 0.190838; step 1
# 17:  |F(x)| = 0.406398; step 1
# 18:  |F(x)| = 0.339699; step 1
# 19:  |F(x)| = 0.119587; step 1
# 20:  |F(x)| = 0.0597929; step 1
# 21:  |F(x)| = 0.0575065; step 0.387554
# 22:  |F(x)| = 0.0655886; step 0.502839
# 23:  |F(x)| = 0.0647379; step 1
# 24:  |F(x)| = 0.0312286; step 1
# 25:  |F(x)| = 0.00923396; step 1
# 26:  |F(x)| = 0.00998356; step 0.500719
# 27:  |F(x)| = 0.0125071; step 1
# 28:  |F(x)| = 0.0084581; step 1
# 29:  |F(x)| = 0.00199256; step 1
# 30:  |F(x)| = 0.00133299; step 0.50473
# 31:  |F(x)| = 0.0011407; step 0.180242
# 32:  |F(x)| = 0.00113843; step 0.0831804
# 33:  |F(x)| = 0.00115633; step 0.0442753
# 34:  |F(x)| = 0.00116543; step 0.0255187
# 35:  |F(x)| = 0.00117051; step 0.0154093
# 36:  |F(x)| = 0.00117366; step 0.01
# 37:  |F(x)| = 0.0011767; step 0.01
# 38:  |F(x)| = 0.0026592; step 1
# 39:  |F(x)| = 0.00213363; step 1
# 40:  |F(x)| = 0.00085797; step 1
# 41:  |F(x)| = 0.000361371; step 1
# 42:  |F(x)| = 0.000362972; step 0.45475
# 43:  |F(x)| = 0.000448419; step 1
# 44:  |F(x)| = 0.000279479; step 1
# 45:  |F(x)| = 7.87328e-05; step 1
# 46:  |F(x)| = 7.57267e-05; step 1
# 47:  |F(x)| = 9.55162e-05; step 1
# 48:  |F(x)| = 5.39106e-05; step 1
# 49:  |F(x)| = 1.33745e-05; step 1
# 50:  |F(x)| = 9.8504e-06; step 0.379574
# 51:  |F(x)| = 1.01203e-05; step 0.136259
# 52:  |F(x)| = 1.02692e-05; step 0.0653448
# 53:  |F(x)| = 1.03344e-05; step 0.0370552
# 54:  |F(x)| = 1.03688e-05; step 0.0232028
# 55:  |F(x)| = 1.03891e-05; step 0.0154767
# 56:  |F(x)| = 1.04021e-05; step 0.0107619
# 57:  |F(x)| = 2.01175e-05; step 1
# 58:  |F(x)| = 1.57094e-05; step 1
# 59:  |F(x)| = 6.01943e-06; step 1
# scipy solver converged in 61 iterations.
# 0:  |F(x)| = 153.819; step 0.426295
# 1:  |F(x)| = 53.0785; step 1
# 2:  |F(x)| = 31.7433; step 1
# 3:  |F(x)| = 18.3846; step 1
# 4:  |F(x)| = 11.2105; step 1
# 5:  |F(x)| = 3.98446; step 1
# 6:  |F(x)| = 3.75802; step 0.231869
# 7:  |F(x)| = 3.89025; step 0.0588061
# 8:  |F(x)| = 3.95869; step 0.0331703
# 9:  |F(x)| = 4.00241; step 0.0223233
# 10:  |F(x)| = 4.03388; step 0.0166591
# 11:  |F(x)| = 4.05844; step 0.0133729
# 12:  |F(x)| = 4.0788; step 0.0113473
# 13:  |F(x)| = 4.09655; step 0.0100857
# 14:  |F(x)| = 4.11383; step 0.01
# 15:  |F(x)| = 4.13079; step 0.01
# 16:  |F(x)| = 4.14745; step 0.01
# 17:  |F(x)| = 4.1638; step 0.01
# 18:  |F(x)| = 4.17984; step 0.01
# 19:  |F(x)| = 4.19741; step 0.0111681
# 20:  |F(x)| = 4.21739; step 0.0129848
# 21:  |F(x)| = 4.24108; step 0.0158076
# 22:  |F(x)| = 4.27059; step 0.0203484
# 23:  |F(x)| = 4.3096; step 0.0280995
# 24:  |F(x)| = 4.36515; step 0.0426509
# 25:  |F(x)| = 4.45251; step 0.0744556
# 26:  |F(x)| = 4.60831; step 0.164121
# 27:  |F(x)| = 5.02327; step 1
# 28:  |F(x)| = 3.16108; step 1
# 29:  |F(x)| = 0.829784; step 1
# 30:  |F(x)| = 0.845554; step 1
# 31:  |F(x)| = 0.863751; step 1
# 32:  |F(x)| = 0.373012; step 1
# 33:  |F(x)| = 0.108507; step 1
# 34:  |F(x)| = 0.10746; step 0.218793
# 35:  |F(x)| = 0.110057; step 0.151614
# 36:  |F(x)| = 0.121118; step 0.145677
# 37:  |F(x)| = 0.136013; step 0.189961
# 38:  |F(x)| = 0.15379; step 0.360267
# 39:  |F(x)| = 0.15674; step 1
# 40:  |F(x)| = 0.0729106; step 1
# 41:  |F(x)| = 0.0194931; step 1
# 42:  |F(x)| = 0.0190663; step 0.261379
# 43:  |F(x)| = 0.0194304; step 0.184767
# 44:  |F(x)| = 0.0197133; step 0.184207
# 45:  |F(x)| = 0.0228239; step 0.25782
# 46:  |F(x)| = 0.0288273; step 1
# 47:  |F(x)| = 0.0162971; step 1
# 48:  |F(x)| = 0.00477705; step 1
# 49:  |F(x)| = 0.0047106; step 1
# 50:  |F(x)| = 0.00495666; step 1
# 51:  |F(x)| = 0.00214316; step 1
# 52:  |F(x)| = 0.000581031; step 1
# 53:  |F(x)| = 0.000582478; step 0.0935861
# 54:  |F(x)| = 0.000593801; step 0.0594599
# 55:  |F(x)| = 0.000600475; step 0.0424655
# 56:  |F(x)| = 0.000617711; step 0.0330145
# 57:  |F(x)| = 0.000637229; step 0.0274317
# 58:  |F(x)| = 0.000653652; step 0.0240902
# 59:  |F(x)| = 0.000668229; step 0.0222156
# 60:  |F(x)| = 0.000681793; step 0.0214299
# 61:  |F(x)| = 0.000694984; step 0.0215919
# 62:  |F(x)| = 0.000708376; step 0.0227323
# 63:  |F(x)| = 0.000722574; step 0.0250597
# 64:  |F(x)| = 0.000738329; step 0.0290662
# 65:  |F(x)| = 0.000756713; step 0.0357502
# 66:  |F(x)| = 0.000779429; step 0.0472517
# 67:  |F(x)| = 0.000809472; step 0.0686307
# 68:  |F(x)| = 0.000852542; step 0.114054
# 69:  |F(x)| = 0.000919054; step 0.234786
# 70:  |F(x)| = 0.0010266; step 1
# 71:  |F(x)| = 0.000539466; step 1
# 72:  |F(x)| = 0.000140532; step 1
# 73:  |F(x)| = 0.000124566; step 0.434841
# 74:  |F(x)| = 0.00012627; step 0.333684
# 75:  |F(x)| = 0.000139574; step 0.459528
# 76:  |F(x)| = 0.00014794; step 1
# 77:  |F(x)| = 7.05227e-05; step 1
# 78:  |F(x)| = 1.99882e-05; step 1
# 79:  |F(x)| = 2.10314e-05; step 0.412427
# 80:  |F(x)| = 2.13011e-05; step 0.461093
# 81:  |F(x)| = 2.49711e-05; step 1
# 82:  |F(x)| = 1.20997e-05; step 1
# 83:  |F(x)| = 3.05887e-06; step 1
# scipy solver converged in 85 iterations.
# 0:  |F(x)| = 15.8242; step 1
# 1:  |F(x)| = 3.38945; step 1
# 2:  |F(x)| = 0.925161; step 1
# 3:  |F(x)| = 1.08305; step 1
# 4:  |F(x)| = 0.588231; step 1
# 5:  |F(x)| = 0.0875678; step 1
# 6:  |F(x)| = 0.0855622; step 1
# 7:  |F(x)| = 0.0497915; step 1
# 8:  |F(x)| = 0.00841417; step 1
# 9:  |F(x)| = 0.0121422; step 1
# 10:  |F(x)| = 0.00535244; step 1
# 11:  |F(x)| = 0.00101539; step 1
# 12:  |F(x)| = 0.00110529; step 0.395128
# 13:  |F(x)| = 0.00131165; step 1
# 14:  |F(x)| = 0.000373587; step 1
# 15:  |F(x)| = 0.000127984; step 1
# 16:  |F(x)| = 0.000140609; step 1
# 17:  |F(x)| = 2.99558e-05; step 1
# 18:  |F(x)| = 2.13783e-05; step 1
# 19:  |F(x)| = 1.71905e-05; step 1
# 20:  |F(x)| = 2.64182e-06; step 1
# scipy solver converged in 22 iterations.
# 0:  |F(x)| = 177.17; step 0.403975
# 1:  |F(x)| = 71.4161; step 1
# 2:  |F(x)| = 36.3911; step 1
# 3:  |F(x)| = 23.2162; step 1
# 4:  |F(x)| = 15.3924; step 1
# 5:  |F(x)| = 4.64547; step 1
# 6:  |F(x)| = 3.71133; step 0.303076
# 7:  |F(x)| = 3.67374; step 0.0225007
# 8:  |F(x)| = 3.65745; step 0.01
# 9:  |F(x)| = 6.55043; step 1
# 10:  |F(x)| = 6.06864; step 1
# 11:  |F(x)| = 2.04777; step 1
# 12:  |F(x)| = 1.15427; step 1
# 13:  |F(x)| = 1.31444; step 1
# 14:  |F(x)| = 0.852559; step 1
# 15:  |F(x)| = 0.256187; step 1
# 16:  |F(x)| = 0.23568; step 1
# 17:  |F(x)| = 0.257537; step 0.32453
# 18:  |F(x)| = 0.266316; step 1
# 19:  |F(x)| = 0.138208; step 1
# 20:  |F(x)| = 0.0349248; step 1
# 21:  |F(x)| = 0.0313579; step 0.320233
# 22:  |F(x)| = 0.032575; step 0.22061
# 23:  |F(x)| = 0.0326336; step 0.21794
# 24:  |F(x)| = 0.0377051; step 0.31274
# 25:  |F(x)| = 0.0455026; step 1
# 26:  |F(x)| = 0.0254068; step 1
# 27:  |F(x)| = 0.00721974; step 1
# 28:  |F(x)| = 0.00786175; step 1
# 29:  |F(x)| = 0.00828772; step 1
# 30:  |F(x)| = 0.00373851; step 1
# 31:  |F(x)| = 0.0010138; step 1
# 32:  |F(x)| = 0.000987381; step 0.149737
# 33:  |F(x)| = 0.00101346; step 0.0920948
# 34:  |F(x)| = 0.00102712; step 0.0674851
# 35:  |F(x)| = 0.00103549; step 0.0563911
# 36:  |F(x)| = 0.00108396; step 0.0526312
# 37:  |F(x)| = 0.00113633; step 0.054483
# 38:  |F(x)| = 0.00119127; step 0.062772
# 39:  |F(x)| = 0.00125509; step 0.0817682
# 40:  |F(x)| = 0.00133771; step 0.124639
# 41:  |F(x)| = 0.00145605; step 0.23907
# 42:  |F(x)| = 0.00166156; step 1
# 43:  |F(x)| = 0.000902595; step 1
# 44:  |F(x)| = 0.000235863; step 1
# 45:  |F(x)| = 0.000204581; step 0.477248
# 46:  |F(x)| = 0.000207697; step 0.35935
# 47:  |F(x)| = 0.000228087; step 0.498446
# 48:  |F(x)| = 0.000233134; step 1
# 49:  |F(x)| = 0.000109299; step 1
# 50:  |F(x)| = 3.1346e-05; step 1
# 51:  |F(x)| = 3.36756e-05; step 0.382466
# 52:  |F(x)| = 3.34696e-05; step 0.4052
# 53:  |F(x)| = 4.28544e-05; step 1
# 54:  |F(x)| = 2.30641e-05; step 1
# 55:  |F(x)| = 5.68508e-06; step 1
# scipy solver converged in 57 iterations.
# 0:  |F(x)| = 5.36559; step 1
# 1:  |F(x)| = 0.758645; step 1
# 2:  |F(x)| = 0.308527; step 1
# 3:  |F(x)| = 0.269124; step 1
# 4:  |F(x)| = 0.0595549; step 1
# 5:  |F(x)| = 0.017008; step 1
# 6:  |F(x)| = 0.014132; step 1
# 7:  |F(x)| = 0.0017594; step 1
# 8:  |F(x)| = 0.00211319; step 1
# 9:  |F(x)| = 0.000866656; step 1
# 10:  |F(x)| = 0.000127382; step 1
# 11:  |F(x)| = 0.000192723; step 1
# 12:  |F(x)| = 4.7753e-05; step 1
# 13:  |F(x)| = 1.70836e-05; step 1
# 14:  |F(x)| = 1.36163e-05; step 1
# 15:  |F(x)| = 1.43766e-06; step 1
# scipy solver converged in 17 iterations.
# 0:  |F(x)| = 250.328; step 0.347689
# 1:  |F(x)| = 142.543; step 1
# 2:  |F(x)| = 53.2063; step 1
# 3:  |F(x)| = 41.2892; step 1
# 4:  |F(x)| = 30.955; step 1
# 5:  |F(x)| = 7.40133; step 1
# 6:  |F(x)| = 4.10891; step 0.455712
# 7:  |F(x)| = 4.06091; step 0.0452401
# 8:  |F(x)| = 4.04857; step 0.0124791
# 9:  |F(x)| = 9.10552; step 1
# 10:  |F(x)| = 9.76283; step 1
# 11:  |F(x)| = 4.45944; step 1
# 12:  |F(x)| = 1.63103; step 1
# 13:  |F(x)| = 1.66487; step 1
# 14:  |F(x)| = 1.44478; step 1
# 15:  |F(x)| = 0.67139; step 1
# 16:  |F(x)| = 0.174768; step 1
# 17:  |F(x)| = 0.437285; step 1
# 18:  |F(x)| = 0.392154; step 1
# 19:  |F(x)| = 0.155858; step 1
# 20:  |F(x)| = 0.0626362; step 1
# 21:  |F(x)| = 0.0617765; step 0.438085
# 22:  |F(x)| = 0.0648549; step 0.46009
# 23:  |F(x)| = 0.0721265; step 1
# 24:  |F(x)| = 0.0387351; step 1
# 25:  |F(x)| = 0.0114411; step 1
# 26:  |F(x)| = 0.0127612; step 1
# 27:  |F(x)| = 0.0135122; step 1
# 28:  |F(x)| = 0.00654064; step 1
# 29:  |F(x)| = 0.00170815; step 1
# 30:  |F(x)| = 0.00148189; step 0.166547
# 31:  |F(x)| = 0.00153179; step 0.0802919
# 32:  |F(x)| = 0.00155394; step 0.0442501
# 33:  |F(x)| = 0.00156549; step 0.0263479
# 34:  |F(x)| = 0.00157211; step 0.016443
# 35:  |F(x)| = 0.00157614; step 0.010569
# 36:  |F(x)| = 0.00157982; step 0.01
# 37:  |F(x)| = 0.00345958; step 1
# 38:  |F(x)| = 0.00279784; step 1
# 39:  |F(x)| = 0.00114939; step 1
# 40:  |F(x)| = 0.000471842; step 1
# 41:  |F(x)| = 0.000476117; step 0.482781
# 42:  |F(x)| = 0.000575489; step 1
# 43:  |F(x)| = 0.000362313; step 1
# 44:  |F(x)| = 0.000101498; step 1
# 45:  |F(x)| = 9.59543e-05; step 1
# 46:  |F(x)| = 0.000124752; step 1
# 47:  |F(x)| = 7.3035e-05; step 1
# 48:  |F(x)| = 1.79622e-05; step 1
# 49:  |F(x)| = 1.27727e-05; step 0.434614
# 50:  |F(x)| = 1.33177e-05; step 0.167354
# 51:  |F(x)| = 1.35386e-05; step 0.0897188
# 52:  |F(x)| = 1.36329e-05; step 0.0594189
# 53:  |F(x)| = 1.36807e-05; step 0.0453845
# 54:  |F(x)| = 1.37067e-05; step 0.0386248
# 55:  |F(x)| = 1.37197e-05; step 0.0359909
# 56:  |F(x)| = 1.37228e-05; step 0.0364543
# 57:  |F(x)| = 1.37153e-05; step 0.0400781
# 58:  |F(x)| = 1.39644e-05; step 0.0480988
# 59:  |F(x)| = 1.46017e-05; step 0.0638637
# 60:  |F(x)| = 1.54578e-05; step 0.0961975
# 61:  |F(x)| = 1.67224e-05; step 0.172036
# 62:  |F(x)| = 1.8614e-05; step 0.39551
# 63:  |F(x)| = 1.82919e-05; step 1
# 64:  |F(x)| = 9.38953e-06; step 1
# 65:  |F(x)| = 2.69758e-06; step 1
# scipy solver converged in 67 iterations.
# 0:  |F(x)| = 112.983; step 0.472989
# 1:  |F(x)| = 28.8238; step 1
# 2:  |F(x)| = 24.0591; step 1
# 3:  |F(x)| = 11.404; step 1
# 4:  |F(x)| = 5.0095; step 1
# 5:  |F(x)| = 3.87349; step 1
# 6:  |F(x)| = 4.15373; step 0.317557
# 7:  |F(x)| = 4.25295; step 1
# 8:  |F(x)| = 2.49306; step 1
# 9:  |F(x)| = 0.589552; step 1
# 10:  |F(x)| = 0.548083; step 0.496815
# 11:  |F(x)| = 0.697649; step 1
# 12:  |F(x)| = 0.463843; step 1
# 13:  |F(x)| = 0.112213; step 1
# 14:  |F(x)| = 0.0734422; step 0.452224
# 15:  |F(x)| = 0.0619895; step 0.209085
# 16:  |F(x)| = 0.0656333; step 0.1404
# 17:  |F(x)| = 0.0749025; step 0.125449
# 18:  |F(x)| = 0.0834672; step 0.145544
# 19:  |F(x)| = 0.093275; step 0.227663
# 20:  |F(x)| = 0.114588; step 1
# 21:  |F(x)| = 0.0592768; step 1
# 22:  |F(x)| = 0.0144546; step 1
# 23:  |F(x)| = 0.0111998; step 0.290715
# 24:  |F(x)| = 0.0116763; step 0.164577
# 25:  |F(x)| = 0.0118601; step 0.127055
# 26:  |F(x)| = 0.0125645; step 0.125835
# 27:  |F(x)| = 0.0140036; step 0.159475
# 28:  |F(x)| = 0.0157291; step 0.272986
# 29:  |F(x)| = 0.0180365; step 1
# 30:  |F(x)| = 0.00920449; step 1
# 31:  |F(x)| = 0.002549; step 1
# 32:  |F(x)| = 0.00243593; step 0.523932
# 33:  |F(x)| = 0.00298759; step 1
# 34:  |F(x)| = 0.00178037; step 1
# 35:  |F(x)| = 0.000404195; step 1
# 36:  |F(x)| = 0.00030797; step 0.333681
# 37:  |F(x)| = 0.000272181; step 0.136598
# 38:  |F(x)| = 0.000255276; step 0.072086
# 39:  |F(x)| = 0.000273752; step 0.0440257
# 40:  |F(x)| = 0.000285335; step 0.0294622
# 41:  |F(x)| = 0.000293225; step 0.0209832
# 42:  |F(x)| = 0.00029891; step 0.0156166
# 43:  |F(x)| = 0.00030318; step 0.0120193
# 44:  |F(x)| = 0.000306666; step 0.01
# 45:  |F(x)| = 0.000310098; step 0.01
# 46:  |F(x)| = 0.000313474; step 0.01
# 47:  |F(x)| = 0.000645728; step 1
# 48:  |F(x)| = 0.000440881; step 1
# 49:  |F(x)| = 0.000114357; step 1
# 50:  |F(x)| = 9.08217e-05; step 1
# 51:  |F(x)| = 0.000124246; step 1
# 52:  |F(x)| = 6.76371e-05; step 1
# 53:  |F(x)| = 1.80383e-05; step 1
# 54:  |F(x)| = 1.47279e-05; step 0.459808
# 55:  |F(x)| = 1.51681e-05; step 0.393824
# 56:  |F(x)| = 1.99412e-05; step 1
# 57:  |F(x)| = 1.04896e-05; step 1
# 58:  |F(x)| = 2.51326e-06; step 1
# scipy solver converged in 60 iterations.
# 0:  |F(x)| = 7.4409e-05; step 1
# 1:  |F(x)| = 2.681e-06; step 1
# scipy solver converged in 3 iterations.
# 0:  |F(x)| = 85.4666; step 0.51237
# 1:  |F(x)| = 16.4258; step 1
# 2:  |F(x)| = 18.9989; step 1
# 3:  |F(x)| = 7.66702; step 1
# 4:  |F(x)| = 2.60928; step 1
# 5:  |F(x)| = 1.58664; step 0.439378
# 6:  |F(x)| = 1.42538; step 0.105752
# 7:  |F(x)| = 1.37051; step 0.0383983
# 8:  |F(x)| = 1.34907; step 0.0153542
# 9:  |F(x)| = 1.33525; step 0.01
# 10:  |F(x)| = 3.57041; step 1
# 11:  |F(x)| = 2.52458; step 1
# 12:  |F(x)| = 0.821472; step 1
# 13:  |F(x)| = 0.456555; step 1
# 14:  |F(x)| = 0.548072; step 1
# 15:  |F(x)| = 0.288393; step 1
# 16:  |F(x)| = 0.0691829; step 1
# 17:  |F(x)| = 0.0551191; step 0.263444
# 18:  |F(x)| = 0.0565251; step 0.168384
# 19:  |F(x)| = 0.0660351; step 0.152113
# 20:  |F(x)| = 0.074856; step 0.18978
# 21:  |F(x)| = 0.0849542; step 0.349304
# 22:  |F(x)| = 0.0867848; step 1
# 23:  |F(x)| = 0.0364862; step 1
# 24:  |F(x)| = 0.00943644; step 1
# 25:  |F(x)| = 0.00969576; step 0.140666
# 26:  |F(x)| = 0.010065; step 0.115361
# 27:  |F(x)| = 0.0112073; step 0.119836
# 28:  |F(x)| = 0.0124042; step 0.158922
# 29:  |F(x)| = 0.0138815; step 0.287393
# 30:  |F(x)| = 0.0152988; step 1
# 31:  |F(x)| = 0.0072315; step 1
# 32:  |F(x)| = 0.0019707; step 1
# 33:  |F(x)| = 0.00202641; step 0.4768
# 34:  |F(x)| = 0.00252142; step 1
# 35:  |F(x)| = 0.00135236; step 1
# 36:  |F(x)| = 0.000316233; step 1
# 37:  |F(x)| = 0.000253858; step 0.252174
# 38:  |F(x)| = 0.00022565; step 0.125618
# 39:  |F(x)| = 0.00025229; step 0.0808491
# 40:  |F(x)| = 0.000271511; step 0.06187
# 41:  |F(x)| = 0.000286666; step 0.0541721
# 42:  |F(x)| = 0.000300233; step 0.0534025
# 43:  |F(x)| = 0.00031383; step 0.0591756
# 44:  |F(x)| = 0.000329059; step 0.0746153
# 45:  |F(x)| = 0.000348214; step 0.110519
# 46:  |F(x)| = 0.000375158; step 0.206197
# 47:  |F(x)| = 0.000434085; step 1
# 48:  |F(x)| = 0.000212007; step 1
# 49:  |F(x)| = 5.31967e-05; step 1
# 50:  |F(x)| = 4.69409e-05; step 0.32709
# 51:  |F(x)| = 4.78521e-05; step 0.261737
# 52:  |F(x)| = 5.51203e-05; step 0.350876
# 53:  |F(x)| = 6.46927e-05; step 1
# 54:  |F(x)| = 3.05419e-05; step 1
# 55:  |F(x)| = 8.26074e-06; step 1
# 56:  |F(x)| = 8.26904e-06; step 0.410579
# 57:  |F(x)| = 8.75724e-06; step 0.463591
# 58:  |F(x)| = 9.40957e-06; step 1
# 59:  |F(x)| = 3.69927e-06; step 1
# scipy solver converged in 61 iterations.
# 0:  |F(x)| = 20.5806; step 1
# 1:  |F(x)| = 4.58465; step 1
# 2:  |F(x)| = 1.13226; step 1
# 3:  |F(x)| = 1.35386; step 1
# 4:  |F(x)| = 0.892357; step 1
# 5:  |F(x)| = 0.190603; step 1
# 6:  |F(x)| = 0.105086; step 1
# 7:  |F(x)| = 0.0858346; step 1
# 8:  |F(x)| = 0.0168755; step 1
# 9:  |F(x)| = 0.0174614; step 1
# 10:  |F(x)| = 0.0110584; step 1
# 11:  |F(x)| = 0.00165884; step 1
# 12:  |F(x)| = 0.00131007; step 0.454596
# 13:  |F(x)| = 0.00146086; step 0.362096
# 14:  |F(x)| = 0.00179737; step 1
# 15:  |F(x)| = 0.000570508; step 1
# 16:  |F(x)| = 0.000152576; step 1
# 17:  |F(x)| = 0.000206379; step 1
# 18:  |F(x)| = 5.46412e-05; step 1
# 19:  |F(x)| = 2.90073e-05; step 1
# 20:  |F(x)| = 2.88113e-05; step 1
# 21:  |F(x)| = 6.55105e-06; step 1
# 22:  |F(x)| = 4.3314e-06; step 1
# scipy solver converged in 24 iterations.
# 0:  |F(x)| = 86.8052; step 0.510255
# 1:  |F(x)| = 16.8195; step 1
# 2:  |F(x)| = 19.2459; step 1
# 3:  |F(x)| = 7.84534; step 1
# 4:  |F(x)| = 2.6989; step 1
# 5:  |F(x)| = 1.60545; step 0.449777
# 6:  |F(x)| = 1.44202; step 0.106542
# 7:  |F(x)| = 1.38681; step 0.0383968
# 8:  |F(x)| = 1.36543; step 0.0152249
# 9:  |F(x)| = 1.35151; step 0.01
# 10:  |F(x)| = 3.60269; step 1
# 11:  |F(x)| = 2.56603; step 1
# 12:  |F(x)| = 0.843555; step 1
# 13:  |F(x)| = 0.461893; step 1
# 14:  |F(x)| = 0.556414; step 1
# 15:  |F(x)| = 0.296508; step 1
# 16:  |F(x)| = 0.0708217; step 1
# 17:  |F(x)| = 0.0560846; step 0.272393
# 18:  |F(x)| = 0.0562268; step 0.170156
# 19:  |F(x)| = 0.0658867; step 0.150478
# 20:  |F(x)| = 0.0746911; step 0.183079
# 21:  |F(x)| = 0.08471; step 0.324789
# 22:  |F(x)| = 0.089728; step 1
# 23:  |F(x)| = 0.0391871; step 1
# 24:  |F(x)| = 0.00998106; step 1
# 25:  |F(x)| = 0.00965577; step 0.158308
# 26:  |F(x)| = 0.00985617; step 0.119403
# 27:  |F(x)| = 0.010849; step 0.114853
# 28:  |F(x)| = 0.0120001; step 0.13971
# 29:  |F(x)| = 0.0133594; step 0.224439
# 30:  |F(x)| = 0.0163284; step 1
# 31:  |F(x)| = 0.0083345; step 1
# 32:  |F(x)| = 0.00220696; step 1
# 33:  |F(x)| = 0.00204849; step 0.495401
# 34:  |F(x)| = 0.0026501; step 1
# 35:  |F(x)| = 0.00152878; step 1
# 36:  |F(x)| = 0.000347144; step 1
# 37:  |F(x)| = 0.000266578; step 0.313988
# 38:  |F(x)| = 0.000233426; step 0.143564
# 39:  |F(x)| = 0.000247854; step 0.0872646
# 40:  |F(x)| = 0.000268578; step 0.0638309
# 41:  |F(x)| = 0.000284234; step 0.0536175
# 42:  |F(x)| = 0.000297696; step 0.0506258
# 43:  |F(x)| = 0.00031064; step 0.0534078
# 44:  |F(x)| = 0.000324477; step 0.0633177
# 45:  |F(x)| = 0.000340971; step 0.0861129
# 46:  |F(x)| = 0.000363035; step 0.140711
# 47:  |F(x)| = 0.000394882; step 0.305255
# 48:  |F(x)| = 0.00039986; step 1
# 49:  |F(x)| = 0.000175062; step 1
# 50:  |F(x)| = 4.62155e-05; step 1
# 51:  |F(x)| = 4.82428e-05; step 0.27782
# 52:  |F(x)| = 4.96228e-05; step 0.281662
# 53:  |F(x)| = 6.06039e-05; step 0.485874
# 54:  |F(x)| = 5.61076e-05; step 1
# 55:  |F(x)| = 2.13486e-05; step 1
# 56:  |F(x)| = 8.38269e-06; step 1
# 57:  |F(x)| = 8.49094e-06; step 0.44052
# 58:  |F(x)| = 1.04835e-05; step 1
# 59:  |F(x)| = 4.68037e-06; step 1
# scipy solver converged in 61 iterations.
# 0:  |F(x)| = 139.32; step 0.441604
# 1:  |F(x)| = 43.9016; step 1
# 2:  |F(x)| = 28.9665; step 1
# 3:  |F(x)| = 15.6251; step 1
# 4:  |F(x)| = 8.83715; step 1
# 5:  |F(x)| = 3.60911; step 1
# 6:  |F(x)| = 3.89439; step 0.199569
# 7:  |F(x)| = 4.06086; step 0.102465
# 8:  |F(x)| = 4.19867; step 0.103601
# 9:  |F(x)| = 4.36339; step 0.159253
# 10:  |F(x)| = 4.60631; step 0.415982
# 11:  |F(x)| = 4.16374; step 1
# 12:  |F(x)| = 2.04698; step 1
# 13:  |F(x)| = 0.564475; step 1
# 14:  |F(x)| = 0.765312; step 1
# 15:  |F(x)| = 0.644838; step 1
# 16:  |F(x)| = 0.189772; step 1
# 17:  |F(x)| = 0.121005; step 1
# 18:  |F(x)| = 0.137788; step 0.207698
# 19:  |F(x)| = 0.157128; step 0.402741
# 20:  |F(x)| = 0.152705; step 1
# 21:  |F(x)| = 0.0663333; step 1
# 22:  |F(x)| = 0.0184195; step 1
# 23:  |F(x)| = 0.0194049; step 0.210141
# 24:  |F(x)| = 0.0196419; step 0.167982
# 25:  |F(x)| = 0.0210584; step 0.184846
# 26:  |F(x)| = 0.0242211; step 0.286493
# 27:  |F(x)| = 0.0285541; step 1
# 28:  |F(x)| = 0.0151864; step 1
# 29:  |F(x)| = 0.00426624; step 1
# 30:  |F(x)| = 0.00506466; step 1
# 31:  |F(x)| = 0.00480432; step 1
# 32:  |F(x)| = 0.00183265; step 1
# 33:  |F(x)| = 0.0006432; step 1
# 34:  |F(x)| = 0.00066347; step 0.0648015
# 35:  |F(x)| = 0.000705037; step 0.0573745
# 36:  |F(x)| = 0.000742659; step 0.0570938
# 37:  |F(x)| = 0.000780731; step 0.0638225
# 38:  |F(x)| = 0.00082375; step 0.0812007
# 39:  |F(x)| = 0.000878336; step 0.121534
# 40:  |F(x)| = 0.000955632; step 0.22985
# 41:  |F(x)| = 0.00110002; step 1
# 42:  |F(x)| = 0.00057725; step 1
# 43:  |F(x)| = 0.000148637; step 1
# 44:  |F(x)| = 0.000129022; step 0.411675
# 45:  |F(x)| = 0.000131895; step 0.306207
# 46:  |F(x)| = 0.000143756; step 0.396278
# 47:  |F(x)| = 0.000166161; step 1
# 48:  |F(x)| = 8.3694e-05; step 1
# 49:  |F(x)| = 2.27532e-05; step 1
# 50:  |F(x)| = 2.18329e-05; step 0.420355
# 51:  |F(x)| = 2.20148e-05; step 0.407057
# 52:  |F(x)| = 2.8165e-05; step 1
# 53:  |F(x)| = 1.47749e-05; step 1
# 54:  |F(x)| = 3.60999e-06; step 1
# scipy solver converged in 56 iterations.
# 0:  |F(x)| = 152.053; step 0.428095
# 1:  |F(x)| = 51.9287; step 1
# 2:  |F(x)| = 31.4013; step 1
# 3:  |F(x)| = 18.0385; step 1
# 4:  |F(x)| = 10.9119; step 1
# 5:  |F(x)| = 3.9375; step 1
# 6:  |F(x)| = 3.77425; step 0.226907
# 7:  |F(x)| = 3.91046; step 0.0626474
# 8:  |F(x)| = 3.98443; step 0.0373804
# 9:  |F(x)| = 4.03481; step 0.0270432
# 10:  |F(x)| = 4.07412; step 0.0220963
# 11:  |F(x)| = 4.10799; step 0.0197986
# 12:  |F(x)| = 4.13967; step 0.0192035
# 13:  |F(x)| = 4.17157; step 0.0200568
# 14:  |F(x)| = 4.20608; step 0.0225641
# 15:  |F(x)| = 4.24634; step 0.0275629
# 16:  |F(x)| = 4.29744; step 0.0371155
# 17:  |F(x)| = 4.3692; step 0.0567371
# 18:  |F(x)| = 4.48359; step 0.104528
# 19:  |F(x)| = 4.69132; step 0.265309
# 20:  |F(x)| = 4.72006; step 1
# 21:  |F(x)| = 2.70589; step 1
# 22:  |F(x)| = 0.699905; step 1
# 23:  |F(x)| = 0.790245; step 1
# 24:  |F(x)| = 0.781459; step 1
# 25:  |F(x)| = 0.300141; step 1
# 26:  |F(x)| = 0.106708; step 1
# 27:  |F(x)| = 0.110092; step 0.162753
# 28:  |F(x)| = 0.118434; step 0.146241
# 29:  |F(x)| = 0.133426; step 0.178933
# 30:  |F(x)| = 0.150844; step 0.313651
# 31:  |F(x)| = 0.164173; step 1
# 32:  |F(x)| = 0.080601; step 1
# 33:  |F(x)| = 0.0210157; step 1
# 34:  |F(x)| = 0.0188148; step 0.298069
# 35:  |F(x)| = 0.0193417; step 0.19186
# 36:  |F(x)| = 0.0193703; step 0.176285
# 37:  |F(x)| = 0.0219676; step 0.224938
# 38:  |F(x)| = 0.0253067; step 0.424114
# 39:  |F(x)| = 0.0246337; step 1
# 40:  |F(x)| = 0.0114044; step 1
# 41:  |F(x)| = 0.00346287; step 1
# 42:  |F(x)| = 0.0037784; step 0.512988
# 43:  |F(x)| = 0.00442178; step 1
# 44:  |F(x)| = 0.00257389; step 1
# 45:  |F(x)| = 0.000601545; step 1
# 46:  |F(x)| = 0.000465243; step 0.317564
# 47:  |F(x)| = 0.000415509; step 0.126643
# 48:  |F(x)| = 0.000391972; step 0.0630572
# 49:  |F(x)| = 0.000396121; step 0.0354258
# 50:  |F(x)| = 0.00039952; step 0.0213424
# 51:  |F(x)| = 0.000403678; step 0.0134171
# 52:  |F(x)| = 0.00040979; step 0.01
# 53:  |F(x)| = 0.00101235; step 1
# 54:  |F(x)| = 0.000761583; step 1
# 55:  |F(x)| = 0.000251736; step 1
# 56:  |F(x)| = 0.000136989; step 1
# 57:  |F(x)| = 0.000140812; step 0.384187
# 58:  |F(x)| = 0.000174587; step 1
# 59:  |F(x)| = 9.34682e-05; step 1
# 60:  |F(x)| = 2.5397e-05; step 1
# 61:  |F(x)| = 2.22855e-05; step 0.460338
# 62:  |F(x)| = 2.27993e-05; step 0.400687
# 63:  |F(x)| = 2.95138e-05; step 1
# 64:  |F(x)| = 1.63875e-05; step 1
# 65:  |F(x)| = 3.91397e-06; step 1
# scipy solver converged in 67 iterations.
# 0:  |F(x)| = 0.158814; step 1
# 1:  |F(x)| = 0.00552334; step 1
# 2:  |F(x)| = 0.00310017; step 1
# 3:  |F(x)| = 0.00029019; step 1
# 4:  |F(x)| = 8.23888e-05; step 1
# 5:  |F(x)| = 1.48227e-05; step 1
# 6:  |F(x)| = 2.80718e-06; step 1
# scipy solver converged in 8 iterations.
# 0:  |F(x)| = 10.1764; step 1
# 1:  |F(x)| = 2.00675; step 1
# 2:  |F(x)| = 0.639584; step 1
# 3:  |F(x)| = 0.691989; step 1
# 4:  |F(x)| = 0.276271; step 1
# 5:  |F(x)| = 0.0370574; step 1
# 6:  |F(x)| = 0.0256447; step 0.516746
# 7:  |F(x)| = 0.0333827; step 1
# 8:  |F(x)| = 0.00639023; step 1
# 9:  |F(x)| = 0.00489463; step 1
# 10:  |F(x)| = 0.00326101; step 1
# 11:  |F(x)| = 0.00041776; step 1
# 12:  |F(x)| = 0.000330749; step 0.498473
# 13:  |F(x)| = 0.000375404; step 0.483672
# 14:  |F(x)| = 0.000346093; step 1
# 15:  |F(x)| = 7.1345e-05; step 1
# 16:  |F(x)| = 4.10243e-05; step 1
# 17:  |F(x)| = 3.0321e-05; step 1
# 18:  |F(x)| = 3.92796e-06; step 1
# scipy solver converged in 20 iterations.
# 0:  |F(x)| = 202.883; step 0.54228
# 1:  |F(x)| = 56.7808; step 1
# 2:  |F(x)| = 18.4186; step 0.513745
# 3:  |F(x)| = 16.7181; step 0.107739
# 4:  |F(x)| = 16.2683; step 0.0300935
# 5:  |F(x)| = 16.1211; step 0.01
# 6:  |F(x)| = 45.1046; step 1
# 7:  |F(x)| = 31.2329; step 1
# 8:  |F(x)| = 10.6719; step 1
# 9:  |F(x)| = 5.87302; step 1
# 10:  |F(x)| = 11.7062; step 1
# 11:  |F(x)| = 9.8202; step 1
# 12:  |F(x)| = 4.1612; step 1
# 13:  |F(x)| = 1.7894; step 1
# 14:  |F(x)| = 1.88124; step 1
# 15:  |F(x)| = 1.5545; step 1
# 16:  |F(x)| = 0.609016; step 1
# 17:  |F(x)| = 0.229172; step 1
# 18:  |F(x)| = 0.488971; step 1
# 19:  |F(x)| = 0.410446; step 1
# 20:  |F(x)| = 0.170018; step 1
# 21:  |F(x)| = 0.0657341; step 1
# 22:  |F(x)| = 0.0663133; step 0.438029
# 23:  |F(x)| = 0.0678786; step 0.46607
# 24:  |F(x)| = 0.0774831; step 1
# 25:  |F(x)| = 0.0442146; step 1
# 26:  |F(x)| = 0.0133901; step 1
# 27:  |F(x)| = 0.0130147; step 1
# 28:  |F(x)| = 0.01433; step 1
# 29:  |F(x)| = 0.00794528; step 1
# 30:  |F(x)| = 0.00195922; step 1
# 31:  |F(x)| = 0.00153458; step 0.305426
# 32:  |F(x)| = 0.00143382; step 0.119638
# 33:  |F(x)| = 0.0014653; step 0.0557061
# 34:  |F(x)| = 0.00147915; step 0.0283829
# 35:  |F(x)| = 0.00148598; step 0.0151645
# 36:  |F(x)| = 0.00149029; step 0.01
# 37:  |F(x)| = 0.00338244; step 1
# 38:  |F(x)| = 0.002907; step 1
# 39:  |F(x)| = 0.00136298; step 1
# 40:  |F(x)| = 0.000435072; step 1
# 41:  |F(x)| = 0.000543114; step 1
# 42:  |F(x)| = 0.00052689; step 1
# 43:  |F(x)| = 0.000250388; step 1
# 44:  |F(x)| = 7.31098e-05; step 1
# 45:  |F(x)| = 7.82941e-05; step 0.371381
# 46:  |F(x)| = 7.91627e-05; step 0.330998
# 47:  |F(x)| = 9.00387e-05; step 0.496551
# 48:  |F(x)| = 9.08084e-05; step 1
# 49:  |F(x)| = 4.52228e-05; step 1
# 50:  |F(x)| = 1.19831e-05; step 1
# 51:  |F(x)| = 1.05181e-05; step 0.255801
# 52:  |F(x)| = 1.0727e-05; step 0.0749535
# 53:  |F(x)| = 1.07523e-05; step 0.0117216
# 54:  |F(x)| = 1.07729e-05; step 0.01
# 55:  |F(x)| = 2.14257e-05; step 1
# 56:  |F(x)| = 1.86153e-05; step 1
# 57:  |F(x)| = 8.84133e-06; step 1
# 58:  |F(x)| = 2.86476e-06; step 1
# scipy solver converged in 60 iterations.
# 0:  |F(x)| = 0.400221; step 1
# 1:  |F(x)| = 0.0168331; step 1
# 2:  |F(x)| = 0.0117131; step 1
# 3:  |F(x)| = 0.00196612; step 1
# 4:  |F(x)| = 0.000356968; step 1
# 5:  |F(x)| = 0.000134987; step 1
# 6:  |F(x)| = 1.02157e-05; step 1
# 7:  |F(x)| = 9.79098e-06; step 1
# 8:  |F(x)| = 6.05995e-07; step 1
# scipy solver converged in 10 iterations.
# 0:  |F(x)| = 234.528; step 0.516819
# 1:  |F(x)| = 90.8246; step 1
# 2:  |F(x)| = 71.862; step 1
# 3:  |F(x)| = 49.4827; step 1
# 4:  |F(x)| = 38.1531; step 1
# 5:  |F(x)| = 9.29186; step 1
# 6:  |F(x)| = 5.55103; step 0.388236
# 7:  |F(x)| = 5.45036; step 0.0455956
# 8:  |F(x)| = 5.42688; step 0.0116721
# 9:  |F(x)| = 11.9362; step 1
# 10:  |F(x)| = 14.1535; step 1
# 11:  |F(x)| = 6.88398; step 1
# 12:  |F(x)| = 2.99796; step 1
# 13:  |F(x)| = 1.92091; step 1
# 14:  |F(x)| = 1.81239; step 1
# 15:  |F(x)| = 1.23094; step 1
# 16:  |F(x)| = 0.28344; step 1
# 17:  |F(x)| = 0.239899; step 0.243921
# 18:  |F(x)| = 0.236925; step 0.0305204
# 19:  |F(x)| = 0.235998; step 0.01
# 20:  |F(x)| = 0.494566; step 1
# 21:  |F(x)| = 0.533197; step 1
# 22:  |F(x)| = 0.246887; step 1
# 23:  |F(x)| = 0.0897686; step 1
# 24:  |F(x)| = 0.0861955; step 1
# 25:  |F(x)| = 0.083999; step 1
# 26:  |F(x)| = 0.0590792; step 1
# 27:  |F(x)| = 0.0117305; step 1
# 28:  |F(x)| = 0.0104618; step 0.360135
# 29:  |F(x)| = 0.0114441; step 0.39974
# 30:  |F(x)| = 0.011923; step 0.52352
# 31:  |F(x)| = 0.0129062; step 1
# 32:  |F(x)| = 0.0076081; step 1
# 33:  |F(x)| = 0.00173118; step 1
# 34:  |F(x)| = 0.00135632; step 0.3118
# 35:  |F(x)| = 0.00125865; step 0.0860107
# 36:  |F(x)| = 0.00122996; step 0.0259611
# 37:  |F(x)| = 0.001219; step 0.01
# 38:  |F(x)| = 0.00321279; step 1
# 39:  |F(x)| = 0.00313199; step 1
# 40:  |F(x)| = 0.00177409; step 1
# 41:  |F(x)| = 0.000569412; step 1
# 42:  |F(x)| = 0.000499603; step 1
# 43:  |F(x)| = 0.000452601; step 1
# 44:  |F(x)| = 0.000270675; step 1
# 45:  |F(x)| = 6.7171e-05; step 1
# 46:  |F(x)| = 4.92572e-05; step 0.425124
# 47:  |F(x)| = 5.05041e-05; step 0.190398
# 48:  |F(x)| = 5.21415e-05; step 0.116754
# 49:  |F(x)| = 5.29713e-05; step 0.0896862
# 50:  |F(x)| = 5.34621e-05; step 0.0822356
# 51:  |F(x)| = 5.43106e-05; step 0.0886519
# 52:  |F(x)| = 5.87081e-05; step 0.113489
# 53:  |F(x)| = 6.43574e-05; step 0.179597
# 54:  |F(x)| = 7.23888e-05; step 0.385376
# 55:  |F(x)| = 7.34779e-05; step 1
# 56:  |F(x)| = 3.91099e-05; step 1
# 57:  |F(x)| = 9.98961e-06; step 1
# 58:  |F(x)| = 7.9953e-06; step 0.382419
# 59:  |F(x)| = 1.60015e-05; step 1
# 60:  |F(x)| = 1.51039e-05; step 1
# 61:  |F(x)| = 8.2603e-06; step 1
# 62:  |F(x)| = 2.91298e-06; step 1
# scipy solver converged in 64 iterations.
# 0:  |F(x)| = 248.184; step 0.349109
# 1:  |F(x)| = 140.188; step 1
# 2:  |F(x)| = 52.6489; step 1
# 3:  |F(x)| = 40.7; step 1
# 4:  |F(x)| = 30.4524; step 1
# 5:  |F(x)| = 7.30234; step 1
# 6:  |F(x)| = 4.10595; step 0.452963
# 7:  |F(x)| = 4.06013; step 0.0420406
# 8:  |F(x)| = 4.04834; step 0.0115366
# 9:  |F(x)| = 9.0271; step 1
# 10:  |F(x)| = 9.66615; step 1
# 11:  |F(x)| = 4.39092; step 1
# 12:  |F(x)| = 1.60452; step 1
# 13:  |F(x)| = 1.66011; step 1
# 14:  |F(x)| = 1.43118; step 1
# 15:  |F(x)| = 0.660651; step 1
# 16:  |F(x)| = 0.174043; step 1
# 17:  |F(x)| = 0.434127; step 1
# 18:  |F(x)| = 0.386795; step 1
# 19:  |F(x)| = 0.152056; step 1
# 20:  |F(x)| = 0.0623675; step 1
# 21:  |F(x)| = 0.0613434; step 0.431815
# 22:  |F(x)| = 0.0648596; step 0.461428
# 23:  |F(x)| = 0.0715344; step 1
# 24:  |F(x)| = 0.0381381; step 1
# 25:  |F(x)| = 0.0112243; step 1
# 26:  |F(x)| = 0.0127878; step 1
# 27:  |F(x)| = 0.0133922; step 1
# 28:  |F(x)| = 0.00641453; step 1
# 29:  |F(x)| = 0.00168485; step 1
# 30:  |F(x)| = 0.0014923; step 0.159196
# 31:  |F(x)| = 0.00153959; step 0.0784696
# 32:  |F(x)| = 0.00156102; step 0.0441313
# 33:  |F(x)| = 0.00157239; step 0.02682
# 34:  |F(x)| = 0.00157903; step 0.0171021
# 35:  |F(x)| = 0.00158315; step 0.0112473
# 36:  |F(x)| = 0.00158667; step 0.01
# 37:  |F(x)| = 0.00344442; step 1
# 38:  |F(x)| = 0.00276912; step 1
# 39:  |F(x)| = 0.00112491; step 1
# 40:  |F(x)| = 0.000471305; step 1
# 41:  |F(x)| = 0.000473764; step 0.477279
# 42:  |F(x)| = 0.000574581; step 1
# 43:  |F(x)| = 0.000359598; step 1
# 44:  |F(x)| = 0.000100568; step 1
# 45:  |F(x)| = 9.65625e-05; step 1
# 46:  |F(x)| = 0.000124224; step 1
# 47:  |F(x)| = 7.2157e-05; step 1
# 48:  |F(x)| = 1.78082e-05; step 1
# 49:  |F(x)| = 1.27288e-05; step 0.42584
# 50:  |F(x)| = 1.33319e-05; step 0.166127
# 51:  |F(x)| = 1.35515e-05; step 0.0903595
# 52:  |F(x)| = 1.36457e-05; step 0.0607881
# 53:  |F(x)| = 1.36934e-05; step 0.0472911
# 54:  |F(x)| = 1.37185e-05; step 0.0411416
# 55:  |F(x)| = 1.37296e-05; step 0.0394046
# 56:  |F(x)| = 1.37288e-05; step 0.0412827
# 57:  |F(x)| = 1.37342e-05; step 0.0474032
# 58:  |F(x)| = 1.43572e-05; step 0.0602272
# 59:  |F(x)| = 1.51618e-05; step 0.0864408
# 60:  |F(x)| = 1.63106e-05; step 0.145644
# 61:  |F(x)| = 1.80554e-05; step 0.308775
# 62:  |F(x)| = 1.94995e-05; step 1
# 63:  |F(x)| = 1.07955e-05; step 1
# 64:  |F(x)| = 3.11198e-06; step 1
# scipy solver converged in 66 iterations.
# 0:  |F(x)| = 0.201069; step 1
# 1:  |F(x)| = 0.00734857; step 1
# 2:  |F(x)| = 0.00435999; step 1
# 3:  |F(x)| = 0.000475334; step 1
# 4:  |F(x)| = 0.000122169; step 1
# 5:  |F(x)| = 2.63119e-05; step 1
# 6:  |F(x)| = 4.23699e-06; step 1
# scipy solver converged in 8 iterations.
# 0:  |F(x)| = 125.51; step 1
# 1:  |F(x)| = 29.2212; step 1
# 2:  |F(x)| = 18.5396; step 1
# 3:  |F(x)| = 5.17219; step 1
# 4:  |F(x)| = 6.17717; step 1
# 5:  |F(x)| = 6.53288; step 0.284674
# 6:  |F(x)| = 6.25707; step 1
# 7:  |F(x)| = 2.8302; step 1
# 8:  |F(x)| = 0.734102; step 1
# 9:  |F(x)| = 1.02515; step 1
# 10:  |F(x)| = 0.641388; step 1
# 11:  |F(x)| = 0.149887; step 1
# 12:  |F(x)| = 0.0994752; step 0.422938
# 13:  |F(x)| = 0.0994835; step 0.258054
# 14:  |F(x)| = 0.122979; step 0.272923
# 15:  |F(x)| = 0.143299; step 0.513811
# 16:  |F(x)| = 0.117058; step 1
# 17:  |F(x)| = 0.0310963; step 1
# 18:  |F(x)| = 0.0241993; step 1
# 19:  |F(x)| = 0.0263765; step 0.275398
# 20:  |F(x)| = 0.0277007; step 1
# 21:  |F(x)| = 0.0118114; step 1
# 22:  |F(x)| = 0.00333926; step 1
# 23:  |F(x)| = 0.00346954; step 0.491431
# 24:  |F(x)| = 0.00398152; step 1
# 25:  |F(x)| = 0.00161819; step 1
# 26:  |F(x)| = 0.000451257; step 1
# 27:  |F(x)| = 0.000535265; step 0.145245
# 28:  |F(x)| = 0.00060046; step 0.149608
# 29:  |F(x)| = 0.000666677; step 0.215617
# 30:  |F(x)| = 0.000737936; step 0.485423
# 31:  |F(x)| = 0.000598878; step 1
# 32:  |F(x)| = 0.000175773; step 1
# 33:  |F(x)| = 9.80773e-05; step 1
# 34:  |F(x)| = 0.00011534; step 0.38134
# 35:  |F(x)| = 0.000116071; step 1
# 36:  |F(x)| = 4.45137e-05; step 1
# 37:  |F(x)| = 1.49609e-05; step 1
# 38:  |F(x)| = 1.59262e-05; step 0.442946
# 39:  |F(x)| = 1.88185e-05; step 1
# 40:  |F(x)| = 7.22312e-06; step 1
# 41:  |F(x)| = 2.35801e-06; step 1
# scipy solver converged in 43 iterations.
# 0:  |F(x)| = 7.15841; step 1
# 1:  |F(x)| = 1.20904; step 1
# 2:  |F(x)| = 0.440116; step 1
# 3:  |F(x)| = 0.428856; step 1
# 4:  |F(x)| = 0.127429; step 1
# 5:  |F(x)| = 0.0177406; step 1
# 6:  |F(x)| = 0.0269096; step 1
# 7:  |F(x)| = 0.00527247; step 1
# 8:  |F(x)| = 0.00341368; step 1
# 9:  |F(x)| = 0.00221426; step 1
# 10:  |F(x)| = 0.000244022; step 1
# 11:  |F(x)| = 0.000194129; step 0.50495
# 12:  |F(x)| = 0.00029567; step 1
# 13:  |F(x)| = 8.29855e-05; step 1
# 14:  |F(x)| = 2.46576e-05; step 1
# 15:  |F(x)| = 2.41859e-05; step 1
# 16:  |F(x)| = 3.77159e-06; step 1
# scipy solver converged in 18 iterations.
# 0:  |F(x)| = 3.26734; step 1
# 1:  |F(x)| = 0.336424; step 1
# 2:  |F(x)| = 0.178522; step 1
# 3:  |F(x)| = 0.114398; step 1
# 4:  |F(x)| = 0.0130443; step 1
# 5:  |F(x)| = 0.00964569; step 1
# 6:  |F(x)| = 0.00403008; step 1
# 7:  |F(x)| = 0.000454303; step 1
# 8:  |F(x)| = 0.000695653; step 1
# 9:  |F(x)| = 0.000119496; step 1
# 10:  |F(x)| = 7.22188e-05; step 1
# 11:  |F(x)| = 3.79276e-05; step 1
# 12:  |F(x)| = 3.53941e-06; step 1
# scipy solver converged in 14 iterations.
# 0:  |F(x)| = 138.545; step 1
# 1:  |F(x)| = 31.983; step 1
# 2:  |F(x)| = 21.1367; step 1
# 3:  |F(x)| = 7.07301; step 1
# 4:  |F(x)| = 6.30531; step 1
# 5:  |F(x)| = 6.39484; step 0.040592
# 6:  |F(x)| = 6.55009; step 0.0795454
# 7:  |F(x)| = 6.84717; step 0.203518
# 8:  |F(x)| = 7.04682; step 1
# 9:  |F(x)| = 3.52261; step 1
# 10:  |F(x)| = 0.844051; step 1
# 11:  |F(x)| = 1.1185; step 1
# 12:  |F(x)| = 0.798415; step 1
# 13:  |F(x)| = 0.195521; step 1
# 14:  |F(x)| = 0.114573; step 0.503114
# 15:  |F(x)| = 0.0983364; step 0.26066
# 16:  |F(x)| = 0.124069; step 0.228967
# 17:  |F(x)| = 0.14621; step 0.331233
# 18:  |F(x)| = 0.16012; step 1
# 19:  |F(x)| = 0.0649082; step 1
# 20:  |F(x)| = 0.0159167; step 1
# 21:  |F(x)| = 0.017234; step 0.0695137
# 22:  |F(x)| = 0.0184132; step 0.054818
# 23:  |F(x)| = 0.0193662; step 0.0487287
# 24:  |F(x)| = 0.0202289; step 0.0481973
# 25:  |F(x)| = 0.0210943; step 0.0529995
# 26:  |F(x)| = 0.0220544; step 0.065435
# 27:  |F(x)| = 0.0232391; step 0.0930932
# 28:  |F(x)| = 0.0248708; step 0.161237
# 29:  |F(x)| = 0.0271645; step 0.382463
# 30:  |F(x)| = 0.024902; step 1
# 31:  |F(x)| = 0.00959314; step 1
# 32:  |F(x)| = 0.00354065; step 1
# 33:  |F(x)| = 0.00461368; step 1
# 34:  |F(x)| = 0.0025902; step 1
# 35:  |F(x)| = 0.000578143; step 1
# 36:  |F(x)| = 0.000445496; step 0.297748
# 37:  |F(x)| = 0.000441335; step 0.156702
# 38:  |F(x)| = 0.000505074; step 0.115436
# 39:  |F(x)| = 0.000554165; step 0.110247
# 40:  |F(x)| = 0.000601875; step 0.135129
# 41:  |F(x)| = 0.000657936; step 0.223393
# 42:  |F(x)| = 0.000760939; step 1
# 43:  |F(x)| = 0.000345056; step 1
# 44:  |F(x)| = 8.43441e-05; step 1
# 45:  |F(x)| = 7.5244e-05; step 0.243246
# 46:  |F(x)| = 7.91135e-05; step 0.206406
# 47:  |F(x)| = 9.45505e-05; step 0.269494
# 48:  |F(x)| = 0.000120019; step 1
# 49:  |F(x)| = 5.69119e-05; step 1
# 50:  |F(x)| = 1.48629e-05; step 1
# 51:  |F(x)| = 1.42101e-05; step 0.438155
# 52:  |F(x)| = 1.94416e-05; step 1
# 53:  |F(x)| = 9.75088e-06; step 1
# 54:  |F(x)| = 2.23293e-06; step 1
# scipy solver converged in 56 iterations.
# 0:  |F(x)| = 13.4983; step 1
# 1:  |F(x)| = 2.81305; step 1
# 2:  |F(x)| = 0.813293; step 1
# 3:  |F(x)| = 0.930179; step 1
# 4:  |F(x)| = 0.451746; step 1
# 5:  |F(x)| = 0.0634699; step 1
# 6:  |F(x)| = 0.0722086; step 1
# 7:  |F(x)| = 0.0348713; step 1
# 8:  |F(x)| = 0.00601012; step 1
# 9:  |F(x)| = 0.00932412; step 1
# 10:  |F(x)| = 0.00327895; step 1
# 11:  |F(x)| = 0.000871033; step 1
# 12:  |F(x)| = 0.00121753; step 1
# 13:  |F(x)| = 0.000364593; step 1
# 14:  |F(x)| = 0.000108715; step 1
# 15:  |F(x)| = 0.000126263; step 1
# 16:  |F(x)| = 2.77215e-05; step 1
# 17:  |F(x)| = 1.78967e-05; step 1
# 18:  |F(x)| = 1.43934e-05; step 1
# 19:  |F(x)| = 2.1194e-06; step 1
# scipy solver converged in 21 iterations.
# 0:  |F(x)| = 302.885; step 0.472484
# 1:  |F(x)| = 182.275; step 1
# 2:  |F(x)| = 102.549; step 1
# 3:  |F(x)| = 75.6942; step 1
# 4:  |F(x)| = 64.4115; step 1
# 5:  |F(x)| = 17.8535; step 1
# 6:  |F(x)| = 8.6446; step 0.479714
# 7:  |F(x)| = 7.4367; step 0.27388
# 8:  |F(x)| = 6.8608; step 0.112609
# 9:  |F(x)| = 6.62145; step 0.0466065
# 10:  |F(x)| = 6.51986; step 0.019842
# 11:  |F(x)| = 6.46876; step 0.01
# 12:  |F(x)| = 14.4279; step 1
# 13:  |F(x)| = 15.2805; step 1
# 14:  |F(x)| = 8.47681; step 1
# 15:  |F(x)| = 3.40837; step 1
# 16:  |F(x)| = 2.28563; step 1
# 17:  |F(x)| = 1.91166; step 1
# 18:  |F(x)| = 1.03689; step 1
# 19:  |F(x)| = 0.267032; step 1
# 20:  |F(x)| = 0.240771; step 0.249582
# 21:  |F(x)| = 0.561707; step 1
# 22:  |F(x)| = 0.571398; step 0.194174
# 23:  |F(x)| = 0.558828; step 1
# 24:  |F(x)| = 0.302059; step 1
# 25:  |F(x)| = 0.112132; step 1
# 26:  |F(x)| = 0.0700844; step 1
# 27:  |F(x)| = 0.0625568; step 1
# 28:  |F(x)| = 0.0500489; step 1
# 29:  |F(x)| = 0.0111103; step 1
# 30:  |F(x)| = 0.00876213; step 0.458632
# 31:  |F(x)| = 0.00775981; step 0.496032
# 32:  |F(x)| = 0.0100229; step 1
# 33:  |F(x)| = 0.00828155; step 1
# 34:  |F(x)| = 0.0028206; step 1
# 35:  |F(x)| = 0.00154556; step 1
# 36:  |F(x)| = 0.00342967; step 1
# 37:  |F(x)| = 0.00309734; step 1
# 38:  |F(x)| = 0.00189108; step 1
# 39:  |F(x)| = 0.000750224; step 1
# 40:  |F(x)| = 0.000497289; step 1
# 41:  |F(x)| = 0.000337734; step 1
# 42:  |F(x)| = 0.00016139; step 1
# 43:  |F(x)| = 4.39149e-05; step 1
# 44:  |F(x)| = 4.35592e-05; step 0.0538267
# 45:  |F(x)| = 0.000104028; step 1
# 46:  |F(x)| = 0.00010414; step 1
# 47:  |F(x)| = 6.91346e-05; step 1
# 48:  |F(x)| = 2.33003e-05; step 1
# 49:  |F(x)| = 1.40169e-05; step 1
# 50:  |F(x)| = 1.22064e-05; step 0.449159
# 51:  |F(x)| = 1.19004e-05; step 0.479974
# 52:  |F(x)| = 1.26278e-05; step 1
# 53:  |F(x)| = 7.73754e-06; step 1
# 54:  |F(x)| = 3.48595e-06; step 1
# scipy solver converged in 56 iterations.
# 0:  |F(x)| = 38.864; step 1
# 1:  |F(x)| = 9.20843; step 1
# 2:  |F(x)| = 2.91213; step 1
# 3:  |F(x)| = 1.82886; step 1
# 4:  |F(x)| = 2.19536; step 1
# 5:  |F(x)| = 0.935977; step 1
# 6:  |F(x)| = 0.185266; step 1
# 7:  |F(x)| = 0.152551; step 0.508014
# 8:  |F(x)| = 0.18443; step 1
# 9:  |F(x)| = 0.0496427; step 1
# 10:  |F(x)| = 0.0299141; step 1
# 11:  |F(x)| = 0.0318647; step 1
# 12:  |F(x)| = 0.00831397; step 1
# 13:  |F(x)| = 0.00559228; step 1
# 14:  |F(x)| = 0.00615322; step 1
# 15:  |F(x)| = 0.00207671; step 1
# 16:  |F(x)| = 0.00053622; step 1
# 17:  |F(x)| = 0.000861852; step 1
# 18:  |F(x)| = 0.000295355; step 1
# 19:  |F(x)| = 0.000106175; step 1
# 20:  |F(x)| = 0.000128862; step 0.469949
# 21:  |F(x)| = 0.000108605; step 1
# 22:  |F(x)| = 2.3391e-05; step 1
# 23:  |F(x)| = 1.97188e-05; step 1
# 24:  |F(x)| = 1.85958e-05; step 1
# 25:  |F(x)| = 4.86062e-06; step 1
# scipy solver converged in 27 iterations.
# 0:  |F(x)| = 1.59963; step 1
# 1:  |F(x)| = 0.103076; step 1
# 2:  |F(x)| = 0.0775342; step 1
# 3:  |F(x)| = 0.0305791; step 1
# 4:  |F(x)| = 0.00247685; step 1
# 5:  |F(x)| = 0.00274867; step 1
# 6:  |F(x)| = 0.00045938; step 1
# 7:  |F(x)| = 0.000222562; step 1
# 8:  |F(x)| = 9.38484e-05; step 1
# 9:  |F(x)| = 9.14369e-06; step 1
# 10:  |F(x)| = 1.19687e-05; step 1
# 11:  |F(x)| = 1.68849e-06; step 1
# scipy solver converged in 13 iterations.
# 0:  |F(x)| = 17.4999; step 1
# 1:  |F(x)| = 3.8086; step 1
# 2:  |F(x)| = 1.00127; step 1
# 3:  |F(x)| = 1.18509; step 1
# 4:  |F(x)| = 0.692029; step 1
# 5:  |F(x)| = 0.114104; step 1
# 6:  |F(x)| = 0.0937699; step 1
# 7:  |F(x)| = 0.0617266; step 1
# 8:  |F(x)| = 0.0106227; step 1
# 9:  |F(x)| = 0.0141254; step 1
# 10:  |F(x)| = 0.00714737; step 1
# 11:  |F(x)| = 0.00123439; step 1
# 12:  |F(x)| = 0.00106712; step 0.384491
# 13:  |F(x)| = 0.00136043; step 0.484897
# 14:  |F(x)| = 0.00114047; step 1
# 15:  |F(x)| = 0.000238862; step 1
# 16:  |F(x)| = 0.000151936; step 1
# 17:  |F(x)| = 0.000121994; step 1
# 18:  |F(x)| = 1.88643e-05; step 1
# 19:  |F(x)| = 2.37723e-05; step 1
# 20:  |F(x)| = 1.53007e-05; step 1
# 21:  |F(x)| = 2.17461e-06; step 1
# scipy solver converged in 23 iterations.
# 0:  |F(x)| = 8.90437; step 1
# 1:  |F(x)| = 1.70586; step 1
# 2:  |F(x)| = 0.568255; step 1
# 3:  |F(x)| = 0.595883; step 1
# 4:  |F(x)| = 0.216668; step 1
# 5:  |F(x)| = 0.0283272; step 1
# 6:  |F(x)| = 0.0257985; step 0.52273
# 7:  |F(x)| = 0.026248; step 1
# 8:  |F(x)| = 0.0045196; step 1
# 9:  |F(x)| = 0.00417673; step 1
# 10:  |F(x)| = 0.00232847; step 1
# 11:  |F(x)| = 0.000328515; step 1
# 12:  |F(x)| = 0.000256354; step 0.454855
# 13:  |F(x)| = 0.000387533; step 1
# 14:  |F(x)| = 0.000110494; step 1
# 15:  |F(x)| = 3.30621e-05; step 1
# 16:  |F(x)| = 3.43836e-05; step 1
# 17:  |F(x)| = 6.06424e-06; step 1
# 18:  |F(x)| = 4.92337e-06; step 1
# scipy solver converged in 20 iterations.
# 0:  |F(x)| = 305.433; step 0.314756
# 1:  |F(x)| = 208.382; step 1
# 2:  |F(x)| = 69.3459; step 1
# 3:  |F(x)| = 57.4969; step 1
# 4:  |F(x)| = 44.6702; step 1
# 5:  |F(x)| = 10.4729; step 1
# 6:  |F(x)| = 5.66124; step 0.504598
# 7:  |F(x)| = 5.13582; step 0.149494
# 8:  |F(x)| = 4.96509; step 0.0468622
# 9:  |F(x)| = 4.90832; step 0.0155507
# 10:  |F(x)| = 4.87181; step 0.01
# 11:  |F(x)| = 11.2069; step 1
# 12:  |F(x)| = 11.8885; step 1
# 13:  |F(x)| = 6.00128; step 1
# 14:  |F(x)| = 2.22215; step 1
# 15:  |F(x)| = 1.87552; step 1
# 16:  |F(x)| = 1.68177; step 1
# 17:  |F(x)| = 0.848252; step 1
# 18:  |F(x)| = 0.192114; step 1
# 19:  |F(x)| = 0.515696; step 1
# 20:  |F(x)| = 0.510079; step 1
# 21:  |F(x)| = 0.244053; step 1
# 22:  |F(x)| = 0.0758568; step 1
# 23:  |F(x)| = 0.0917429; step 1
# 24:  |F(x)| = 0.0921448; step 1
# 25:  |F(x)| = 0.0523102; step 1
# 26:  |F(x)| = 0.0136404; step 1
# 27:  |F(x)| = 0.0133932; step 0.484094
# 28:  |F(x)| = 0.0137505; step 0.520189
# 29:  |F(x)| = 0.0153107; step 1
# 30:  |F(x)| = 0.00885049; step 1
# 31:  |F(x)| = 0.00206865; step 1
# 32:  |F(x)| = 0.00163076; step 0.299419
# 33:  |F(x)| = 0.00150324; step 0.0933013
# 34:  |F(x)| = 0.00145976; step 0.0328357
# 35:  |F(x)| = 0.00144388; step 0.0121368
# 36:  |F(x)| = 0.00379882; step 1
# 37:  |F(x)| = 0.00350655; step 1
# 38:  |F(x)| = 0.0018038; step 1
# 39:  |F(x)| = 0.000530226; step 1
# 40:  |F(x)| = 0.00057823; step 1
# 41:  |F(x)| = 0.000584063; step 1
# 42:  |F(x)| = 0.000296547; step 1
# 43:  |F(x)| = 8.21803e-05; step 1
# 44:  |F(x)| = 7.69455e-05; step 0.344662
# 45:  |F(x)| = 8.03543e-05; step 0.238057
# 46:  |F(x)| = 8.06999e-05; step 0.25277
# 47:  |F(x)| = 9.71338e-05; step 0.419477
# 48:  |F(x)| = 0.000102513; step 1
# 49:  |F(x)| = 5.34389e-05; step 1
# 50:  |F(x)| = 1.3698e-05; step 1
# 51:  |F(x)| = 1.1023e-05; step 0.299585
# 52:  |F(x)| = 1.12939e-05; step 0.0816669
# 53:  |F(x)| = 1.13523e-05; step 0.0228558
# 54:  |F(x)| = 2.3436e-05; step 1
# 55:  |F(x)| = 2.06385e-05; step 1
# 56:  |F(x)| = 1.00064e-05; step 1
# 57:  |F(x)| = 3.20333e-06; step 1
# scipy solver converged in 59 iterations.
# 0:  |F(x)| = 7.77852; step 1
# 1:  |F(x)| = 1.38126; step 1
# 2:  |F(x)| = 0.486212; step 1
# 3:  |F(x)| = 0.487907; step 1
# 4:  |F(x)| = 0.156904; step 1
# 5:  |F(x)| = 0.0197751; step 1
# 6:  |F(x)| = 0.0319912; step 1
# 7:  |F(x)| = 0.00741598; step 1
# 8:  |F(x)| = 0.00377821; step 1
# 9:  |F(x)| = 0.00284066; step 1
# 10:  |F(x)| = 0.000305271; step 1
# 11:  |F(x)| = 0.000500707; step 1
# 12:  |F(x)| = 0.000251281; step 1
# 13:  |F(x)| = 3.16091e-05; step 1
# 14:  |F(x)| = 2.38654e-05; step 0.487348
# 15:  |F(x)| = 3.32667e-05; step 1
# 16:  |F(x)| = 7.29947e-06; step 1
# 17:  |F(x)| = 3.98843e-06; step 1
# scipy solver converged in 19 iterations.
# 0:  |F(x)| = 4.98048; step 1
# 1:  |F(x)| = 0.671987; step 1
# 2:  |F(x)| = 0.280843; step 1
# 3:  |F(x)| = 0.237625; step 1
# 4:  |F(x)| = 0.0483708; step 1
# 5:  |F(x)| = 0.016086; step 1
# 6:  |F(x)| = 0.0118421; step 1
# 7:  |F(x)| = 0.00143392; step 1
# 8:  |F(x)| = 0.00182315; step 1
# 9:  |F(x)| = 0.000666296; step 1
# 10:  |F(x)| = 0.000111803; step 1
# 11:  |F(x)| = 0.000154539; step 1
# 12:  |F(x)| = 3.21291e-05; step 1
# 13:  |F(x)| = 1.53779e-05; step 1
# 14:  |F(x)| = 1.01386e-05; step 1
# 15:  |F(x)| = 1.06966e-06; step 1
# scipy solver converged in 17 iterations.
# 0:  |F(x)| = 162.428; step 1
# 1:  |F(x)| = 36.9416; step 1
# 2:  |F(x)| = 25.8452; step 1
# 3:  |F(x)| = 10.9038; step 1
# 4:  |F(x)| = 6.25875; step 1
# 5:  |F(x)| = 9.74495; step 1
# 6:  |F(x)| = 6.85281; step 1
# 7:  |F(x)| = 1.84304; step 1
# 8:  |F(x)| = 1.37561; step 1
# 9:  |F(x)| = 1.43479; step 1
# 10:  |F(x)| = 0.539892; step 1
# 11:  |F(x)| = 0.170859; step 1
# 12:  |F(x)| = 0.204897; step 0.21106
# 13:  |F(x)| = 0.24183; step 0.276423
# 14:  |F(x)| = 0.295916; step 1
# 15:  |F(x)| = 0.136415; step 1
# 16:  |F(x)| = 0.0332523; step 1
# 17:  |F(x)| = 0.0280355; step 0.180832
# 18:  |F(x)| = 0.0283205; step 0.118049
# 19:  |F(x)| = 0.0315728; step 0.0985944
# 20:  |F(x)| = 0.0345433; step 0.101496
# 21:  |F(x)| = 0.0376397; step 0.129464
# 22:  |F(x)| = 0.0414496; step 0.215422
# 23:  |F(x)| = 0.0499715; step 1
# 24:  |F(x)| = 0.0245224; step 1
# 25:  |F(x)| = 0.00641927; step 1
# 26:  |F(x)| = 0.00610415; step 0.473527
# 27:  |F(x)| = 0.0079351; step 1
# 28:  |F(x)| = 0.00429051; step 1
# 29:  |F(x)| = 0.000992626; step 1
# 30:  |F(x)| = 0.000781095; step 0.273757
# 31:  |F(x)| = 0.000729858; step 0.146134
# 32:  |F(x)| = 0.000835359; step 0.105856
# 33:  |F(x)| = 0.000915326; step 0.0966427
# 34:  |F(x)| = 0.000990261; step 0.10921
# 35:  |F(x)| = 0.00107479; step 0.156699
# 36:  |F(x)| = 0.00118355; step 0.311643
# 37:  |F(x)| = 0.00120793; step 1
# 38:  |F(x)| = 0.000508168; step 1
# 39:  |F(x)| = 0.000134145; step 1
# 40:  |F(x)| = 0.000140395; step 0.237034
# 41:  |F(x)| = 0.000153995; step 0.251985
# 42:  |F(x)| = 0.00018411; step 0.437808
# 43:  |F(x)| = 0.000176437; step 1
# 44:  |F(x)| = 6.78588e-05; step 1
# 45:  |F(x)| = 2.47645e-05; step 1
# 46:  |F(x)| = 2.52536e-05; step 0.429476
# 47:  |F(x)| = 3.15395e-05; step 1
# 48:  |F(x)| = 1.36717e-05; step 1
# 49:  |F(x)| = 3.4264e-06; step 1
# scipy solver converged in 51 iterations.
# 0:  |F(x)| = 129.234; step 1
# 1:  |F(x)| = 30.015; step 1
# 2:  |F(x)| = 19.2824; step 1
# 3:  |F(x)| = 5.69982; step 1
# 4:  |F(x)| = 6.22552; step 1
# 5:  |F(x)| = 6.51691; step 0.191857
# 6:  |F(x)| = 6.84225; step 1
# 7:  |F(x)| = 3.41821; step 1
# 8:  |F(x)| = 0.807776; step 1
# 9:  |F(x)| = 1.08088; step 1
# 10:  |F(x)| = 0.758702; step 1
# 11:  |F(x)| = 0.184302; step 1
# 12:  |F(x)| = 0.108993; step 0.496142
# 13:  |F(x)| = 0.0967228; step 0.267317
# ...
# 6200 21.69143277072306 	Loss(validation) = 24.352774428213586
# 6300 22.001668851079113 	Loss(validation) = 24.918231351765826
# 6400 21.24033847961446 	Loss(validation) = 23.94327775177749
# 6500 21.003260564370894 	Loss(validation) = 23.74122144805667
# 6600 20.779987726282496 	Loss(validation) = 23.54381670254083
# 6700 20.69036558912338 	Loss(validation) = 23.47887370034564
# 6800 20.385936750091734 	Loss(validation) = 23.216114758916525
# 6900 20.189175721097296 	Loss(validation) = 23.051000014941852
# 7000 20.04481133463828 	Loss(validation) = 22.971201373555186
# 7100 19.846285639771782 	Loss(validation) = 22.784033360521228
# 7200 19.677147005792623 	Loss(validation) = 22.652255890835324
# 7300 19.580811080030465 	Loss(validation) = 22.570249523501573
# 7400 19.3978173745356 	Loss(validation) = 22.45539646550675
# 7500 19.25847830945659 	Loss(validation) = 22.357233842085975
# 7600 28.535387112026577 	Loss(validation) = 22.381432726680323
# 7700 19.024504317557025 	Loss(validation) = 22.21279635833892
# 7800 18.911246901122333 	Loss(validation) = 22.138825935943316
# 7900 51.40040419159827 	Loss(validation) = 71.0501167051454
# 8000 18.728276983795638 	Loss(validation) = 22.042244787674065
# 8100 18.63471168370226 	Loss(validation) = 21.988399626348393
# 8200 18.550084841353822 	Loss(validation) = 21.945764688104784
# 8300 18.521982221464505 	Loss(validation) = 21.96895818558121
# 8400 18.41549817043861 	Loss(validation) = 21.887737579916063
# 8500 18.348355717788266 	Loss(validation) = 21.859637665390757
# 8600 18.37471845790092 	Loss(validation) = 22.206990886212402
# 8700 18.242314946954476 	Loss(validation) = 21.822408791975572
# 8800 18.1885196105348 	Loss(validation) = 21.80424147950768
# 8900 29.271969668428643 	Loss(validation) = 71.70290445705318
# 9000 18.107041973947744 	Loss(validation) = 21.787622698525354
# 9100 18.062454928632114 	Loss(validation) = 21.771145364541553
# 9200 18.021087340346778 	Loss(validation) = 21.762673945499017
# 9300 41.725495595815595 	Loss(validation) = 60.60568065656147
# 9400 17.961840236179157 	Loss(validation) = 21.756078223022968
# 9500 17.921936509757913 	Loss(validation) = 21.74809044483409
# 9600 17.888773873260128 	Loss(validation) = 21.746066601293755
# 9700 24.789742497887936 	Loss(validation) = 36.255152747244495
# 9800 17.83669887505901 	Loss(validation) = 21.746639912423475
# 9900 17.807503511020755 	Loss(validation) = 21.74750555798578
# 10000 17.780593175853795 	Loss(validation) = 21.751199203843022
# 10100 17.794985431098365 	Loss(validation) = 21.781257387046086
# 10200 17.736541320965358 	Loss(validation) = 21.760591046962716
# 10300 17.712404569712707 	Loss(validation) = 21.767811113739373
# 10400 17.91436393164169 	Loss(validation) = 22.048452842256246
# 10500 17.67353350289772 	Loss(validation) = 21.784380234135764
# 10600 17.652011995854345 	Loss(validation) = 21.79452783783819
# 10700 17.76502832200711 	Loss(validation) = 21.81930600069106
# 10800 17.617605955070232 	Loss(validation) = 21.81742387578723
# 10900 17.598273246748057 	Loss(validation) = 21.8303202451008
# 11000 17.877196881016463 	Loss(validation) = 21.927881369752527
# 11100 17.568328381562573 	Loss(validation) = 21.8582606903502
# 11200 17.550966404855 	Loss(validation) = 21.873464676397838
# 11300 18.71755654318958 	Loss(validation) = 24.743261780964524
# 11400 17.523281193916553 	Loss(validation) = 21.904398163212846
# 11500 17.507357721582757 	Loss(validation) = 21.921275799925
# 11600 24.620653951457818 	Loss(validation) = 40.74268200570033
# 11700 17.48478037590286 	Loss(validation) = 21.954302116078946
# 11800 17.47015957592196 	Loss(validation) = 21.97379865102178
# 11900 17.455971478464644 	Loss(validation) = 21.992111804089596
# 12000 27.570805739726744 	Loss(validation) = 24.026435089681502
# 12100 17.434609667330843 	Loss(validation) = 22.025323803071622
# 12200 17.42134611499965 	Loss(validation) = 22.04647984294252
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 prnn_trainer.train()
#
# File ~/Desktop/MLniCS/tutorials/17_Greedy_PDNN_PINN/../../mlnics/Training.py:210, in PRNNTrainer.train(self)
#     205 """
#     206 Function for getting training and validation sets to pass to
#     207 _normalize_and_train which then performs the training.
#     208 """
#     209 train_snap, validation_snap, train_no_snap, val_no_snap = self.data.train_validation_split()
# --> 210 return self._normalize_and_train(train_snap, validation_snap, train_no_snap, val_no_snap)
#
# File ~/Desktop/MLniCS/tutorials/17_Greedy_PDNN_PINN/../../mlnics/Training.py:110, in RONNTrainer._normalize_and_train(self, train_snap, validation_snap, train_no_snap, validation_no_snap)
#     108 for e in range(starting_epoch, starting_epoch + self.num_epochs):
#     109     coeff_pred = self.ronn(train_normalized)
# --> 110     loss = self.loss_fn(prediction_snap=coeff_pred[:num_train_snaps],
#     111                         prediction_no_snap=coeff_pred[num_train_snaps:],
#     112                         input_normalization=self.input_normalization,
#     113                         normalized_mu=train_normalized[num_train_snaps:])
#     115     self.optimizer.zero_grad()
#     116     loss.backward()
#
# File ~/Desktop/MLniCS/tutorials/17_Greedy_PDNN_PINN/../../mlnics/Losses.py:273, in PRNN_Loss.__call__(self, **kwargs)
#     271 self.value = dict()
#     272 self.value["pdnn_loss"] = self.pdnn_loss(**kwargs)
# --> 273 self.value["pinn_loss"] = self.pinn_loss(**kwargs)
#     274 self.value["loss"] = self.value["pinn_loss"] + self.omega * self.value["pdnn_loss"]
#     276 return self.value["loss"]
#
# File ~/Desktop/MLniCS/tutorials/17_Greedy_PDNN_PINN/../../mlnics/Losses.py:129, in PINN_Loss.__call__(self, **kwargs)
#     127 #print("Assembly time:", end_time - start_time)
#     128 start_time = time.time()
# --> 129 thetas = np.array(self.ronn.reduced_problem.compute_theta('c'))
#     130 end_time = time.time()
#     131 #print("Compute theta time:", end_time - start_time)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/problems/base/parametrized_reduced_differential_problem.py:676, in ParametrizedReducedDifferentialProblem.compute_theta(self, term)
#     669 def compute_theta(self, term):
#     670     """
#     671     Return theta multiplicative terms of the affine expansion of the problem.
#     672
#     673     :param term: the forms of the class of the problem.
#     674     :return: computed thetas.
#     675     """
# --> 676     return self.truth_problem.compute_theta(term)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/backends/offline_online_class_method.py:25, in OfflineOnlineClassMethod.<locals>._OfflineOnlineClassMethod.__call__(self, term)
#      23 def __call__(self, term):
#      24     if self._replacement_condition[_OfflineOnlineClassMethod_Base._current_stage](term):
# ---> 25         return self._content[_OfflineOnlineClassMethod_Base._current_stage](term)
#      26     else:
#      27         return self._original_class_method(term)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/problems/deim_decorated_problem.py:211, in DEIMDecoratedProblem.<locals>.DEIMDecoratedProblem_Decorator.<locals>.DEIMDecoratedProblem_Class._compute_theta_DEIM(self, term)
#     208     if self._N_DEIM is not None:
#     209         N_DEIM = self._N_DEIM[term][q]
#     210     deim_thetas_q = [v * original_thetas[q]
# --> 211                      for v in deim_approximation.compute_interpolated_theta(N_DEIM)]
#     212     deim_thetas.extend(deim_thetas_q)
#     213 # Append forms which did not require DEIM, if applicable
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/problems/eim_approximation.py:142, in EIMApproximation.compute_interpolated_theta(self, N)
#     141 def compute_interpolated_theta(self, N=None):
# --> 142     interpolated_theta = self.solve(N)
#     143     interpolated_theta_list = list()
#     144     for theta in interpolated_theta:
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/problems/eim_approximation.py:112, in EIMApproximation.solve(self, N)
#     109 if N is None:
#     110     N = self.N
# --> 112 self._solve(self.parametrized_expression, N)
#     113 return self._interpolation_coefficients
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/problems/eim_approximation.py:123, in EIMApproximation._solve(self, rhs_, N)
#     120 self._interpolation_coefficients = OnlineFunction(N)
#     122 # Evaluate the parametrized expression at interpolation locations
# --> 123 rhs = evaluate(rhs_, self.interpolation_locations[:N])
#     125 (max_abs_rhs, _) = max(abs(rhs))
#     126 if max_abs_rhs == 0.:
#     127     # If the rhs is zero, then we are interpolating the zero function
#     128     # and the default zero coefficients are enough.
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/utils/decorators/dispatch.py:150, in Dispatcher.__call__(self, *args, **kwargs)
#     148 def __call__(self, *args, **kwargs):
#     149     func = self._get_func(*args)
# --> 150     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/dolfin/evaluate.py:68, in evaluate(expression, at, **kwargs)
#      64 @backend_for("dolfin", inputs=((Matrix.Type(), Vector.Type(), Function.Type(), Operator, TensorsList,
#      65                                 FunctionsList, ParametrizedTensorFactory, ParametrizedExpressionFactory),
#      66                                (ReducedMesh, ReducedVertices, None)))
#      67 def evaluate(expression, at=None, **kwargs):
# ---> 68     return _evaluate(expression, at, **kwargs)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/utils/decorators/dispatch.py:150, in Dispatcher.__call__(self, *args, **kwargs)
#     148 def __call__(self, *args, **kwargs):
#     149     func = self._get_func(*args)
# --> 150     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/dolfin/evaluate.py:120, in _evaluate(expression, at, **kwargs)
#     113 @overload
#     114 def _evaluate(
#     115     expression: ParametrizedTensorFactory,
#     116     at: ReducedMesh,
#     117     **kwargs
#     118 ):
#     119     assert len(kwargs) == 0
# --> 120     return evaluate_base(expression, at)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/utils/decorators/dispatch.py:334, in MethodDispatcher.__call__(self, *args, **kwargs)
#     332     args = args[1:]
#     333 func = self._get_func(*args)
# --> 334 return func(obj, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/basic/evaluate.py:68, in evaluate.<locals>._Evaluate.__call__(self, parametrized_tensor, at)
#      65 @overload(backend.ParametrizedTensorFactory, backend.ReducedMesh)
#      66 def __call__(self, parametrized_tensor, at):
#      67     # Efficient version, assemblying only on the reduced mesh
# ---> 68     (assembled_form, form_rank) = wrapping.form_on_reduced_function_space(parametrized_tensor, at)
#      69     assert form_rank in (1, 2)
#      70     if form_rank == 2:
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/dolfin/wrapping/form_on_reduced_function_space.py:433, in basic_form_on_reduced_function_space.<locals>._basic_form_on_reduced_function_space(form_wrapper, at)
#     430             backend.assign(solution_dot_to, solution_dot_from)
#     432 # Assemble and return
# --> 433 assembled_replaced_form = wrapping.assemble(replaced_form_with_replaced_measures)
#     434 if not isinstance(assembled_replaced_form, Number):
#     435     form_rank = assembled_replaced_form.rank()
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/dolfin/wrapping/assemble.py:11, in assemble(form, tensor)
#      10 def assemble(form, tensor=None):
# ---> 11     return dolfin_assemble(form, keep_diagonal=True, tensor=tensor)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/fem/assembling.py:198, in assemble(form, tensor, form_compiler_parameters, add_values, finalize_tensor, keep_diagonal, backend)
#     196     dolfin_form = form
#     197 else:
# --> 198     dolfin_form = _create_dolfin_form(form, form_compiler_parameters)
#     200 # Create tensor
#     201 comm = dolfin_form.mesh().mpi_comm()
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/fem/assembling.py:56, in _create_dolfin_form(form, form_compiler_parameters, function_spaces)
#      54     return form
#      55 elif isinstance(form, ufl.Form):
# ---> 56     return Form(form,
#      57                 form_compiler_parameters=form_compiler_parameters,
#      58                 function_spaces=function_spaces)
#      59 else:
#      60     raise TypeError("Invalid form type %s" % (type(form),))
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/fem/form.py:43, in Form.__init__(self, form, **kwargs)
#      40 if form_compiler_parameters is None:
#      41     form_compiler_parameters = {"external_include_dirs": dolfin_pc["include_dirs"]}
# ---> 43 ufc_form = ffc_jit(form, form_compiler_parameters=form_compiler_parameters,
#      44                    mpi_comm=mesh.mpi_comm())
#      45 ufc_form = cpp.fem.make_ufc_form(ufc_form[0])
#      47 function_spaces = kwargs.get("function_spaces")
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/jit/jit.py:47, in mpi_jit_decorator.<locals>.mpi_jit(*args, **kwargs)
#      45 # Just call JIT compiler when running in serial
#      46 if MPI.size(mpi_comm) == 1:
# ---> 47     return local_jit(*args, **kwargs)
#      49 # Default status (0 == ok, 1 == fail)
#      50 status = 0
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/jit/jit.py:97, in ffc_jit(ufl_form, form_compiler_parameters)
#      95 p.update(dict(parameters["form_compiler"]))
#      96 p.update(form_compiler_parameters or {})
# ---> 97 return ffc.jit(ufl_form, parameters=p)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/ffc/jitcompiler.py:214, in jit(ufl_object, parameters, indirect)
#     211 set_prefix(parameters["log_prefix"])
#     213 # Make unique module name for generated code
# --> 214 kind, module_name = compute_jit_prefix(ufl_object, parameters)
#     216 # Inspect cache and generate+build if necessary
#     217 module = jit_build(ufl_object, module_name, parameters)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/ffc/jitcompiler.py:159, in compute_jit_prefix(ufl_object, parameters, kind)
#     156     error("Unknown ufl object type %s" % (ufl_object.__class__.__name__,))
#     158 # Compute deterministic string of relevant parameters
# --> 159 parameters_signature = compute_jit_parameters_signature(parameters)
#     161 # Increase this number at any time to invalidate cache
#     162 # signatures if code generation has changed in important
#     163 # ways without the change being visible in regular signatures:
#     164 jit_version_bump = 3
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/ffc/parameters.py:195, in compute_jit_parameters_signature(parameters)
#     185     # This doesn't work because some parameters may not be among the defaults above.
#     186     # That is somewhat confusing but we'll just have to live with it at least for now.
#     187     # sp = split_parameters(parameters)
#     188     # p = {}
#     189     # p.update(sp["generate"])
#     190     # p.update(sp["build"])
#     192     return p
# --> 195 def compute_jit_parameters_signature(parameters):
#     196     "Return parameters signature (some parameters must be ignored)."
#     197     from ufl.utils.sorting import canonicalize_metadata
#
# KeyboardInterrupt:

# %%
fig, ax = Training.plot_loss(prnn_trainer, prnn_net, separate=True)

# %% [markdown]
# #### 4.5.4 Train PINN

# %%
input_normalization_pinn = Normalization.MinMaxNormalization(input_normalization=True)
output_normalization_pinn = Normalization.MinMaxNormalization()

pinn_net  = NN.RONN(f"PINN", problem, reduction_method, n_hidden=2, n_neurons=60)
pinn_loss = Losses.PINN_Loss(pinn_net, output_normalization_pinn)
data      = RONNData.RONNDataLoader(pinn_net, validation_proportion=0.2,
                                    num_without_snapshots=225)
optimizer = torch.optim.Adam(pinn_net.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.99999)

pinn_trainer = Training.PINNTrainer(
    pinn_net, data, pinn_loss, optimizer, scheduler,
    input_normalization_pinn, num_epochs=110000
)

loaded, starting_epoch = IO.initialize_parameters(
    pinn_net, data, pinn_trainer, optimizer
)

# %%
pinn_trainer.train()
# Out:
# Operator 'bt_restricted' not implemented. Continuing without operator 'bt_restricted'...
# 0:  |F(x)| = 230.188; step 0.52013
# 1:  |F(x)| = 85.7699; step 1
# 2:  |F(x)| = 70.1531; step 1
# 3:  |F(x)| = 47.8735; step 1
# 4:  |F(x)| = 36.5895; step 1
# 5:  |F(x)| = 9.00799; step 1
# 6:  |F(x)| = 5.60883; step 0.376707
# 7:  |F(x)| = 5.5232; step 0.0368869
# 8:  |F(x)| = 5.50161; step 0.01
# 9:  |F(x)| = 11.7914; step 1
# 10:  |F(x)| = 13.9515; step 1
# 11:  |F(x)| = 6.69339; step 1
# 12:  |F(x)| = 2.919; step 1
# 13:  |F(x)| = 1.95092; step 1
# 14:  |F(x)| = 1.80532; step 1
# 15:  |F(x)| = 1.20813; step 1
# 16:  |F(x)| = 0.28085; step 1
# 17:  |F(x)| = 0.241089; step 0.228341
# 18:  |F(x)| = 0.237702; step 0.0334672
# 19:  |F(x)| = 0.236744; step 0.01
# 20:  |F(x)| = 0.490879; step 1
# 21:  |F(x)| = 0.526813; step 1
# 22:  |F(x)| = 0.240061; step 1
# 23:  |F(x)| = 0.0867269; step 1
# 24:  |F(x)| = 0.0885357; step 1
# 25:  |F(x)| = 0.0844863; step 1
# 26:  |F(x)| = 0.0581582; step 1
# 27:  |F(x)| = 0.0117444; step 1
# 28:  |F(x)| = 0.0104048; step 0.350718
# 29:  |F(x)| = 0.0116017; step 0.388861
# 30:  |F(x)| = 0.0120505; step 0.518614
# 31:  |F(x)| = 0.0130862; step 1
# 32:  |F(x)| = 0.00768141; step 1
# 33:  |F(x)| = 0.00176034; step 1
# 34:  |F(x)| = 0.00138042; step 0.311389
# 35:  |F(x)| = 0.00127705; step 0.0897482
# 36:  |F(x)| = 0.00124514; step 0.0284997
# 37:  |F(x)| = 0.00123406; step 0.01
# 38:  |F(x)| = 0.00323813; step 1
# 39:  |F(x)| = 0.00312376; step 1
# 40:  |F(x)| = 0.00173902; step 1
# 41:  |F(x)| = 0.000548035; step 1
# 42:  |F(x)| = 0.000501067; step 1
# 43:  |F(x)| = 0.000466979; step 1
# 44:  |F(x)| = 0.000272975; step 1
# 45:  |F(x)| = 6.90065e-05; step 1
# 46:  |F(x)| = 5.06021e-05; step 0.418703
# 47:  |F(x)| = 5.45323e-05; step 0.204121
# 48:  |F(x)| = 5.61409e-05; step 0.14022
# 49:  |F(x)| = 5.68787e-05; step 0.125871
# 50:  |F(x)| = 5.89926e-05; step 0.143911
# 51:  |F(x)| = 6.63705e-05; step 0.215097
# 52:  |F(x)| = 7.59652e-05; step 0.460225
# 53:  |F(x)| = 7.25833e-05; step 1
# 54:  |F(x)| = 3.61463e-05; step 1
# 55:  |F(x)| = 9.50535e-06; step 1
# 56:  |F(x)| = 8.50934e-06; step 0.136098
# 57:  |F(x)| = 8.07374e-06; step 0.0623886
# 58:  |F(x)| = 8.02733e-06; step 0.0307191
# 59:  |F(x)| = 8.06205e-06; step 0.0156483
# 60:  |F(x)| = 8.08322e-06; step 0.01
# 61:  |F(x)| = 1.6559e-05; step 1
# 62:  |F(x)| = 1.58182e-05; step 1
# 63:  |F(x)| = 8.67712e-06; step 1
# 64:  |F(x)| = 2.99482e-06; step 1
# scipy solver converged in 66 iterations.
# 0:  |F(x)| = 16.0193; step 1
# 1:  |F(x)| = 3.43811; step 1
# 2:  |F(x)| = 0.934208; step 1
# 3:  |F(x)| = 1.09529; step 1
# 4:  |F(x)| = 0.600099; step 1
# 5:  |F(x)| = 0.090375; step 1
# 6:  |F(x)| = 0.086584; step 1
# 7:  |F(x)| = 0.0511331; step 1
# 8:  |F(x)| = 0.00862761; step 1
# 9:  |F(x)| = 0.0123766; step 1
# 10:  |F(x)| = 0.00554873; step 1
# 11:  |F(x)| = 0.00104029; step 1
# 12:  |F(x)| = 0.00110175; step 0.390117
# 13:  |F(x)| = 0.00135611; step 1
# 14:  |F(x)| = 0.0003976; step 1
# 15:  |F(x)| = 0.000127393; step 1
# 16:  |F(x)| = 0.000146233; step 1
# 17:  |F(x)| = 3.26002e-05; step 1
# 18:  |F(x)| = 2.16632e-05; step 1
# 19:  |F(x)| = 1.80335e-05; step 1
# 20:  |F(x)| = 2.96788e-06; step 1
# scipy solver converged in 22 iterations.
# 0:  |F(x)| = 254.789; step 0.344771
# 1:  |F(x)| = 147.492; step 1
# 2:  |F(x)| = 54.3811; step 1
# 3:  |F(x)| = 42.5256; step 1
# 4:  |F(x)| = 32.0089; step 1
# 5:  |F(x)| = 7.61122; step 1
# 6:  |F(x)| = 4.11334; step 0.461179
# 7:  |F(x)| = 4.06119; step 0.0522096
# 8:  |F(x)| = 4.04783; step 0.0145615
# 9:  |F(x)| = 9.2694; step 1
# 10:  |F(x)| = 9.9618; step 1
# 11:  |F(x)| = 4.60119; step 1
# 12:  |F(x)| = 1.68584; step 1
# 13:  |F(x)| = 1.67381; step 1
# 14:  |F(x)| = 1.47225; step 1
# 15:  |F(x)| = 0.693119; step 1
# 16:  |F(x)| = 0.176245; step 1
# 17:  |F(x)| = 0.443778; step 1
# 18:  |F(x)| = 0.403174; step 1
# 19:  |F(x)| = 0.163741; step 1
# 20:  |F(x)| = 0.0631735; step 1
# 21:  |F(x)| = 0.0626691; step 0.4515
# 22:  |F(x)| = 0.0648934; step 0.458765
# 23:  |F(x)| = 0.073261; step 1
# 24:  |F(x)| = 0.0398698; step 1
# 25:  |F(x)| = 0.0118544; step 1
# 26:  |F(x)| = 0.0127106; step 1
# 27:  |F(x)| = 0.01374; step 1
# 28:  |F(x)| = 0.0067792; step 1
# 29:  |F(x)| = 0.00175192; step 1
# 30:  |F(x)| = 0.0015017; step 0.180072
# 31:  |F(x)| = 0.00151681; step 0.0832532
# 32:  |F(x)| = 0.00154018; step 0.0441148
# 33:  |F(x)| = 0.00155196; step 0.025233
# 34:  |F(x)| = 0.00155848; step 0.0150905
# 35:  |F(x)| = 0.0015626; step 0.01
# 36:  |F(x)| = 0.00156659; step 0.01
# 37:  |F(x)| = 0.00349178; step 1
# 38:  |F(x)| = 0.00285623; step 1
# 39:  |F(x)| = 0.00119903; step 1
# 40:  |F(x)| = 0.000473152; step 1
# 41:  |F(x)| = 0.00048117; step 0.495181
# 42:  |F(x)| = 0.000577015; step 1
# 43:  |F(x)| = 0.000367159; step 1
# 44:  |F(x)| = 0.000103128; step 1
# 45:  |F(x)| = 9.48968e-05; step 1
# 46:  |F(x)| = 0.000125773; step 1
# 47:  |F(x)| = 7.46937e-05; step 1
# 48:  |F(x)| = 1.82542e-05; step 1
# 49:  |F(x)| = 1.28587e-05; step 0.450902
# 50:  |F(x)| = 1.32993e-05; step 0.169442
# 51:  |F(x)| = 1.35219e-05; step 0.0882963
# 52:  |F(x)| = 1.36158e-05; step 0.0566732
# 53:  |F(x)| = 1.36636e-05; step 0.0417188
# 54:  |F(x)| = 1.36905e-05; step 0.0339695
# 55:  |F(x)| = 1.37059e-05; step 0.0300015
# 56:  |F(x)| = 1.37138e-05; step 0.0284382
# 57:  |F(x)| = 1.37156e-05; step 0.0287954
# 58:  |F(x)| = 1.37108e-05; step 0.0311389
# 59:  |F(x)| = 1.36973e-05; step 0.0360888
# 60:  |F(x)| = 1.41588e-05; step 0.0452105
# 61:  |F(x)| = 1.47622e-05; step 0.0622012
# 62:  |F(x)| = 1.55988e-05; step 0.0965547
# 63:  |F(x)| = 1.68638e-05; step 0.177369
# 64:  |F(x)| = 1.87557e-05; step 0.418412
# 65:  |F(x)| = 1.79822e-05; step 1
# 66:  |F(x)| = 9.06815e-06; step 1
# 67:  |F(x)| = 2.64054e-06; step 1
# scipy solver converged in 69 iterations.
# 0:  |F(x)| = 354.489; step 0.452776
# 1:  |F(x)| = 241.589; step 1
# 2:  |F(x)| = 123.284; step 1
# 3:  |F(x)| = 90.4534; step 1
# 4:  |F(x)| = 80.0585; step 1
# 5:  |F(x)| = 27.9656; step 1
# 6:  |F(x)| = 10.6268; step 0.496797
# 7:  |F(x)| = 8.47511; step 0.414665
# 8:  |F(x)| = 7.30544; step 0.186723
# 9:  |F(x)| = 6.82897; step 0.0785903
# 10:  |F(x)| = 6.68011; step 0.0349948
# 11:  |F(x)| = 6.7312; step 0.0161103
# 12:  |F(x)| = 6.7617; step 0.01
# 13:  |F(x)| = 15.6113; step 1
# 14:  |F(x)| = 15.3107; step 1
# 15:  |F(x)| = 8.75416; step 1
# 16:  |F(x)| = 3.45167; step 1
# 17:  |F(x)| = 2.45197; step 1
# 18:  |F(x)| = 1.81008; step 1
# 19:  |F(x)| = 0.697897; step 1
# 20:  |F(x)| = 0.260739; step 1
# 21:  |F(x)| = 0.259664; step 0.0402074
# 22:  |F(x)| = 0.627095; step 1
# 23:  |F(x)| = 0.681714; step 1
# 24:  |F(x)| = 0.423307; step 1
# 25:  |F(x)| = 0.200796; step 1
# 26:  |F(x)| = 0.0752512; step 1
# 27:  |F(x)| = 0.0797609; step 1
# 28:  |F(x)| = 0.0507142; step 1
# 29:  |F(x)| = 0.0145829; step 1
# 30:  |F(x)| = 0.0112843; step 1
# 31:  |F(x)| = 0.0143499; step 1
# 32:  |F(x)| = 0.00872594; step 1
# 33:  |F(x)| = 0.00569673; step 1
# 34:  |F(x)| = 0.00330218; step 1
# 35:  |F(x)| = 0.00278193; step 1
# 36:  |F(x)| = 0.00303916; step 0.247703
# 37:  |F(x)| = 0.00314001; step 0.120674
# 38:  |F(x)| = 0.00318757; step 0.0993867
# 39:  |F(x)| = 0.00321565; step 0.117187
# 40:  |F(x)| = 0.003216; step 0.203538
# 41:  |F(x)| = 0.00288077; step 1
# 42:  |F(x)| = 0.00142849; step 1
# 43:  |F(x)| = 0.000865398; step 1
# 44:  |F(x)| = 0.000338878; step 1
# 45:  |F(x)| = 0.000362759; step 1
# 46:  |F(x)| = 0.000105412; step 1
# 47:  |F(x)| = 0.000104871; step 0.0610557
# 48:  |F(x)| = 0.000104647; step 0.0202066
# 49:  |F(x)| = 0.00010453; step 0.01
# 50:  |F(x)| = 0.00014059; step 1
# 51:  |F(x)| = 9.96208e-05; step 1
# 52:  |F(x)| = 0.000121844; step 1
# 53:  |F(x)| = 4.3119e-05; step 1
# 54:  |F(x)| = 4.05179e-05; step 0.303111
# 55:  |F(x)| = 2.24518e-05; step 1
# 56:  |F(x)| = 8.88669e-06; step 1
# 57:  |F(x)| = 7.39175e-06; step 0.246202
# 58:  |F(x)| = 7.87365e-06; step 0.446426
# 59:  |F(x)| = 6.46159e-06; step 1
# 60:  |F(x)| = 5.56102e-06; step 0.499493
# scipy solver converged in 62 iterations.
# 0:  |F(x)| = 358.318; step 0.451421
# 1:  |F(x)| = 246.214; step 1
# 2:  |F(x)| = 124.944; step 1
# 3:  |F(x)| = 91.5434; step 1
# 4:  |F(x)| = 81.2461; step 1
# 5:  |F(x)| = 28.7825; step 1
# 6:  |F(x)| = 10.7734; step 0.497664
# 7:  |F(x)| = 8.54563; step 0.424824
# 8:  |F(x)| = 7.32726; step 0.192011
# 9:  |F(x)| = 6.83349; step 0.0806721
# 10:  |F(x)| = 6.75943; step 0.0359742
# 11:  |F(x)| = 6.81044; step 0.0166142
# 12:  |F(x)| = 6.83991; step 0.01
# 13:  |F(x)| = 15.6885; step 1
# 14:  |F(x)| = 15.3195; step 1
# 15:  |F(x)| = 8.7765; step 1
# 16:  |F(x)| = 3.46079; step 1
# 17:  |F(x)| = 2.46233; step 1
# 18:  |F(x)| = 1.8038; step 1
# 19:  |F(x)| = 0.671191; step 1
# 20:  |F(x)| = 0.261391; step 1
# 21:  |F(x)| = 0.260996; step 0.0181281
# 22:  |F(x)| = 0.634119; step 1
# 23:  |F(x)| = 0.688877; step 1
# 24:  |F(x)| = 0.431692; step 1
# 25:  |F(x)| = 0.206642; step 1
# 26:  |F(x)| = 0.0761965; step 1
# 27:  |F(x)| = 0.0802957; step 1
# 28:  |F(x)| = 0.0498281; step 1
# 29:  |F(x)| = 0.0146336; step 1
# 30:  |F(x)| = 0.0108259; step 1
# 31:  |F(x)| = 0.0142174; step 1
# 32:  |F(x)| = 0.00866416; step 1
# 33:  |F(x)| = 0.00574457; step 1
# 34:  |F(x)| = 0.00325704; step 1
# 35:  |F(x)| = 0.00274891; step 1
# 36:  |F(x)| = 0.00300893; step 0.239744
# 37:  |F(x)| = 0.00310758; step 0.109595
# 38:  |F(x)| = 0.003154; step 0.0815571
# 39:  |F(x)| = 0.0031839; step 0.0819512
# 40:  |F(x)| = 0.00320408; step 0.108898
# 41:  |F(x)| = 0.00319946; step 0.20495
# 42:  |F(x)| = 0.00285252; step 1
# 43:  |F(x)| = 0.00143902; step 1
# 44:  |F(x)| = 0.000866743; step 1
# 45:  |F(x)| = 0.000342037; step 1
# 46:  |F(x)| = 0.000357223; step 1
# 47:  |F(x)| = 0.000111377; step 1
# 48:  |F(x)| = 0.000111257; step 0.01
# 49:  |F(x)| = 0.000146342; step 1
# 50:  |F(x)| = 9.98396e-05; step 1
# 51:  |F(x)| = 0.000127906; step 1
# 52:  |F(x)| = 4.4974e-05; step 1
# 53:  |F(x)| = 4.32272e-05; step 0.281743
# 54:  |F(x)| = 2.59757e-05; step 1
# 55:  |F(x)| = 9.87554e-06; step 1
# 56:  |F(x)| = 8.35999e-06; step 0.231268
# 57:  |F(x)| = 7.7425e-06; step 0.280709
# 58:  |F(x)| = 6.99965e-06; step 1
# 59:  |F(x)| = 5.79669e-06; step 0.355866
# scipy solver converged in 61 iterations.
# 0:  |F(x)| = 213.169; step 0.374088
# 1:  |F(x)| = 104.008; step 1
# 2:  |F(x)| = 44.151; step 1
# 3:  |F(x)| = 31.5722; step 1
# 4:  |F(x)| = 22.6212; step 1
# 5:  |F(x)| = 5.85107; step 1
# 6:  |F(x)| = 3.98358; step 0.394783
# 7:  |F(x)| = 3.96881; step 0.01
# 8:  |F(x)| = 7.77872; step 1
# 9:  |F(x)| = 7.98929; step 1
# 10:  |F(x)| = 3.24492; step 1
# 11:  |F(x)| = 1.36284; step 1
# 12:  |F(x)| = 1.53722; step 1
# 13:  |F(x)| = 1.17488; step 1
# 14:  |F(x)| = 0.462717; step 1
# 15:  |F(x)| = 0.207847; step 1
# 16:  |F(x)| = 0.377362; step 1
# 17:  |F(x)| = 0.293885; step 1
# 18:  |F(x)| = 0.089776; step 1
# 19:  |F(x)| = 0.0566744; step 1
# 20:  |F(x)| = 0.0554123; step 0.376418
# 21:  |F(x)| = 0.0731142; step 1
# 22:  |F(x)| = 0.0421858; step 1
# 23:  |F(x)| = 0.0126853; step 1
# 24:  |F(x)| = 0.0118811; step 1
# 25:  |F(x)| = 0.0137239; step 1
# 26:  |F(x)| = 0.00718292; step 1
# 27:  |F(x)| = 0.00180822; step 1
# 28:  |F(x)| = 0.0014687; step 0.251978
# 29:  |F(x)| = 0.00151129; step 0.12782
# 30:  |F(x)| = 0.0015452; step 0.0800708
# 31:  |F(x)| = 0.00156358; step 0.0579027
# 32:  |F(x)| = 0.00157507; step 0.046589
# 33:  |F(x)| = 0.00158295; step 0.0408942
# 34:  |F(x)| = 0.00161196; step 0.0387631
# 35:  |F(x)| = 0.00166979; step 0.0395388
# 36:  |F(x)| = 0.00172938; step 0.0434489
# 37:  |F(x)| = 0.00179542; step 0.0518193
# 38:  |F(x)| = 0.00187457; step 0.0681175
# 39:  |F(x)| = 0.00197818; step 0.101571
# 40:  |F(x)| = 0.0021271; step 0.181786
# 41:  |F(x)| = 0.00234045; step 0.437309
# 42:  |F(x)| = 0.0021484; step 1
# 43:  |F(x)| = 0.000998707; step 1
# 44:  |F(x)| = 0.000293714; step 1
# 45:  |F(x)| = 0.00031956; step 0.43615
# 46:  |F(x)| = 0.000309762; step 0.467565
# 47:  |F(x)| = 0.000370445; step 1
# 48:  |F(x)| = 0.000200536; step 1
# 49:  |F(x)| = 5.38659e-05; step 1
# 50:  |F(x)| = 4.76279e-05; step 0.44864
# 51:  |F(x)| = 4.9404e-05; step 0.342257
# 52:  |F(x)| = 5.46545e-05; step 0.481534
# 53:  |F(x)| = 5.73148e-05; step 1
# 54:  |F(x)| = 2.74243e-05; step 1
# 55:  |F(x)| = 7.23102e-06; step 1
# 56:  |F(x)| = 6.3758e-06; step 0.151145
# 57:  |F(x)| = 6.4604e-06; step 0.0368708
# 58:  |F(x)| = 1.44011e-05; step 1
# 59:  |F(x)| = 1.21815e-05; step 1
# 60:  |F(x)| = 5.16337e-06; step 1
# scipy solver converged in 62 iterations.
# 0:  |F(x)| = 97.447; step 0.494224
# 1:  |F(x)| = 20.9546; step 1
# 2:  |F(x)| = 21.2038; step 1
# 3:  |F(x)| = 9.27722; step 1
# 4:  |F(x)| = 3.44517; step 1
# 5:  |F(x)| = 1.77125; step 0.51956
# 6:  |F(x)| = 1.57905; step 0.119605
# 7:  |F(x)| = 1.51758; step 0.0408136
# 8:  |F(x)| = 1.4951; step 0.015266
# 9:  |F(x)| = 1.48049; step 0.01
# 10:  |F(x)| = 3.85813; step 1
# 11:  |F(x)| = 2.90331; step 1
# 12:  |F(x)| = 1.0304; step 1
# 13:  |F(x)| = 0.504535; step 1
# 14:  |F(x)| = 0.622198; step 1
# 15:  |F(x)| = 0.362649; step 1
# 16:  |F(x)| = 0.0841299; step 1
# 17:  |F(x)| = 0.0636428; step 0.343635
# 18:  |F(x)| = 0.0578558; step 0.185699
# 19:  |F(x)| = 0.0658878; step 0.144106
# 20:  |F(x)| = 0.0748702; step 0.151149
# 21:  |F(x)| = 0.0843156; step 0.217503
# 22:  |F(x)| = 0.0953934; step 0.476915
# 23:  |F(x)| = 0.0827127; step 1
# 24:  |F(x)| = 0.0293262; step 1
# 25:  |F(x)| = 0.011317; step 1
# 26:  |F(x)| = 0.0122684; step 0.12262
# 27:  |F(x)| = 0.0136441; step 0.154265
# 28:  |F(x)| = 0.0152919; step 0.261684
# 29:  |F(x)| = 0.017724; step 1
# 30:  |F(x)| = 0.00887814; step 1
# 31:  |F(x)| = 0.00238481; step 1
# 32:  |F(x)| = 0.00231919; step 0.495689
# 33:  |F(x)| = 0.00293879; step 1
# 34:  |F(x)| = 0.00170561; step 1
# 35:  |F(x)| = 0.000389385; step 1
# 36:  |F(x)| = 0.000298836; step 0.317959
# 37:  |F(x)| = 0.000262594; step 0.140952
# 38:  |F(x)| = 0.000266766; step 0.0821036
# 39:  |F(x)| = 0.000288236; step 0.0567444
# 40:  |F(x)| = 0.000303539; step 0.0442624
# 41:  |F(x)| = 0.000315742; step 0.0379759
# 42:  |F(x)| = 0.000326393; step 0.035367
# 43:  |F(x)| = 0.000336456; step 0.035569
# 44:  |F(x)| = 0.000346697; step 0.0386281
# 45:  |F(x)| = 0.000357929; step 0.0456042
# 46:  |F(x)| = 0.00037128; step 0.0593934
# 47:  |F(x)| = 0.000388653; step 0.0877933
# 48:  |F(x)| = 0.000413593; step 0.155783
# 49:  |F(x)| = 0.000450237; step 0.373259
# 50:  |F(x)| = 0.000420936; step 1
# 51:  |F(x)| = 0.000173704; step 1
# 52:  |F(x)| = 5.37141e-05; step 1
# 53:  |F(x)| = 5.55038e-05; step 0.274956
# 54:  |F(x)| = 5.99074e-05; step 0.325209
# 55:  |F(x)| = 7.69748e-05; step 1
# 56:  |F(x)| = 3.9503e-05; step 1
# 57:  |F(x)| = 1.04234e-05; step 1
# 58:  |F(x)| = 9.4966e-06; step 0.445169
# 59:  |F(x)| = 9.63984e-06; step 0.459661
# 60:  |F(x)| = 1.14524e-05; step 1
# 61:  |F(x)| = 5.06231e-06; step 1
# scipy solver converged in 63 iterations.
# 0:  |F(x)| = 211.624; step 0.53493
# 1:  |F(x)| = 65.5301; step 1
# 2:  |F(x)| = 63.1815; step 1
# 3:  |F(x)| = 41.1964; step 1
# 4:  |F(x)| = 30.154; step 1
# 5:  |F(x)| = 7.89721; step 1
# 6:  |F(x)| = 5.78457; step 0.314046
# 7:  |F(x)| = 5.74463; step 0.0146212
# 8:  |F(x)| = 11.1732; step 1
# 9:  |F(x)| = 13.0093; step 1
# 10:  |F(x)| = 5.87129; step 1
# 11:  |F(x)| = 2.55848; step 1
# 12:  |F(x)| = 2.04224; step 1
# 13:  |F(x)| = 1.75236; step 1
# 14:  |F(x)| = 1.0854; step 1
# 15:  |F(x)| = 0.266861; step 1
# 16:  |F(x)| = 0.244158; step 0.151091
# 17:  |F(x)| = 0.239993; step 0.0372033
# 18:  |F(x)| = 0.238734; step 0.0119129
# 19:  |F(x)| = 0.477405; step 1
# 20:  |F(x)| = 0.499232; step 1
# 21:  |F(x)| = 0.212245; step 1
# 22:  |F(x)| = 0.0776873; step 1
# 23:  |F(x)| = 0.0968757; step 1
# 24:  |F(x)| = 0.0855365; step 1
# 25:  |F(x)| = 0.0533101; step 1
# 26:  |F(x)| = 0.0116269; step 1
# 27:  |F(x)| = 0.0106186; step 0.313469
# 28:  |F(x)| = 0.0123198; step 0.354185
# 29:  |F(x)| = 0.0125053; step 0.519042
# 30:  |F(x)| = 0.0136571; step 1
# 31:  |F(x)| = 0.00758706; step 1
# 32:  |F(x)| = 0.0018217; step 1
# 33:  |F(x)| = 0.00146726; step 0.271202
# 34:  |F(x)| = 0.00135099; step 0.0947791
# 35:  |F(x)| = 0.00130655; step 0.0374181
# 36:  |F(x)| = 0.00128826; step 0.0156161
# 37:  |F(x)| = 0.00129209; step 0.01
# 38:  |F(x)| = 0.00336577; step 1
# 39:  |F(x)| = 0.00306979; step 1
# 40:  |F(x)| = 0.00156585; step 1
# 41:  |F(x)| = 0.000464932; step 1
# 42:  |F(x)| = 0.000505872; step 1
# 43:  |F(x)| = 0.000515967; step 1
# 44:  |F(x)| = 0.00026956; step 1
# 45:  |F(x)| = 7.36699e-05; step 1
# 46:  |F(x)| = 6.71397e-05; step 0.377492
# 47:  |F(x)| = 7.03148e-05; step 0.255534
# 48:  |F(x)| = 7.04305e-05; step 0.269979
# 49:  |F(x)| = 8.44168e-05; step 0.453574
# 50:  |F(x)| = 8.65245e-05; step 1
# 51:  |F(x)| = 4.46185e-05; step 1
# 52:  |F(x)| = 1.1594e-05; step 1
# 53:  |F(x)| = 9.65546e-06; step 0.306501
# 54:  |F(x)| = 9.73179e-06; step 0.0304306
# 55:  |F(x)| = 9.77093e-06; step 0.0171988
# 56:  |F(x)| = 9.79242e-06; step 0.01
# 57:  |F(x)| = 9.81318e-06; step 0.01
# 58:  |F(x)| = 1.97347e-05; step 1
# 59:  |F(x)| = 1.77051e-05; step 1
# 60:  |F(x)| = 8.87454e-06; step 1
# 61:  |F(x)| = 2.76384e-06; step 1
# scipy solver converged in 63 iterations.
# 0:  |F(x)| = 5.21142; step 1
# 1:  |F(x)| = 0.723494; step 1
# 2:  |F(x)| = 0.29741; step 1
# 3:  |F(x)| = 0.256372; step 1
# 4:  |F(x)| = 0.054933; step 1
# 5:  |F(x)| = 0.0166704; step 1
# 6:  |F(x)| = 0.0131936; step 1
# 7:  |F(x)| = 0.00160722; step 1
# 8:  |F(x)| = 0.00199645; step 1
# 9:  |F(x)| = 0.000782768; step 1
# 10:  |F(x)| = 0.000118739; step 1
# 11:  |F(x)| = 0.000176947; step 1
# 12:  |F(x)| = 4.1038e-05; step 1
# 13:  |F(x)| = 1.64679e-05; step 1
# 14:  |F(x)| = 1.21508e-05; step 1
# 15:  |F(x)| = 1.28285e-06; step 1
# scipy solver converged in 17 iterations.
# 0:  |F(x)| = 360.356; step 0.450705
# 1:  |F(x)| = 248.69; step 1
# 2:  |F(x)| = 125.835; step 1
# 3:  |F(x)| = 92.1233; step 1
# 4:  |F(x)| = 81.8799; step 1
# 5:  |F(x)| = 29.2212; step 1
# 6:  |F(x)| = 10.8514; step 0.498109
# 7:  |F(x)| = 8.58283; step 0.430214
# 8:  |F(x)| = 7.33835; step 0.194807
# 9:  |F(x)| = 6.83546; step 0.0817605
# 10:  |F(x)| = 6.801; step 0.0364869
# 11:  |F(x)| = 6.85192; step 0.0168792
# 12:  |F(x)| = 6.88085; step 0.01
# 13:  |F(x)| = 15.729; step 1
# 14:  |F(x)| = 15.3244; step 1
# 15:  |F(x)| = 8.78845; step 1
# 16:  |F(x)| = 3.46594; step 1
# 17:  |F(x)| = 2.46772; step 1
# 18:  |F(x)| = 1.80051; step 1
# 19:  |F(x)| = 0.670672; step 1
# 20:  |F(x)| = 0.261806; step 1
# 21:  |F(x)| = 0.261615; step 0.01
# 22:  |F(x)| = 0.638249; step 1
# 23:  |F(x)| = 0.691769; step 1
# 24:  |F(x)| = 0.435394; step 1
# 25:  |F(x)| = 0.209038; step 1
# 26:  |F(x)| = 0.0767563; step 1
# 27:  |F(x)| = 0.0803696; step 1
# 28:  |F(x)| = 0.0491906; step 1
# 29:  |F(x)| = 0.0146092; step 1
# 30:  |F(x)| = 0.0105458; step 1
# 31:  |F(x)| = 0.0141174; step 1
# 32:  |F(x)| = 0.00858612; step 1
# 33:  |F(x)| = 0.00573328; step 1
# 34:  |F(x)| = 0.00321389; step 1
# 35:  |F(x)| = 0.0027156; step 1
# 36:  |F(x)| = 0.00299304; step 0.233089
# 37:  |F(x)| = 0.00308945; step 0.103588
# 38:  |F(x)| = 0.00313455; step 0.0732756
# 39:  |F(x)| = 0.00316368; step 0.0680666
# 40:  |F(x)| = 0.00318559; step 0.0800222
# 41:  |F(x)| = 0.00319922; step 0.122314
# 42:  |F(x)| = 0.00317048; step 0.272275
# 43:  |F(x)| = 0.00267459; step 1
# 44:  |F(x)| = 0.00136938; step 1
# 45:  |F(x)| = 0.000793166; step 1
# 46:  |F(x)| = 0.000347548; step 1
# 47:  |F(x)| = 0.000318364; step 1
# 48:  |F(x)| = 0.000113758; step 1
# 49:  |F(x)| = 0.000141196; step 1
# 50:  |F(x)| = 0.000106002; step 1
# 51:  |F(x)| = 0.000117967; step 1
# 52:  |F(x)| = 4.59953e-05; step 1
# 53:  |F(x)| = 4.14482e-05; step 0.350491
# 54:  |F(x)| = 1.98419e-05; step 1
# 55:  |F(x)| = 8.80628e-06; step 1
# 56:  |F(x)| = 8.21656e-06; step 0.311361
# 57:  |F(x)| = 6.86332e-06; step 1
# 58:  |F(x)| = 5.74455e-06; step 0.390833
# scipy solver converged in 60 iterations.
# 0:  |F(x)| = 6.83273; step 1
# 1:  |F(x)| = 1.12181; step 1
# 2:  |F(x)| = 0.415984; step 1
# 3:  |F(x)| = 0.398502; step 1
# 4:  |F(x)| = 0.113174; step 1
# 5:  |F(x)| = 0.0176635; step 1
# 6:  |F(x)| = 0.0243603; step 1
# 7:  |F(x)| = 0.00430168; step 1
# 8:  |F(x)| = 0.00319746; step 1
# 9:  |F(x)| = 0.00191803; step 1
# 10:  |F(x)| = 0.000221005; step 1
# 11:  |F(x)| = 0.000173721; step 0.489397
# 12:  |F(x)| = 0.000261078; step 1
# 13:  |F(x)| = 6.7932e-05; step 1
# 14:  |F(x)| = 2.34531e-05; step 1
# 15:  |F(x)| = 2.06408e-05; step 1
# 16:  |F(x)| = 2.71863e-06; step 1
# scipy solver converged in 18 iterations.
# 0:  |F(x)| = 211.94; step 0.375032
# 1:  |F(x)| = 102.817; step 1
# 2:  |F(x)| = 43.8715; step 1
# 3:  |F(x)| = 31.2693; step 1
# 4:  |F(x)| = 22.36; step 1
# 5:  |F(x)| = 5.80548; step 1
# 6:  |F(x)| = 3.97678; step 0.392219
# 7:  |F(x)| = 3.96191; step 0.01
# 8:  |F(x)| = 7.73608; step 1
# 9:  |F(x)| = 7.92447; step 1
# 10:  |F(x)| = 3.20235; step 1
# 11:  |F(x)| = 1.35623; step 1
# 12:  |F(x)| = 1.53109; step 1
# 13:  |F(x)| = 1.1644; step 1
# 14:  |F(x)| = 0.454786; step 1
# 15:  |F(x)| = 0.209172; step 1
# 16:  |F(x)| = 0.375089; step 1
# 17:  |F(x)| = 0.290344; step 1
# 18:  |F(x)| = 0.087548; step 1
# 19:  |F(x)| = 0.0564144; step 1
# 20:  |F(x)| = 0.0557463; step 0.377877
# 21:  |F(x)| = 0.0725119; step 1
# 22:  |F(x)| = 0.0414814; step 1
# 23:  |F(x)| = 0.0124239; step 1
# 24:  |F(x)| = 0.0119419; step 1
# 25:  |F(x)| = 0.0135956; step 1
# 26:  |F(x)| = 0.00702837; step 1
# 27:  |F(x)| = 0.00178012; step 1
# 28:  |F(x)| = 0.00145602; step 0.241751
# 29:  |F(x)| = 0.00151472; step 0.124811
# 30:  |F(x)| = 0.00154749; step 0.0793379
# 31:  |F(x)| = 0.00156544; step 0.0581672
# 32:  |F(x)| = 0.00157674; step 0.047486
# 33:  |F(x)| = 0.00158451; step 0.0423683
# 34:  |F(x)| = 0.00162695; step 0.0409428
# 35:  |F(x)| = 0.00168823; step 0.0427404
# 36:  |F(x)| = 0.00175286; step 0.0483708
# 37:  |F(x)| = 0.00182657; step 0.0599597
# 38:  |F(x)| = 0.00191811; step 0.0831315
# 39:  |F(x)| = 0.00204315; step 0.134221
# 40:  |F(x)| = 0.00222791; step 0.273653
# 41:  |F(x)| = 0.00243557; step 1
# 42:  |F(x)| = 0.00132592; step 1
# 43:  |F(x)| = 0.000353566; step 1
# 44:  |F(x)| = 0.000316763; step 0.512599
# 45:  |F(x)| = 0.000317028; step 0.414537
# 46:  |F(x)| = 0.000406343; step 1
# 47:  |F(x)| = 0.000251915; step 1
# 48:  |F(x)| = 7.09752e-05; step 1
# 49:  |F(x)| = 6.87114e-05; step 1
# 50:  |F(x)| = 8.50038e-05; step 1
# 51:  |F(x)| = 4.66705e-05; step 1
# 52:  |F(x)| = 1.16886e-05; step 1
# 53:  |F(x)| = 8.81216e-06; step 0.344565
# 54:  |F(x)| = 9.11253e-06; step 0.128826
# 55:  |F(x)| = 9.2456e-06; step 0.0646789
# 56:  |F(x)| = 9.30683e-06; step 0.0385393
# 57:  |F(x)| = 9.34068e-06; step 0.0255161
# 58:  |F(x)| = 9.36169e-06; step 0.0181261
# 59:  |F(x)| = 9.37583e-06; step 0.0135361
# 60:  |F(x)| = 9.38589e-06; step 0.0105001
# 61:  |F(x)| = 9.39482e-06; step 0.01
# 62:  |F(x)| = 1.80007e-05; step 1
# 63:  |F(x)| = 1.36329e-05; step 1
# 64:  |F(x)| = 4.86465e-06; step 1
# scipy solver converged in 66 iterations.
# 0:  |F(x)| = 0.232918; step 1
# 1:  |F(x)| = 0.0087781; step 1
# 2:  |F(x)| = 0.0053904; step 1
# 3:  |F(x)| = 0.000645346; step 1
# 4:  |F(x)| = 0.000155353; step 1
# 5:  |F(x)| = 3.75027e-05; step 1
# 6:  |F(x)| = 5.37653e-06; step 1
# scipy solver converged in 8 iterations.
# 0:  |F(x)| = 2.77167; step 1
# 1:  |F(x)| = 0.256344; step 1
# 2:  |F(x)| = 0.149637; step 1
# 3:  |F(x)| = 0.0850935; step 1
# 4:  |F(x)| = 0.00707727; step 1
# 5:  |F(x)| = 0.007454; step 1
# 6:  |F(x)| = 0.00255082; step 1
# 7:  |F(x)| = 0.00043514; step 1
# 8:  |F(x)| = 0.000455129; step 1
# 9:  |F(x)| = 5.06999e-05; step 1
# 10:  |F(x)| = 5.1246e-05; step 1
# 11:  |F(x)| = 2.03958e-05; step 1
# 12:  |F(x)| = 2.07493e-06; step 1
# scipy solver converged in 14 iterations.
# 0:  |F(x)| = 6.98954; step 1
# 1:  |F(x)| = 1.16352; step 1
# 2:  |F(x)| = 0.427595; step 1
# 3:  |F(x)| = 0.413055; step 1
# 4:  |F(x)| = 0.119932; step 1
# 5:  |F(x)| = 0.0174169; step 1
# 6:  |F(x)| = 0.0255767; step 1
# 7:  |F(x)| = 0.00475604; step 1
# 8:  |F(x)| = 0.00330336; step 1
# 9:  |F(x)| = 0.00205782; step 1
# 10:  |F(x)| = 0.000232009; step 1
# 11:  |F(x)| = 0.00018338; step 0.497046
# 12:  |F(x)| = 0.000277432; step 1
# 13:  |F(x)| = 7.49319e-05; step 1
# 14:  |F(x)| = 2.40698e-05; step 1
# 15:  |F(x)| = 2.23047e-05; step 1
# 16:  |F(x)| = 3.2002e-06; step 1
# scipy solver converged in 18 iterations.
# 0:  |F(x)| = 88.0138; step 1
# 1:  |F(x)| = 20.9665; step 1
# 2:  |F(x)| = 11.1183; step 1
# 3:  |F(x)| = 2.95061; step 1
# 4:  |F(x)| = 2.43385; step 0.38775
# 5:  |F(x)| = 2.24632; step 0.153562
# 6:  |F(x)| = 2.32434; step 0.0879623
# 7:  |F(x)| = 2.464; step 0.063542
# 8:  |F(x)| = 2.56977; step 0.0544898
# 9:  |F(x)| = 2.66375; step 0.0542396
# 10:  |F(x)| = 2.75994; step 0.0626929
# 11:  |F(x)| = 2.87338; step 0.0862214
# 12:  |F(x)| = 3.02862; step 0.150642
# 13:  |F(x)| = 3.25239; step 0.394409
# 14:  |F(x)| = 2.82074; step 1
# 15:  |F(x)| = 1.06159; step 1
# 16:  |F(x)| = 0.345469; step 1
# 17:  |F(x)| = 0.407147; step 1
# 18:  |F(x)| = 0.197298; step 1
# 19:  |F(x)| = 0.0478512; step 1
# 20:  |F(x)| = 0.0451633; step 0.350164
# 21:  |F(x)| = 0.057853; step 0.40225
# 22:  |F(x)| = 0.06026; step 1
# 23:  |F(x)| = 0.0196079; step 1
# 24:  |F(x)| = 0.00973685; step 1
# 25:  |F(x)| = 0.0102683; step 0.0994911
# 26:  |F(x)| = 0.0109757; step 0.17324
# 27:  |F(x)| = 0.0118905; step 0.433597
# 28:  |F(x)| = 0.00994969; step 1
# 29:  |F(x)| = 0.00322076; step 1
# 30:  |F(x)| = 0.00139675; step 1
# 31:  |F(x)| = 0.00163722; step 1
# 32:  |F(x)| = 0.000658635; step 1
# 33:  |F(x)| = 0.00019598; step 1
# 34:  |F(x)| = 0.000239169; step 0.210069
# 35:  |F(x)| = 0.000273557; step 0.277867
# 36:  |F(x)| = 0.000310299; step 1
# 37:  |F(x)| = 0.000122694; step 1
# 38:  |F(x)| = 2.91374e-05; step 1
# 39:  |F(x)| = 3.34647e-05; step 0.193049
# 40:  |F(x)| = 3.93182e-05; step 0.23707
# 41:  |F(x)| = 4.50584e-05; step 0.477947
# 42:  |F(x)| = 3.75275e-05; step 1
# 43:  |F(x)| = 1.06985e-05; step 1
# 44:  |F(x)| = 5.45154e-06; step 1
# scipy solver converged in 46 iterations.
# 0:  |F(x)| = 7.71263; step 1
# 1:  |F(x)| = 1.36259; step 1
# 2:  |F(x)| = 0.481308; step 1
# 3:  |F(x)| = 0.481563; step 1
# 4:  |F(x)| = 0.153628; step 1
# 5:  |F(x)| = 0.0193139; step 1
# 6:  |F(x)| = 0.0314383; step 1
# 7:  |F(x)| = 0.00716949; step 1
# 8:  |F(x)| = 0.00374293; step 1
# 9:  |F(x)| = 0.00277028; step 1
# 10:  |F(x)| = 0.000297907; step 1
# 11:  |F(x)| = 0.000491473; step 1
# 12:  |F(x)| = 0.000242927; step 1
# 13:  |F(x)| = 3.05624e-05; step 1
# 14:  |F(x)| = 2.39462e-05; step 0.485394
# 15:  |F(x)| = 3.23466e-05; step 1
# 16:  |F(x)| = 6.93395e-06; step 1
# 17:  |F(x)| = 3.92574e-06; step 1
# scipy solver converged in 19 iterations.
# 0:  |F(x)| = 264.604; step 0.338521
# 1:  |F(x)| = 158.622; step 1
# 2:  |F(x)| = 57.0407; step 1
# 3:  |F(x)| = 45.296; step 1
# 4:  |F(x)| = 34.365; step 1
# 5:  |F(x)| = 8.09205; step 1
# 6:  |F(x)| = 4.28783; step 0.47209
# 7:  |F(x)| = 4.09966; step 0.0688394
# 8:  |F(x)| = 4.04464; step 0.019685
# 9:  |F(x)| = 4.03391; step 0.01
# 10:  |F(x)| = 9.64058; step 1
# 11:  |F(x)| = 10.3339; step 1
# 12:  |F(x)| = 4.86559; step 1
# 13:  |F(x)| = 1.78471; step 1
# 14:  |F(x)| = 1.68747; step 1
# 15:  |F(x)| = 1.52047; step 1
# 16:  |F(x)| = 0.728562; step 1
# 17:  |F(x)| = 0.179176; step 1
# 18:  |F(x)| = 0.45748; step 1
# 19:  |F(x)| = 0.424257; step 1
# 20:  |F(x)| = 0.179018; step 1
# 21:  |F(x)| = 0.064276; step 1
# 22:  |F(x)| = 0.0644906; step 0.479711
# 23:  |F(x)| = 0.0653056; step 0.463753
# 24:  |F(x)| = 0.0750295; step 1
# 25:  |F(x)| = 0.0415588; step 1
# 26:  |F(x)| = 0.0124864; step 1
# 27:  |F(x)| = 0.0127048; step 1
# 28:  |F(x)| = 0.0140807; step 1
# 29:  |F(x)| = 0.00712888; step 1
# 30:  |F(x)| = 0.00181383; step 1
# 31:  |F(x)| = 0.00153621; step 0.196406
# 32:  |F(x)| = 0.00148655; step 0.0844194
# 33:  |F(x)| = 0.00151087; step 0.0415007
# 34:  |F(x)| = 0.00152237; step 0.0218894
# 35:  |F(x)| = 0.00152829; step 0.0119925
# 36:  |F(x)| = 0.00153306; step 0.01
# 37:  |F(x)| = 0.00357006; step 1
# 38:  |F(x)| = 0.00299923; step 1
# 39:  |F(x)| = 0.00132047; step 1
# 40:  |F(x)| = 0.000475986; step 1
# 41:  |F(x)| = 0.000493914; step 0.523781
# 42:  |F(x)| = 0.000581301; step 1
# 43:  |F(x)| = 0.00037883; step 1
# 44:  |F(x)| = 0.000106928; step 1
# 45:  |F(x)| = 9.29005e-05; step 1
# 46:  |F(x)| = 0.00012833; step 1
# 47:  |F(x)| = 7.8609e-05; step 1
# 48:  |F(x)| = 1.8951e-05; step 1
# 49:  |F(x)| = 1.30875e-05; step 0.486874
# 50:  |F(x)| = 1.33133e-05; step 0.174425
# 51:  |F(x)| = 1.35393e-05; step 0.0855965
# 52:  |F(x)| = 1.36315e-05; step 0.0514032
# 53:  |F(x)| = 1.36779e-05; step 0.0350226
# 54:  |F(x)| = 1.37044e-05; step 0.0260209
# 55:  |F(x)| = 1.3721e-05; step 0.0206155
# 56:  |F(x)| = 1.37318e-05; step 0.017176
# 57:  |F(x)| = 1.37393e-05; step 0.0149307
# 58:  |F(x)| = 1.37444e-05; step 0.0134562
# 59:  |F(x)| = 1.37478e-05; step 0.0125265
# 60:  |F(x)| = 1.375e-05; step 0.012013
# 61:  |F(x)| = 1.37511e-05; step 0.0118562
# 62:  |F(x)| = 1.37511e-05; step 0.0120319
# 63:  |F(x)| = 1.375e-05; step 0.0125577
# 64:  |F(x)| = 1.37476e-05; step 0.0134951
# 65:  |F(x)| = 1.37435e-05; step 0.0149546
# 66:  |F(x)| = 1.3737e-05; step 0.0171425
# 67:  |F(x)| = 1.37417e-05; step 0.020412
# 68:  |F(x)| = 1.4011e-05; step 0.0254073
# 69:  |F(x)| = 1.43502e-05; step 0.033384
# 70:  |F(x)| = 1.4801e-05; step 0.0469755
# 71:  |F(x)| = 1.54399e-05; step 0.0724249
# 72:  |F(x)| = 1.6414e-05; step 0.127051
# 73:  |F(x)| = 1.79707e-05; step 0.270585
# 74:  |F(x)| = 2.00486e-05; step 1
# 75:  |F(x)| = 1.15469e-05; step 1
# 76:  |F(x)| = 3.47311e-06; step 1
# scipy solver converged in 78 iterations.
# 0:  |F(x)| = 28.0805; step 1
# 1:  |F(x)| = 6.48593; step 1
# 2:  |F(x)| = 1.74997; step 1
# 3:  |F(x)| = 1.65786; step 1
# 4:  |F(x)| = 1.41398; step 1
# 5:  |F(x)| = 0.44062; step 1
# 6:  |F(x)| = 0.109829; step 1
# 7:  |F(x)| = 0.152573; step 1
# 8:  |F(x)| = 0.0420915; step 1
# 9:  |F(x)| = 0.022234; step 1
# 10:  |F(x)| = 0.0232741; step 1
# 11:  |F(x)| = 0.00546938; step 1
# 12:  |F(x)| = 0.00407342; step 1
# 13:  |F(x)| = 0.00393871; step 1
# 14:  |F(x)| = 0.00107589; step 1
# 15:  |F(x)| = 0.000463253; step 1
# 16:  |F(x)| = 0.0005102; step 1
# 17:  |F(x)| = 0.000123969; step 1
# 18:  |F(x)| = 8.29197e-05; step 1
# 19:  |F(x)| = 7.97687e-05; step 1
# 20:  |F(x)| = 1.89213e-05; step 1
# 21:  |F(x)| = 1.24976e-05; step 1
# 22:  |F(x)| = 1.20068e-05; step 1
# 23:  |F(x)| = 2.91959e-06; step 1
# scipy solver converged in 25 iterations.
# 0:  |F(x)| = 48.1965; step 1
# 1:  |F(x)| = 11.5306; step 1
# 2:  |F(x)| = 4.07176; step 1
# 3:  |F(x)| = 1.82646; step 1
# 4:  |F(x)| = 2.21917; step 0.415476
# 5:  |F(x)| = 2.27545; step 1
# 6:  |F(x)| = 0.894753; step 1
# 7:  |F(x)| = 0.195254; step 1
# 8:  |F(x)| = 0.280814; step 1
# 9:  |F(x)| = 0.122827; step 1
# 10:  |F(x)| = 0.0285962; step 1
# 11:  |F(x)| = 0.0339831; step 0.420275
# 12:  |F(x)| = 0.040237; step 1
# 13:  |F(x)| = 0.0124159; step 1
# 14:  |F(x)| = 0.00624447; step 1
# 15:  |F(x)| = 0.00705645; step 0.389327
# 16:  |F(x)| = 0.00641181; step 1
# 17:  |F(x)| = 0.00192655; step 1
# 18:  |F(x)| = 0.000704079; step 1
# 19:  |F(x)| = 0.000942781; step 1
# 20:  |F(x)| = 0.00029758; step 1
# 21:  |F(x)| = 0.000140334; step 1
# 22:  |F(x)| = 0.000163573; step 0.510634
# 23:  |F(x)| = 0.000126046; step 1
# 24:  |F(x)| = 2.45321e-05; step 1
# 25:  |F(x)| = 2.55795e-05; step 1
# 26:  |F(x)| = 2.35884e-05; step 1
# 27:  |F(x)| = 6.39649e-06; step 1
# 28:  |F(x)| = 3.39966e-06; step 1
# scipy solver converged in 30 iterations.
# 0:  |F(x)| = 171.591; step 0.409072
# 1:  |F(x)| = 66.7977; step 1
# 2:  |F(x)| = 35.2575; step 1
# 3:  |F(x)| = 22.0189; step 1
# 4:  |F(x)| = 14.3548; step 1
# 5:  |F(x)| = 4.48013; step 1
# 6:  |F(x)| = 3.65448; step 0.286129
# 7:  |F(x)| = 3.67562; step 0.0292506
# 8:  |F(x)| = 3.70707; step 0.010832
# 9:  |F(x)| = 6.36399; step 1
# 10:  |F(x)| = 5.7683; step 1
# 11:  |F(x)| = 1.87275; step 1
# 12:  |F(x)| = 1.11921; step 1
# 13:  |F(x)| = 1.27227; step 1
# 14:  |F(x)| = 0.800541; step 1
# 15:  |F(x)| = 0.237392; step 1
# 16:  |F(x)| = 0.237525; step 1
# 17:  |F(x)| = 0.261954; step 0.466311
# 18:  |F(x)| = 0.236052; step 1
# 19:  |F(x)| = 0.103252; step 1
# 20:  |F(x)| = 0.0309068; step 1
# 21:  |F(x)| = 0.0325795; step 0.230075
# 22:  |F(x)| = 0.0328689; step 0.207861
# 23:  |F(x)| = 0.0364634; step 0.26984
# 24:  |F(x)| = 0.0478666; step 1
# 25:  |F(x)| = 0.0280154; step 1
# 26:  |F(x)| = 0.00802628; step 1
# 27:  |F(x)| = 0.00785218; step 1
# 28:  |F(x)| = 0.00881412; step 1
# 29:  |F(x)| = 0.00419657; step 1
# 30:  |F(x)| = 0.00110887; step 1
# 31:  |F(x)| = 0.000989962; step 0.194285
# 32:  |F(x)| = 0.00102601; step 0.112437
# 33:  |F(x)| = 0.00104347; step 0.0804187
# 34:  |F(x)| = 0.0010536; step 0.0672494
# 35:  |F(x)| = 0.00111334; step 0.0641853
# 36:  |F(x)| = 0.00117857; step 0.0695183
# 37:  |F(x)| = 0.00125011; step 0.086305
# 38:  |F(x)| = 0.00133876; step 0.126628
# 39:  |F(x)| = 0.00146194; step 0.235161
# 40:  |F(x)| = 0.00169178; step 1
# 41:  |F(x)| = 0.000921248; step 1
# 42:  |F(x)| = 0.000239415; step 1
# 43:  |F(x)| = 0.000205338; step 0.469671
# 44:  |F(x)| = 0.000209384; step 0.346999
# 45:  |F(x)| = 0.000227841; step 0.465987
# 46:  |F(x)| = 0.000243398; step 1
# 47:  |F(x)| = 0.000118238; step 1
# 48:  |F(x)| = 3.31591e-05; step 1
# 49:  |F(x)| = 3.37894e-05; step 0.393909
# 50:  |F(x)| = 3.3949e-05; step 0.385931
# 51:  |F(x)| = 4.44091e-05; step 1
# 52:  |F(x)| = 2.4731e-05; step 1
# 53:  |F(x)| = 6.0071e-06; step 1
# scipy solver converged in 55 iterations.
# 0:  |F(x)| = 0.0123306; step 1
# 1:  |F(x)| = 0.000265494; step 1
# 2:  |F(x)| = 6.49523e-05; step 1
# 3:  |F(x)| = 1.8771e-06; step 1
# scipy solver converged in 5 iterations.
# 0:  |F(x)| = 309.071; step 0.469968
# 1:  |F(x)| = 189.081; step 1
# 2:  |F(x)| = 104.88; step 1
# 3:  |F(x)| = 77.4656; step 1
# 4:  |F(x)| = 66.2504; step 1
# 5:  |F(x)| = 18.974; step 1
# 6:  |F(x)| = 8.88192; step 0.482432
# 7:  |F(x)| = 7.57015; step 0.291037
# 8:  |F(x)| = 6.93115; step 0.121562
# 9:  |F(x)| = 6.66447; step 0.0506881
# 10:  |F(x)| = 6.55043; step 0.0217827
# 11:  |F(x)| = 6.49822; step 0.01
# 12:  |F(x)| = 14.5826; step 1
# 13:  |F(x)| = 15.2989; step 1
# 14:  |F(x)| = 8.5298; step 1
# 15:  |F(x)| = 3.41552; step 1
# 16:  |F(x)| = 2.30978; step 1
# 17:  |F(x)| = 1.90274; step 1
# 18:  |F(x)| = 1.00247; step 1
# 19:  |F(x)| = 0.265237; step 1
# 20:  |F(x)| = 0.242729; step 0.23546
# 21:  |F(x)| = 0.567706; step 1
# 22:  |F(x)| = 0.575021; step 0.145981
# 23:  |F(x)| = 0.578136; step 1
# 24:  |F(x)| = 0.319066; step 1
# 25:  |F(x)| = 0.121484; step 1
# 26:  |F(x)| = 0.070267; step 1
# 27:  |F(x)| = 0.0658106; step 1
# 28:  |F(x)| = 0.0515935; step 1
# 29:  |F(x)| = 0.0119912; step 1
# 30:  |F(x)| = 0.00897494; step 0.465304
# 31:  |F(x)| = 0.00733207; step 0.504037
# 32:  |F(x)| = 0.00811447; step 0.510391
# 33:  |F(x)| = 0.00911218; step 1
# 34:  |F(x)| = 0.00564848; step 1
# 35:  |F(x)| = 0.00105619; step 1
# 36:  |F(x)| = 0.00087623; step 0.260676
# 37:  |F(x)| = 0.000865635; step 0.0274913
# 38:  |F(x)| = 0.00266123; step 1
# 39:  |F(x)| = 0.00306264; step 1
# 40:  |F(x)| = 0.00221024; step 1
# 41:  |F(x)| = 0.0010923; step 1
# 42:  |F(x)| = 0.000471161; step 1
# 43:  |F(x)| = 0.000375622; step 1
# 44:  |F(x)| = 0.000213638; step 1
# 45:  |F(x)| = 7.23204e-05; step 1
# 46:  |F(x)| = 7.51881e-05; step 1
# 47:  |F(x)| = 0.000101533; step 1
# 48:  |F(x)| = 7.95345e-05; step 1
# 49:  |F(x)| = 4.01974e-05; step 1
# 50:  |F(x)| = 1.16098e-05; step 1
# 51:  |F(x)| = 1.10872e-05; step 1
# 52:  |F(x)| = 1.2974e-05; step 1
# 53:  |F(x)| = 8.88983e-06; step 1
# 54:  |F(x)| = 4.00171e-06; step 1
# scipy solver converged in 56 iterations.
# 0:  |F(x)| = 55.726; step 1
# 1:  |F(x)| = 13.3746; step 1
# 2:  |F(x)| = 5.15645; step 1
# 3:  |F(x)| = 2.08252; step 1
# 4:  |F(x)| = 2.10998; step 0.311945
# 5:  |F(x)| = 2.47004; step 0.424928
# 6:  |F(x)| = 2.27773; step 1
# 7:  |F(x)| = 0.837187; step 1
# 8:  |F(x)| = 0.22506; step 1
# 9:  |F(x)| = 0.294583; step 1
# 10:  |F(x)| = 0.123201; step 1
# 11:  |F(x)| = 0.030092; step 1
# 12:  |F(x)| = 0.0388682; step 0.412428
# 13:  |F(x)| = 0.044496; step 1
# 14:  |F(x)| = 0.0138672; step 1
# 15:  |F(x)| = 0.0070403; step 1
# 16:  |F(x)| = 0.00788181; step 0.317474
# 17:  |F(x)| = 0.00794447; step 1
# 18:  |F(x)| = 0.00276194; step 1
# 19:  |F(x)| = 0.000819787; step 1
# 20:  |F(x)| = 0.00119107; step 1
# 21:  |F(x)| = 0.000461617; step 1
# 22:  |F(x)| = 0.00013288; step 1
# 23:  |F(x)| = 0.000168425; step 0.315523
# 24:  |F(x)| = 0.000203522; step 1
# 25:  |F(x)| = 7.36305e-05; step 1
# 26:  |F(x)| = 2.10115e-05; step 1
# 27:  |F(x)| = 2.57666e-05; step 0.2832
# 28:  |F(x)| = 3.19563e-05; step 1
# 29:  |F(x)| = 1.19249e-05; step 1
# 30:  |F(x)| = 2.91027e-06; step 1
# scipy solver converged in 32 iterations.
# 0:  |F(x)| = 10.3289; step 1
# 1:  |F(x)| = 2.04318; step 1
# 2:  |F(x)| = 0.647949; step 1
# 3:  |F(x)| = 0.70336; step 1
# 4:  |F(x)| = 0.283731; step 1
# 5:  |F(x)| = 0.038161; step 1
# 6:  |F(x)| = 0.0256153; step 0.51807
# 7:  |F(x)| = 0.0341985; step 1
# 8:  |F(x)| = 0.00661162; step 1
# 9:  |F(x)| = 0.00497512; step 1
# 10:  |F(x)| = 0.00337324; step 1
# 11:  |F(x)| = 0.000428637; step 1
# 12:  |F(x)| = 0.000339931; step 0.503066
# 13:  |F(x)| = 0.000380403; step 0.475763
# 14:  |F(x)| = 0.000360281; step 1
# 15:  |F(x)| = 7.68815e-05; step 1
# 16:  |F(x)| = 4.17602e-05; step 1
# 17:  |F(x)| = 3.18417e-05; step 1
# 18:  |F(x)| = 4.1152e-06; step 1
# scipy solver converged in 20 iterations.
# 0:  |F(x)| = 311.148; step 0.311687
# 1:  |F(x)| = 215.784; step 1
# 2:  |F(x)| = 71.2472; step 1
# 3:  |F(x)| = 59.2831; step 1
# 4:  |F(x)| = 46.1715; step 1
# 5:  |F(x)| = 11.207; step 1
# 6:  |F(x)| = 5.86314; step 0.50789
# 7:  |F(x)| = 5.27684; step 0.161542
# 8:  |F(x)| = 5.08422; step 0.0511406
# 9:  |F(x)| = 5.01962; step 0.0171277
# 10:  |F(x)| = 4.98193; step 0.01
# 11:  |F(x)| = 11.4287; step 1
# 12:  |F(x)| = 12.0945; step 1
# 13:  |F(x)| = 6.15463; step 1
# 14:  |F(x)| = 2.28264; step 1
# 15:  |F(x)| = 1.91756; step 1
# 16:  |F(x)| = 1.69687; step 1
# 17:  |F(x)| = 0.858697; step 1
# 18:  |F(x)| = 0.194133; step 1
# 19:  |F(x)| = 0.524276; step 1
# 20:  |F(x)| = 0.521348; step 1
# 21:  |F(x)| = 0.252879; step 1
# 22:  |F(x)| = 0.0782365; step 1
# 23:  |F(x)| = 0.0909364; step 1
# 24:  |F(x)| = 0.0932303; step 1
# 25:  |F(x)| = 0.053887; step 1
# 26:  |F(x)| = 0.0141865; step 1
# 27:  |F(x)| = 0.0134208; step 0.496577
# 28:  |F(x)| = 0.0138431; step 0.525105
# 29:  |F(x)| = 0.0153605; step 1
# 30:  |F(x)| = 0.00893692; step 1
# 31:  |F(x)| = 0.00207357; step 1
# 32:  |F(x)| = 0.00163259; step 0.301314
# 33:  |F(x)| = 0.0015088; step 0.0903878
# 34:  |F(x)| = 0.00146838; step 0.030418
# 35:  |F(x)| = 0.00145431; step 0.0107039
# 36:  |F(x)| = 0.00383334; step 1
# 37:  |F(x)| = 0.00357666; step 1
# 38:  |F(x)| = 0.00187218; step 1
# 39:  |F(x)| = 0.000551612; step 1
# 40:  |F(x)| = 0.00058734; step 1
# 41:  |F(x)| = 0.000585251; step 1
# 42:  |F(x)| = 0.000303909; step 1
# 43:  |F(x)| = 8.30739e-05; step 1
# 44:  |F(x)| = 7.46936e-05; step 0.352564
# 45:  |F(x)| = 7.85076e-05; step 0.229343
# 46:  |F(x)| = 7.93745e-05; step 0.225765
# 47:  |F(x)| = 9.16912e-05; step 0.334823
# 48:  |F(x)| = 0.000108581; step 1
# 49:  |F(x)| = 6.22063e-05; step 1
# 50:  |F(x)| = 1.5287e-05; step 1
# 51:  |F(x)| = 1.0938e-05; step 0.417315
# 52:  |F(x)| = 1.11314e-05; step 0.106943
# 53:  |F(x)| = 1.12011e-05; step 0.026198
# 54:  |F(x)| = 2.32969e-05; step 1
# 55:  |F(x)| = 2.07233e-05; step 1
# 56:  |F(x)| = 1.02191e-05; step 1
# 57:  |F(x)| = 3.20442e-06; step 1
# scipy solver converged in 59 iterations.
# 0:  |F(x)| = 45.8028; step 1
# 1:  |F(x)| = 10.9387; step 1
# 2:  |F(x)| = 3.76223; step 1
# 3:  |F(x)| = 1.78086; step 1
# 4:  |F(x)| = 2.23225; step 0.479145
# 5:  |F(x)| = 2.03052; step 1
# 6:  |F(x)| = 0.712424; step 1
# 7:  |F(x)| = 0.187799; step 1
# 8:  |F(x)| = 0.250852; step 1
# 9:  |F(x)| = 0.0938373; step 1
# 10:  |F(x)| = 0.027362; step 1
# 11:  |F(x)| = 0.0365604; step 0.493716
# 12:  |F(x)| = 0.0320595; step 1
# 13:  |F(x)| = 0.00661752; step 1
# 14:  |F(x)| = 0.00694293; step 1
# 15:  |F(x)| = 0.00672802; step 1
# 16:  |F(x)| = 0.00212377; step 1
# 17:  |F(x)| = 0.000680331; step 1
# 18:  |F(x)| = 0.000980388; step 1
# 19:  |F(x)| = 0.000324159; step 1
# 20:  |F(x)| = 0.000134463; step 1
# 21:  |F(x)| = 0.000159814; step 0.471147
# 22:  |F(x)| = 0.000133047; step 1
# 23:  |F(x)| = 2.95502e-05; step 1
# 24:  |F(x)| = 2.44896e-05; step 1
# 25:  |F(x)| = 2.4206e-05; step 1
# 26:  |F(x)| = 6.99823e-06; step 1
# 27:  |F(x)| = 3.21573e-06; step 1
# scipy solver converged in 29 iterations.
# 0:  |F(x)| = 46.3409; step 1
# 1:  |F(x)| = 11.072; step 1
# 2:  |F(x)| = 3.83112; step 1
# 3:  |F(x)| = 1.77223; step 1
# 4:  |F(x)| = 2.23083; step 0.463174
# 5:  |F(x)| = 2.08749; step 1
# 6:  |F(x)| = 0.753967; step 1
# 7:  |F(x)| = 0.189656; step 1
# 8:  |F(x)| = 0.257878; step 1
# 9:  |F(x)| = 0.100367; step 1
# 10:  |F(x)| = 0.0259895; step 1
# 11:  |F(x)| = 0.0360036; step 0.467007
# 12:  |F(x)| = 0.0342067; step 1
# 13:  |F(x)| = 0.00808387; step 1
# 14:  |F(x)| = 0.00679203; step 1
# 15:  |F(x)| = 0.00714294; step 1
# 16:  |F(x)| = 0.0024407; step 1
# 17:  |F(x)| = 0.000670094; step 1
# 18:  |F(x)| = 0.00103793; step 1
# 19:  |F(x)| = 0.000377069; step 1
# 20:  |F(x)| = 0.000123008; step 1
# 21:  |F(x)| = 0.000152421; step 0.385403
# 22:  |F(x)| = 0.000153992; step 1
# 23:  |F(x)| = 4.4744e-05; step 1
# 24:  |F(x)| = 2.20503e-05; step 1
# 25:  |F(x)| = 2.76212e-05; step 1
# 26:  |F(x)| = 9.84401e-06; step 1
# 27:  |F(x)| = 2.58487e-06; step 1
# scipy solver converged in 29 iterations.
# 0:  |F(x)| = 23.7376; step 1
# 1:  |F(x)| = 5.38412; step 1
# 2:  |F(x)| = 1.34537; step 1
# 3:  |F(x)| = 1.50051; step 1
# 4:  |F(x)| = 1.1074; step 1
# 5:  |F(x)| = 0.285294; step 1
# 6:  |F(x)| = 0.11079; step 1
# 7:  |F(x)| = 0.112847; step 1
# 8:  |F(x)| = 0.0245466; step 1
# 9:  |F(x)| = 0.0201836; step 1
# 10:  |F(x)| = 0.0157953; step 1
# 11:  |F(x)| = 0.0021371; step 1
# 12:  |F(x)| = 0.00347193; step 1
# 13:  |F(x)| = 0.00249525; step 1
# 14:  |F(x)| = 0.000449967; step 1
# 15:  |F(x)| = 0.000416979; step 1
# 16:  |F(x)| = 0.00030274; step 1
# 17:  |F(x)| = 4.83149e-05; step 1
# 18:  |F(x)| = 6.7087e-05; step 1
# 19:  |F(x)| = 4.32851e-05; step 1
# 20:  |F(x)| = 6.62139e-06; step 1
# 21:  |F(x)| = 4.29903e-06; step 0.462559
# scipy solver converged in 23 iterations.
# 0:  |F(x)| = 0.698002; step 1
# 1:  |F(x)| = 0.0325289; step 1
# 2:  |F(x)| = 0.025616; step 1
# 3:  |F(x)| = 0.00604676; step 1
# 4:  |F(x)| = 0.000713141; step 1
# 5:  |F(x)| = 0.000479319; step 1
# 6:  |F(x)| = 3.32835e-05; step 1
# 7:  |F(x)| = 3.86466e-05; step 1
# 8:  |F(x)| = 5.25068e-06; step 1
# scipy solver converged in 10 iterations.
# 0:  |F(x)| = 230.397; step 0.361357
# 1:  |F(x)| = 121.27; step 1
# 2:  |F(x)| = 48.1969; step 1
# 3:  |F(x)| = 35.945; step 1
# 4:  |F(x)| = 26.3829; step 1
# 5:  |F(x)| = 6.52725; step 1
# 6:  |F(x)| = 4.0611; step 0.42678
# 7:  |F(x)| = 4.03491; step 0.0200263
# 8:  |F(x)| = 4.02217; step 0.01
# 9:  |F(x)| = 8.3875; step 1
# 10:  |F(x)| = 8.81276; step 1
# 11:  |F(x)| = 3.79637; step 1
# 12:  |F(x)| = 1.45008; step 1
# 13:  |F(x)| = 1.60715; step 1
# 14:  |F(x)| = 1.30503; step 1
# 15:  |F(x)| = 0.561055; step 1
# 16:  |F(x)| = 0.190835; step 1
# 17:  |F(x)| = 0.406402; step 1
# 18:  |F(x)| = 0.339706; step 1
# 19:  |F(x)| = 0.119591; step 1
# 20:  |F(x)| = 0.0597933; step 1
# 21:  |F(x)| = 0.057507; step 0.387558
# 22:  |F(x)| = 0.0655886; step 0.502834
# 23:  |F(x)| = 0.064739; step 1
# 24:  |F(x)| = 0.0312296; step 1
# 25:  |F(x)| = 0.0092342; step 1
# 26:  |F(x)| = 0.00998361; step 0.500727
# 27:  |F(x)| = 0.0125072; step 1
# 28:  |F(x)| = 0.00845828; step 1
# 29:  |F(x)| = 0.00199261; step 1
# 30:  |F(x)| = 0.00133301; step 0.504742
# 31:  |F(x)| = 0.00114071; step 0.180245
# 32:  |F(x)| = 0.00113843; step 0.0831809
# 33:  |F(x)| = 0.00115633; step 0.0442745
# 34:  |F(x)| = 0.00116543; step 0.0255155
# 35:  |F(x)| = 0.00117051; step 0.01541
# 36:  |F(x)| = 0.00117366; step 0.01
# 37:  |F(x)| = 0.0011767; step 0.01
# 38:  |F(x)| = 0.00265922; step 1
# 39:  |F(x)| = 0.00213367; step 1
# 40:  |F(x)| = 0.000857992; step 1
# 41:  |F(x)| = 0.000361373; step 1
# 42:  |F(x)| = 0.000362975; step 0.454756
# 43:  |F(x)| = 0.000448422; step 1
# 44:  |F(x)| = 0.000279482; step 1
# 45:  |F(x)| = 7.87339e-05; step 1
# 46:  |F(x)| = 7.57266e-05; step 1
# 47:  |F(x)| = 9.55171e-05; step 1
# 48:  |F(x)| = 5.39116e-05; step 1
# 49:  |F(x)| = 1.33747e-05; step 1
# 50:  |F(x)| = 9.85048e-06; step 0.379583
# 51:  |F(x)| = 1.01203e-05; step 0.13626
# 52:  |F(x)| = 1.02692e-05; step 0.0653437
# 53:  |F(x)| = 1.03344e-05; step 0.0370544
# 54:  |F(x)| = 1.03688e-05; step 0.0232033
# 55:  |F(x)| = 1.03891e-05; step 0.0154742
# 56:  |F(x)| = 1.04021e-05; step 0.0107621
# 57:  |F(x)| = 2.01177e-05; step 1
# 58:  |F(x)| = 1.57096e-05; step 1
# 59:  |F(x)| = 6.01955e-06; step 1
# scipy solver converged in 61 iterations.
# 0:  |F(x)| = 131.778; step 0.450081
# 1:  |F(x)| = 39.3691; step 1
# 2:  |F(x)| = 27.5467; step 1
# 3:  |F(x)| = 14.2634; step 1
# 4:  |F(x)| = 7.67487; step 1
# 5:  |F(x)| = 3.617; step 1
# 6:  |F(x)| = 3.97088; step 0.197184
# 7:  |F(x)| = 4.1633; step 0.151529
# 8:  |F(x)| = 4.37445; step 0.247431
# 9:  |F(x)| = 4.54282; step 1
# 10:  |F(x)| = 2.70325; step 1
# 11:  |F(x)| = 0.672227; step 1
# 12:  |F(x)| = 0.750431; step 1
# 13:  |F(x)| = 0.757092; step 1
# 14:  |F(x)| = 0.284262; step 1
# 15:  |F(x)| = 0.103601; step 1
# 16:  |F(x)| = 0.106613; step 0.180204
# 17:  |F(x)| = 0.12054; step 0.181026
# 18:  |F(x)| = 0.138118; step 0.266241
# 19:  |F(x)| = 0.16616; step 1
# 20:  |F(x)| = 0.0851416; step 1
# 21:  |F(x)| = 0.0215206; step 1
# 22:  |F(x)| = 0.0174836; step 0.319688
# 23:  |F(x)| = 0.0181724; step 0.190249
# 24:  |F(x)| = 0.0183285; step 0.162318
# 25:  |F(x)| = 0.0203016; step 0.189297
# 26:  |F(x)| = 0.0232902; step 0.313532
# 27:  |F(x)| = 0.0260799; step 1
# 28:  |F(x)| = 0.0132452; step 1
# 29:  |F(x)| = 0.00363184; step 1
# 30:  |F(x)| = 0.00356845; step 0.502989
# 31:  |F(x)| = 0.00455612; step 1
# 32:  |F(x)| = 0.00287296; step 1
# 33:  |F(x)| = 0.000652595; step 1
# 34:  |F(x)| = 0.00047392; step 0.404574
# 35:  |F(x)| = 0.000410248; step 0.161873
# 36:  |F(x)| = 0.000393609; step 0.0860615
# 37:  |F(x)| = 0.000402165; step 0.0541657
# 38:  |F(x)| = 0.000423851; step 0.0380381
# 39:  |F(x)| = 0.000439399; step 0.0288812
# 40:  |F(x)| = 0.000451382; step 0.0232746
# 41:  |F(x)| = 0.000461154; step 0.0196868
# 42:  |F(x)| = 0.000469496; step 0.0173426
# 43:  |F(x)| = 0.000476905; step 0.0158437
# 44:  |F(x)| = 0.00048372; step 0.0149598
# 45:  |F(x)| = 0.000490197; step 0.0145738
# 46:  |F(x)| = 0.000496542; step 0.0146346
# 47:  |F(x)| = 0.00050295; step 0.0151554
# 48:  |F(x)| = 0.000509618; step 0.0161914
# 49:  |F(x)| = 0.00051678; step 0.0178969
# 50:  |F(x)| = 0.000524737; step 0.0205318
# 51:  |F(x)| = 0.000533911; step 0.0245796
# 52:  |F(x)| = 0.000544947; step 0.0309717
# 53:  |F(x)| = 0.0005589; step 0.0415901
# 54:  |F(x)| = 0.00057765; step 0.0608372
# 55:  |F(x)| = 0.000604782; step 0.100626
# 56:  |F(x)| = 0.000647102; step 0.202436
# 57:  |F(x)| = 0.000744721; step 1
# 58:  |F(x)| = 0.000390825; step 1
# 59:  |F(x)| = 9.99769e-05; step 1
# 60:  |F(x)| = 8.63397e-05; step 0.415043
# 61:  |F(x)| = 8.80283e-05; step 0.309498
# 62:  |F(x)| = 9.63485e-05; step 0.405191
# 63:  |F(x)| = 0.000109667; step 1
# 64:  |F(x)| = 5.42184e-05; step 1
# 65:  |F(x)| = 1.49342e-05; step 1
# 66:  |F(x)| = 1.4835e-05; step 0.433873
# 67:  |F(x)| = 1.4948e-05; step 0.47025
# 68:  |F(x)| = 1.74803e-05; step 1
# 69:  |F(x)| = 8.1364e-06; step 1
# 70:  |F(x)| = 2.05927e-06; step 1
# scipy solver converged in 72 iterations.
# 0:  |F(x)| = 356.582; step 0.452034
# 1:  |F(x)| = 244.114; step 1
# 2:  |F(x)| = 124.189; step 1
# 3:  |F(x)| = 91.0495; step 1
# 4:  |F(x)| = 80.7073; step 1
# 5:  |F(x)| = 28.4111; step 1
# 6:  |F(x)| = 10.707; step 0.497277
# 7:  |F(x)| = 8.51377; step 0.420224
# 8:  |F(x)| = 7.31753; step 0.18962
# 9:  |F(x)| = 6.83158; step 0.0797341
# 10:  |F(x)| = 6.72369; step 0.0355333
# 11:  |F(x)| = 6.77474; step 0.0163862
# 12:  |F(x)| = 6.80468; step 0.01
# 13:  |F(x)| = 15.6537; step 1
# 14:  |F(x)| = 15.3155; step 1
# 15:  |F(x)| = 8.76637; step 1
# 16:  |F(x)| = 3.45656; step 1
# 17:  |F(x)| = 2.45767; step 1
# 18:  |F(x)| = 1.80663; step 1
# 19:  |F(x)| = 0.683327; step 1
# 20:  |F(x)| = 0.261074; step 1
# 21:  |F(x)| = 0.260396; step 0.028253
# 22:  |F(x)| = 0.630887; step 1
# 23:  |F(x)| = 0.685598; step 1
# 24:  |F(x)| = 0.427847; step 1
# 25:  |F(x)| = 0.203975; step 1
# 26:  |F(x)| = 0.0757563; step 1
# 27:  |F(x)| = 0.0800548; step 1
# 28:  |F(x)| = 0.0502374; step 1
# 29:  |F(x)| = 0.01461; step 1
# 30:  |F(x)| = 0.0110378; step 1
# 31:  |F(x)| = 0.0142782; step 1
# 32:  |F(x)| = 0.00869449; step 1
# 33:  |F(x)| = 0.00572373; step 1
# 34:  |F(x)| = 0.00327906; step 1
# 35:  |F(x)| = 0.00276483; step 1
# 36:  |F(x)| = 0.00302262; step 0.243528
# 37:  |F(x)| = 0.00312239; step 0.11456
# 38:  |F(x)| = 0.00316951; step 0.0892359
# 39:  |F(x)| = 0.00319921; step 0.0962684
# 40:  |F(x)| = 0.00321423; step 0.143597
# 41:  |F(x)| = 0.00316288; step 0.33408
# 42:  |F(x)| = 0.00254469; step 1
# 43:  |F(x)| = 0.00128755; step 1
# 44:  |F(x)| = 0.00072216; step 1
# 45:  |F(x)| = 0.000351714; step 1
# 46:  |F(x)| = 0.000289821; step 1
# 47:  |F(x)| = 0.000107482; step 1
# 48:  |F(x)| = 0.000107148; step 0.0164932
# 49:  |F(x)| = 0.000106723; step 0.0208408
# 50:  |F(x)| = 0.000106155; step 0.0274715
# 51:  |F(x)| = 0.000105353; step 0.0382179
# 52:  |F(x)| = 0.00010413; step 0.0571604
# 53:  |F(x)| = 0.000102055; step 0.0947123
# 54:  |F(x)| = 9.79103e-05; step 0.183304
# 55:  |F(x)| = 9.44435e-05; step 0.454567
# 56:  |F(x)| = 0.000114859; step 1
# 57:  |F(x)| = 9.5e-05; step 1
# 58:  |F(x)| = 6.20758e-05; step 1
# 59:  |F(x)| = 2.61602e-05; step 1
# 60:  |F(x)| = 1.22796e-05; step 1
# 61:  |F(x)| = 7.85856e-06; step 1
# 62:  |F(x)| = 6.22025e-06; step 1
# 63:  |F(x)| = 5.37347e-06; step 0.494094
# scipy solver converged in 65 iterations.
# 0:  |F(x)| = 144.061; step 0.436461
# 1:  |F(x)| = 46.8361; step 1
# 2:  |F(x)| = 29.8671; step 1
# 3:  |F(x)| = 16.507; step 1
# 4:  |F(x)| = 9.59351; step 1
# 5:  |F(x)| = 3.72943; step 1
# 6:  |F(x)| = 3.84863; step 0.207425
# ...
# 5300 3.217418671604646 	Loss(validation) = 2.6043287343001795
# 5400 10.662650725012423 	Loss(validation) = 14.89302710968462
# 5500 2.8723524813663 	Loss(validation) = 2.3113895420921136
# 5600 2.7155495275623087 	Loss(validation) = 2.1600937524381427
# 5700 17.35375987151196 	Loss(validation) = 8.880358602027753
# 5800 2.4472578997516017 	Loss(validation) = 1.9263225550520329
# 5900 2.3245874183651534 	Loss(validation) = 1.8141022880908049
# 6000 70.0163482953566 	Loss(validation) = 50.36190606168155
# 6100 2.1217342519335833 	Loss(validation) = 1.626619161992549
# 6200 2.0235724981119043 	Loss(validation) = 1.5486274029946918
# 6300 1.932399173661474 	Loss(validation) = 1.4703831998555466
# 6400 4.18492147310369 	Loss(validation) = 5.771450967061781
# 6500 1.7752758782532407 	Loss(validation) = 1.3486116121880816
# 6600 1.6975697052395984 	Loss(validation) = 1.2699734955723185
# 6700 11.911375461481972 	Loss(validation) = 31.482563304311405
# 6800 1.5722993349955932 	Loss(validation) = 1.158792934611255
# 6900 1.5087164674383733 	Loss(validation) = 1.1109725391004082
# 7000 1.4482921260558235 	Loss(validation) = 1.0621327478319365
# 7100 1.4754179204683588 	Loss(validation) = 1.1031994082804457
# 7200 1.346298743257468 	Loss(validation) = 0.9784130111439016
# 7300 1.2946313408691514 	Loss(validation) = 0.9379521483968868
# 7400 1.6427639423535818 	Loss(validation) = 0.9870818003393188
# 7500 1.2090262357639907 	Loss(validation) = 0.8690666600111983
# 7600 1.1657576265223932 	Loss(validation) = 0.8360624941239694
# 7700 1.157994325063039 	Loss(validation) = 0.8084006251158045
# 7800 1.096195694179483 	Loss(validation) = 0.7815124630679386
# 7900 1.0586634600423717 	Loss(validation) = 0.7537446705523324
# 8000 3.4993133748394145 	Loss(validation) = 4.125264875139782
# 8100 0.9963942862559556 	Loss(validation) = 0.7062788607900423
# 8200 0.9635179285002696 	Loss(validation) = 0.6830977974227509
# 8300 1.304445296897325 	Loss(validation) = 0.793775154705807
# 8400 0.9126240822981129 	Loss(validation) = 0.645391184600691
# 8500 0.8853133628417312 	Loss(validation) = 0.6262797426479658
# 8600 0.9927545114606428 	Loss(validation) = 1.0141623226672873
# 8700 0.8409287513086344 	Loss(validation) = 0.5949146848353025
# 8800 11.04662176595392 	Loss(validation) = 10.7004641424554
# 8900 2.5920218802899906 	Loss(validation) = 3.3443205106670844
# 9000 0.7817898603551429 	Loss(validation) = 0.5489165556542691
# 9100 1.001994427049146 	Loss(validation) = 1.0508963724638016
# 9200 0.73947759778084 	Loss(validation) = 0.5271890641417313
# 9300 0.8813497777407039 	Loss(validation) = 0.5407561025755591
# 9400 7.705475133274853 	Loss(validation) = 11.679904705941963
# 9500 0.6922158698325643 	Loss(validation) = 0.4966030843883621
# 9600 34.87132045366424 	Loss(validation) = 49.70291325568327
# 9700 0.6643427667800058 	Loss(validation) = 0.4819934529941741
# 9800 0.6475604727686126 	Loss(validation) = 0.4676257695692863
# 9900 0.6853914957868223 	Loss(validation) = 0.5247470793935968
# 10000 1.0981945904046915 	Loss(validation) = 0.9246394908708713
# 10100 0.6171647613995366 	Loss(validation) = 0.4452430500812558
# 10200 0.6085081699295081 	Loss(validation) = 0.4651064622428141
# 10300 2.9715053064870864 	Loss(validation) = 4.473411649316801
# 10400 0.6028490221666643 	Loss(validation) = 0.4798291288202339
# 10500 0.569561844991035 	Loss(validation) = 0.4246876718533952
# 10600 0.784754189344427 	Loss(validation) = 0.49274172111783476
# 10700 0.5520447882387234 	Loss(validation) = 0.4186621158453497
# 10800 0.5641852513010339 	Loss(validation) = 0.41031637971449914
# 10900 2.9961519388004847 	Loss(validation) = 4.459551947802052
# 11000 26.69018773294063 	Loss(validation) = 30.22628624534302
# 11100 0.5192009537601261 	Loss(validation) = 0.3969830507808524
# 11200 1.4139732864534387 	Loss(validation) = 1.5415497448248632
# 11300 0.8333205623986238 	Loss(validation) = 0.9126349554277227
# 11400 8.079923306218063 	Loss(validation) = 3.919819714022542
# 11500 0.48993734301028724 	Loss(validation) = 0.3773126883483736
# 11600 0.6811799365277807 	Loss(validation) = 0.5481934663636074
# 11700 10.493334676804286 	Loss(validation) = 2.5240189090321925
# 11800 0.47104803405942086 	Loss(validation) = 0.3644882658890834
# 11900 0.8682637884011434 	Loss(validation) = 1.2520130834399852
# 12000 0.6196960684710937 	Loss(validation) = 0.6385735433849344
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 pinn_trainer.train()
#
# File ~/Desktop/MLniCS/tutorials/17_Greedy_PDNN_PINN/../../mlnics/Training.py:189, in PINNTrainer.train(self)
#     184 """
#     185 Function for getting training and validation sets to pass to
#     186 _normalize_and_train which then performs the training.
#     187 """
#     188 _, _, train_no_snap, validation_no_snap = self.data.train_validation_split()
# --> 189 return self._normalize_and_train(None, None, train_no_snap, validation_no_snap)
#
# File ~/Desktop/MLniCS/tutorials/17_Greedy_PDNN_PINN/../../mlnics/Training.py:110, in RONNTrainer._normalize_and_train(self, train_snap, validation_snap, train_no_snap, validation_no_snap)
#     108 for e in range(starting_epoch, starting_epoch + self.num_epochs):
#     109     coeff_pred = self.ronn(train_normalized)
# --> 110     loss = self.loss_fn(prediction_snap=coeff_pred[:num_train_snaps],
#     111                         prediction_no_snap=coeff_pred[num_train_snaps:],
#     112                         input_normalization=self.input_normalization,
#     113                         normalized_mu=train_normalized[num_train_snaps:])
#     115     self.optimizer.zero_grad()
#     116     loss.backward()
#
# File ~/Desktop/MLniCS/tutorials/17_Greedy_PDNN_PINN/../../mlnics/Losses.py:129, in PINN_Loss.__call__(self, **kwargs)
#     127 #print("Assembly time:", end_time - start_time)
#     128 start_time = time.time()
# --> 129 thetas = np.array(self.ronn.reduced_problem.compute_theta('c'))
#     130 end_time = time.time()
#     131 #print("Compute theta time:", end_time - start_time)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/problems/base/parametrized_reduced_differential_problem.py:676, in ParametrizedReducedDifferentialProblem.compute_theta(self, term)
#     669 def compute_theta(self, term):
#     670     """
#     671     Return theta multiplicative terms of the affine expansion of the problem.
#     672
#     673     :param term: the forms of the class of the problem.
#     674     :return: computed thetas.
#     675     """
# --> 676     return self.truth_problem.compute_theta(term)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/backends/offline_online_class_method.py:25, in OfflineOnlineClassMethod.<locals>._OfflineOnlineClassMethod.__call__(self, term)
#      23 def __call__(self, term):
#      24     if self._replacement_condition[_OfflineOnlineClassMethod_Base._current_stage](term):
# ---> 25         return self._content[_OfflineOnlineClassMethod_Base._current_stage](term)
#      26     else:
#      27         return self._original_class_method(term)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/problems/deim_decorated_problem.py:211, in DEIMDecoratedProblem.<locals>.DEIMDecoratedProblem_Decorator.<locals>.DEIMDecoratedProblem_Class._compute_theta_DEIM(self, term)
#     208     if self._N_DEIM is not None:
#     209         N_DEIM = self._N_DEIM[term][q]
#     210     deim_thetas_q = [v * original_thetas[q]
# --> 211                      for v in deim_approximation.compute_interpolated_theta(N_DEIM)]
#     212     deim_thetas.extend(deim_thetas_q)
#     213 # Append forms which did not require DEIM, if applicable
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/problems/eim_approximation.py:142, in EIMApproximation.compute_interpolated_theta(self, N)
#     141 def compute_interpolated_theta(self, N=None):
# --> 142     interpolated_theta = self.solve(N)
#     143     interpolated_theta_list = list()
#     144     for theta in interpolated_theta:
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/problems/eim_approximation.py:112, in EIMApproximation.solve(self, N)
#     109 if N is None:
#     110     N = self.N
# --> 112 self._solve(self.parametrized_expression, N)
#     113 return self._interpolation_coefficients
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/eim/problems/eim_approximation.py:123, in EIMApproximation._solve(self, rhs_, N)
#     120 self._interpolation_coefficients = OnlineFunction(N)
#     122 # Evaluate the parametrized expression at interpolation locations
# --> 123 rhs = evaluate(rhs_, self.interpolation_locations[:N])
#     125 (max_abs_rhs, _) = max(abs(rhs))
#     126 if max_abs_rhs == 0.:
#     127     # If the rhs is zero, then we are interpolating the zero function
#     128     # and the default zero coefficients are enough.
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/utils/decorators/dispatch.py:150, in Dispatcher.__call__(self, *args, **kwargs)
#     148 def __call__(self, *args, **kwargs):
#     149     func = self._get_func(*args)
# --> 150     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/dolfin/evaluate.py:68, in evaluate(expression, at, **kwargs)
#      64 @backend_for("dolfin", inputs=((Matrix.Type(), Vector.Type(), Function.Type(), Operator, TensorsList,
#      65                                 FunctionsList, ParametrizedTensorFactory, ParametrizedExpressionFactory),
#      66                                (ReducedMesh, ReducedVertices, None)))
#      67 def evaluate(expression, at=None, **kwargs):
# ---> 68     return _evaluate(expression, at, **kwargs)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/utils/decorators/dispatch.py:150, in Dispatcher.__call__(self, *args, **kwargs)
#     148 def __call__(self, *args, **kwargs):
#     149     func = self._get_func(*args)
# --> 150     return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/dolfin/evaluate.py:120, in _evaluate(expression, at, **kwargs)
#     113 @overload
#     114 def _evaluate(
#     115     expression: ParametrizedTensorFactory,
#     116     at: ReducedMesh,
#     117     **kwargs
#     118 ):
#     119     assert len(kwargs) == 0
# --> 120     return evaluate_base(expression, at)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/utils/decorators/dispatch.py:334, in MethodDispatcher.__call__(self, *args, **kwargs)
#     332     args = args[1:]
#     333 func = self._get_func(*args)
# --> 334 return func(obj, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/basic/evaluate.py:68, in evaluate.<locals>._Evaluate.__call__(self, parametrized_tensor, at)
#      65 @overload(backend.ParametrizedTensorFactory, backend.ReducedMesh)
#      66 def __call__(self, parametrized_tensor, at):
#      67     # Efficient version, assemblying only on the reduced mesh
# ---> 68     (assembled_form, form_rank) = wrapping.form_on_reduced_function_space(parametrized_tensor, at)
#      69     assert form_rank in (1, 2)
#      70     if form_rank == 2:
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/dolfin/wrapping/form_on_reduced_function_space.py:433, in basic_form_on_reduced_function_space.<locals>._basic_form_on_reduced_function_space(form_wrapper, at)
#     430             backend.assign(solution_dot_to, solution_dot_from)
#     432 # Assemble and return
# --> 433 assembled_replaced_form = wrapping.assemble(replaced_form_with_replaced_measures)
#     434 if not isinstance(assembled_replaced_form, Number):
#     435     form_rank = assembled_replaced_form.rank()
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/RBniCS-0.1.dev1-py3.10.egg/rbnics/backends/dolfin/wrapping/assemble.py:11, in assemble(form, tensor)
#      10 def assemble(form, tensor=None):
# ---> 11     return dolfin_assemble(form, keep_diagonal=True, tensor=tensor)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/fem/assembling.py:198, in assemble(form, tensor, form_compiler_parameters, add_values, finalize_tensor, keep_diagonal, backend)
#     196     dolfin_form = form
#     197 else:
# --> 198     dolfin_form = _create_dolfin_form(form, form_compiler_parameters)
#     200 # Create tensor
#     201 comm = dolfin_form.mesh().mpi_comm()
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/fem/assembling.py:56, in _create_dolfin_form(form, form_compiler_parameters, function_spaces)
#      54     return form
#      55 elif isinstance(form, ufl.Form):
# ---> 56     return Form(form,
#      57                 form_compiler_parameters=form_compiler_parameters,
#      58                 function_spaces=function_spaces)
#      59 else:
#      60     raise TypeError("Invalid form type %s" % (type(form),))
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/fem/form.py:43, in Form.__init__(self, form, **kwargs)
#      40 if form_compiler_parameters is None:
#      41     form_compiler_parameters = {"external_include_dirs": dolfin_pc["include_dirs"]}
# ---> 43 ufc_form = ffc_jit(form, form_compiler_parameters=form_compiler_parameters,
#      44                    mpi_comm=mesh.mpi_comm())
#      45 ufc_form = cpp.fem.make_ufc_form(ufc_form[0])
#      47 function_spaces = kwargs.get("function_spaces")
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/jit/jit.py:47, in mpi_jit_decorator.<locals>.mpi_jit(*args, **kwargs)
#      45 # Just call JIT compiler when running in serial
#      46 if MPI.size(mpi_comm) == 1:
# ---> 47     return local_jit(*args, **kwargs)
#      49 # Default status (0 == ok, 1 == fail)
#      50 status = 0
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/dolfin/jit/jit.py:97, in ffc_jit(ufl_form, form_compiler_parameters)
#      95 p.update(dict(parameters["form_compiler"]))
#      96 p.update(form_compiler_parameters or {})
# ---> 97 return ffc.jit(ufl_form, parameters=p)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/ffc/jitcompiler.py:214, in jit(ufl_object, parameters, indirect)
#     211 set_prefix(parameters["log_prefix"])
#     213 # Make unique module name for generated code
# --> 214 kind, module_name = compute_jit_prefix(ufl_object, parameters)
#     216 # Inspect cache and generate+build if necessary
#     217 module = jit_build(ufl_object, module_name, parameters)
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/ffc/jitcompiler.py:159, in compute_jit_prefix(ufl_object, parameters, kind)
#     156     error("Unknown ufl object type %s" % (ufl_object.__class__.__name__,))
#     158 # Compute deterministic string of relevant parameters
# --> 159 parameters_signature = compute_jit_parameters_signature(parameters)
#     161 # Increase this number at any time to invalidate cache
#     162 # signatures if code generation has changed in important
#     163 # ways without the change being visible in regular signatures:
#     164 jit_version_bump = 3
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/ffc/parameters.py:199, in compute_jit_parameters_signature(parameters)
#     197 from ufl.utils.sorting import canonicalize_metadata
#     198 parameters = compilation_relevant_parameters(parameters)
# --> 199 return str(canonicalize_metadata(parameters))
#
# File ~/opt/anaconda3/envs/MLniCS/lib/python3.10/site-packages/ufl/utils/sorting.py:100, in canonicalize_metadata(metadata)
#      98 newvalues = []
#      99 for value in values:
# --> 100     if isinstance(value, (dict, list, tuple)):
#     101         value = canonicalize_metadata(value)
#     102     elif isinstance(value, (int, float, str)) or value is None:
#
# KeyboardInterrupt:

# %%
fig, ax = Training.plot_loss(pinn_trainer, pinn_net)

# %% [markdown]
# ### 4.6. Perform an error analysis

# %%
np.random.seed(42)
reduction_method.initialize_testing_set(16, DEIM=25, sampling=EquispacedDistribution())
test_mu = torch.tensor(reduction_method.testing_set)

# %% [markdown]
# #### 4.6.1 Greedy PDNN-PINN Error Analysis

# %%
pdnn_net.load_best_weights()
_ = ErrorAnalysis.error_analysis_fixed_net(
    pdnn_net, test_mu, input_normalization_pdnn, output_normalization_pdnn
)
# Out:
# 0:  |F(x)| = 0.176079; step 1
# 1:  |F(x)| = 0.00625836; step 1
# 2:  |F(x)| = 0.0035992; step 1
# 3:  |F(x)| = 0.000360276; step 1
# 4:  |F(x)| = 9.79952e-05; step 1
# 5:  |F(x)| = 1.90677e-05; step 1
# 6:  |F(x)| = 3.37393e-06; step 1
# scipy solver converged in 8 iterations.
# 0:  |F(x)| = 1.9153; step 1
# 1:  |F(x)| = 0.138948; step 1
# 2:  |F(x)| = 0.0970699; step 1
# 3:  |F(x)| = 0.0429902; step 1
# 4:  |F(x)| = 0.00342303; step 1
# 5:  |F(x)| = 0.00388338; step 1
# 6:  |F(x)| = 0.000836349; step 1
# 7:  |F(x)| = 0.000298355; step 1
# 8:  |F(x)| = 0.000161619; step 1
# 9:  |F(x)| = 1.47415e-05; step 1
# 10:  |F(x)| = 2.00819e-05; step 1
# 11:  |F(x)| = 4.20324e-06; step 1
# scipy solver converged in 13 iterations.
# 0:  |F(x)| = 6.63356; step 1
# 1:  |F(x)| = 1.06961; step 1
# 2:  |F(x)| = 0.401262; step 1
# 3:  |F(x)| = 0.380194; step 1
# 4:  |F(x)| = 0.104876; step 1
# 5:  |F(x)| = 0.0178805; step 1
# 6:  |F(x)| = 0.0228464; step 1
# 7:  |F(x)| = 0.00375909; step 1
# 8:  |F(x)| = 0.00305874; step 1
# 9:  |F(x)| = 0.00174812; step 1
# 10:  |F(x)| = 0.00020726; step 1
# 11:  |F(x)| = 0.000161783; step 0.482007
# 12:  |F(x)| = 0.000240516; step 1
# 13:  |F(x)| = 5.92741e-05; step 1
# 14:  |F(x)| = 2.26198e-05; step 1
# 15:  |F(x)| = 1.85791e-05; step 1
# 16:  |F(x)| = 2.14289e-06; step 1
# scipy solver converged in 18 iterations.
# 0:  |F(x)| = 17.2704; step 1
# 1:  |F(x)| = 3.75104; step 1
# 2:  |F(x)| = 0.991055; step 1
# 3:  |F(x)| = 1.17153; step 1
# 4:  |F(x)| = 0.677575; step 1
# 5:  |F(x)| = 0.109215; step 1
# 6:  |F(x)| = 0.0927247; step 1
# 7:  |F(x)| = 0.0600386; step 1
# 8:  |F(x)| = 0.0102091; step 1
# 9:  |F(x)| = 0.0138587; step 1
# 10:  |F(x)| = 0.00688714; step 1
# 11:  |F(x)| = 0.00120376; step 1
# 12:  |F(x)| = 0.00107292; step 0.382499
# 13:  |F(x)| = 0.00135219; step 0.505867
# 14:  |F(x)| = 0.00108045; step 1
# 15:  |F(x)| = 0.000209977; step 1
# 16:  |F(x)| = 0.000151089; step 1
# 17:  |F(x)| = 0.000114536; step 1
# 18:  |F(x)| = 1.70966e-05; step 1
# 19:  |F(x)| = 2.32137e-05; step 1
# 20:  |F(x)| = 1.41992e-05; step 1
# 21:  |F(x)| = 2.03962e-06; step 1
# scipy solver converged in 23 iterations.
# 0:  |F(x)| = 68.3914; step 1
# 1:  |F(x)| = 16.4131; step 1
# 2:  |F(x)| = 7.40524; step 1
# 3:  |F(x)| = 2.46797; step 1
# 4:  |F(x)| = 2.0801; step 0.301858
# 5:  |F(x)| = 2.27521; step 0.203334
# 6:  |F(x)| = 2.56519; step 0.239836
# 7:  |F(x)| = 3.03115; step 1
# 8:  |F(x)| = 1.39951; step 1
# 9:  |F(x)| = 0.312287; step 1
# 10:  |F(x)| = 0.389679; step 1
# 11:  |F(x)| = 0.227706; step 1
# 12:  |F(x)| = 0.0513778; step 1
# 13:  |F(x)| = 0.0330536; step 0.444568
# 14:  |F(x)| = 0.0454645; step 0.394224
# 15:  |F(x)| = 0.0523781; step 1
# 16:  |F(x)| = 0.0174413; step 1
# 17:  |F(x)| = 0.0078734; step 1
# 18:  |F(x)| = 0.00861511; step 0.175214
# 19:  |F(x)| = 0.0094646; step 0.354978
# 20:  |F(x)| = 0.00881172; step 1
# 21:  |F(x)| = 0.0030074; step 1
# 22:  |F(x)| = 0.00103771; step 1
# 23:  |F(x)| = 0.00137361; step 1
# 24:  |F(x)| = 0.000549048; step 1
# 25:  |F(x)| = 0.000153515; step 1
# 26:  |F(x)| = 0.000194161; step 0.266863
# 27:  |F(x)| = 0.000223911; step 0.420299
# 28:  |F(x)| = 0.000200119; step 1
# 29:  |F(x)| = 5.65144e-05; step 1
# 30:  |F(x)| = 3.18547e-05; step 1
# 31:  |F(x)| = 3.64096e-05; step 0.499082
# 32:  |F(x)| = 2.88063e-05; step 1
# 33:  |F(x)| = 7.37969e-06; step 1
# 34:  |F(x)| = 4.85325e-06; step 1
# scipy solver converged in 36 iterations.
# 0:  |F(x)| = 113.039; step 1
# 1:  |F(x)| = 26.5323; step 1
# 2:  |F(x)| = 16.0524; step 1
# 3:  |F(x)| = 3.52373; step 1
# 4:  |F(x)| = 2.75254; step 0.504343
# 5:  |F(x)| = 2.56812; step 0.148462
# 6:  |F(x)| = 2.50118; step 0.0557904
# 7:  |F(x)| = 2.47291; step 0.0239057
# 8:  |F(x)| = 2.46015; step 0.0108545
# 9:  |F(x)| = 5.74345; step 1
# 10:  |F(x)| = 3.88416; step 1
# 11:  |F(x)| = 1.10041; step 1
# 12:  |F(x)| = 0.660446; step 1
# 13:  |F(x)| = 0.711214; step 1
# 14:  |F(x)| = 0.256732; step 1
# 15:  |F(x)| = 0.0968244; step 1
# 16:  |F(x)| = 0.120287; step 0.311536
# 17:  |F(x)| = 0.146253; step 1
# 18:  |F(x)| = 0.0607352; step 1
# 19:  |F(x)| = 0.0143117; step 1
# 20:  |F(x)| = 0.0153093; step 0.0946101
# 21:  |F(x)| = 0.0166915; step 0.0756844
# 22:  |F(x)| = 0.0178307; step 0.0717791
# 23:  |F(x)| = 0.0189315; step 0.0800425
# 24:  |F(x)| = 0.0201644; step 0.106802
# 25:  |F(x)| = 0.0217519; step 0.180071
# 26:  |F(x)| = 0.0237921; step 0.435513
# 27:  |F(x)| = 0.0202794; step 1
# 28:  |F(x)| = 0.00680879; step 1
# 29:  |F(x)| = 0.00295879; step 1
# 30:  |F(x)| = 0.00378965; step 1
# 31:  |F(x)| = 0.00177476; step 1
# 32:  |F(x)| = 0.000421618; step 1
# 33:  |F(x)| = 0.00039001; step 0.21107
# 34:  |F(x)| = 0.000466462; step 0.166988
# 35:  |F(x)| = 0.000528649; step 0.192923
# 36:  |F(x)| = 0.000593065; step 0.341023
# 37:  |F(x)| = 0.000589097; step 1
# 38:  |F(x)| = 0.000218122; step 1
# 39:  |F(x)| = 6.35776e-05; step 1
# 40:  |F(x)| = 7.60581e-05; step 0.207938
# 41:  |F(x)| = 8.92756e-05; step 0.314161
# 42:  |F(x)| = 9.97728e-05; step 1
# 43:  |F(x)| = 4.10868e-05; step 1
# 44:  |F(x)| = 1.13705e-05; step 1
# 45:  |F(x)| = 1.19365e-05; step 0.413796
# 46:  |F(x)| = 1.58441e-05; step 1
# 47:  |F(x)| = 6.57089e-06; step 1
# 48:  |F(x)| = 1.61368e-06; step 1
# scipy solver converged in 50 iterations.
# 0:  |F(x)| = 79.597; step 0.525211
# 1:  |F(x)| = 14.1984; step 1
# 2:  |F(x)| = 17.5511; step 1
# 3:  |F(x)| = 6.63537; step 1
# 4:  |F(x)| = 2.2095; step 1
# 5:  |F(x)| = 1.47792; step 0.374065
# 6:  |F(x)| = 1.33086; step 0.100111
# 7:  |F(x)| = 1.27815; step 0.0383149
# 8:  |F(x)| = 1.25636; step 0.0162319
# 9:  |F(x)| = 1.24309; step 0.01
# 10:  |F(x)| = 3.38727; step 1
# 11:  |F(x)| = 2.29345; step 1
# 12:  |F(x)| = 0.735927; step 1
# 13:  |F(x)| = 0.426346; step 1
# 14:  |F(x)| = 0.500467; step 1
# 15:  |F(x)| = 0.242894; step 1
# 16:  |F(x)| = 0.0599846; step 1
# 17:  |F(x)| = 0.0494215; step 0.214606
# 18:  |F(x)| = 0.0591233; step 0.161505
# 19:  |F(x)| = 0.067996; step 0.171116
# 20:  |F(x)| = 0.0772381; step 0.260499
# 21:  |F(x)| = 0.0913619; step 1
# 22:  |F(x)| = 0.0429775; step 1
# 23:  |F(x)| = 0.0104708; step 1
# 24:  |F(x)| = 0.00874727; step 0.199805
# 25:  |F(x)| = 0.00904498; step 0.131865
# 26:  |F(x)| = 0.00979037; step 0.113888
# 27:  |F(x)| = 0.0108608; step 0.124595
# 28:  |F(x)| = 0.0120305; step 0.176062
# 29:  |F(x)| = 0.0134929; step 0.349622
# 30:  |F(x)| = 0.0135596; step 1
# 31:  |F(x)| = 0.00582891; step 1
# 32:  |F(x)| = 0.00178824; step 1
# 33:  |F(x)| = 0.00187652; step 0.471423
# 34:  |F(x)| = 0.00223409; step 1
# 35:  |F(x)| = 0.00105819; step 1
# 36:  |F(x)| = 0.000259566; step 1
# 37:  |F(x)| = 0.00022321; step 0.16336
# 38:  |F(x)| = 0.000239104; step 0.100358
# 39:  |F(x)| = 0.000261877; step 0.0764456
# 40:  |F(x)| = 0.000279843; step 0.0688508
# 41:  |F(x)| = 0.000296421; step 0.0721638
# 42:  |F(x)| = 0.000314049; step 0.0886539
# 43:  |F(x)| = 0.0003356; step 0.132028
# 44:  |F(x)| = 0.000365187; step 0.258867
# 45:  |F(x)| = 0.000395006; step 1
# 46:  |F(x)| = 0.000179431; step 1
# 47:  |F(x)| = 4.6001e-05; step 1
# 48:  |F(x)| = 4.44946e-05; step 0.284118
# 49:  |F(x)| = 4.49404e-05; step 0.263468
# 50:  |F(x)| = 5.52099e-05; step 0.410065
# 51:  |F(x)| = 5.70314e-05; step 1
# 52:  |F(x)| = 2.38026e-05; step 1
# 53:  |F(x)| = 7.42314e-06; step 1
# 54:  |F(x)| = 7.83502e-06; step 0.397279
# 55:  |F(x)| = 1.05276e-05; step 1
# 56:  |F(x)| = 5.22569e-06; step 1
# scipy solver converged in 58 iterations.
# 0:  |F(x)| = 123.621; step 0.459689
# 1:  |F(x)| = 34.6593; step 1
# 2:  |F(x)| = 26.0259; step 1
# 3:  |F(x)| = 12.8781; step 1
# 4:  |F(x)| = 6.47662; step 1
# 5:  |F(x)| = 3.75208; step 1
# 6:  |F(x)| = 4.0571; step 0.218622
# 7:  |F(x)| = 4.28947; step 0.279356
# 8:  |F(x)| = 4.38609; step 1
# 9:  |F(x)| = 2.55928; step 1
# 10:  |F(x)| = 0.622416; step 1
# 11:  |F(x)| = 0.579833; step 0.514463
# 12:  |F(x)| = 0.719299; step 1
# 13:  |F(x)| = 0.480574; step 1
# 14:  |F(x)| = 0.117398; step 1
# 15:  |F(x)| = 0.076235; step 0.45951
# 16:  |F(x)| = 0.0643828; step 0.20724
# 17:  |F(x)| = 0.0677372; step 0.134342
# 18:  |F(x)| = 0.0754078; step 0.114074
# 19:  |F(x)| = 0.0834339; step 0.122608
# 20:  |F(x)| = 0.0921564; step 0.169656
# 21:  |F(x)| = 0.103254; step 0.327851
# 22:  |F(x)| = 0.10794; step 1
# 23:  |F(x)| = 0.0499163; step 1
# 24:  |F(x)| = 0.0128914; step 1
# 25:  |F(x)| = 0.0121623; step 0.212456
# 26:  |F(x)| = 0.0124573; step 0.143455
# 27:  |F(x)| = 0.0125468; step 0.127393
# 28:  |F(x)| = 0.0139126; step 0.144781
# 29:  |F(x)| = 0.0155962; step 0.216568
# 30:  |F(x)| = 0.0176125; step 0.47017
# 31:  |F(x)| = 0.0157294; step 1
# 32:  |F(x)| = 0.00650793; step 1
# 33:  |F(x)| = 0.00248053; step 1
# 34:  |F(x)| = 0.00323585; step 1
# 35:  |F(x)| = 0.00227325; step 1
# 36:  |F(x)| = 0.000529598; step 1
# 37:  |F(x)| = 0.000340946; step 0.48184
# 38:  |F(x)| = 0.000293398; step 0.170467
# 39:  |F(x)| = 0.000272423; step 0.0803138
# 40:  |F(x)| = 0.000268627; step 0.044276
# 41:  |F(x)| = 0.000280343; step 0.0267063
# 42:  |F(x)| = 0.000287528; step 0.0170235
# 43:  |F(x)| = 0.000292156; step 0.0112387
# 44:  |F(x)| = 0.000296205; step 0.01
# 45:  |F(x)| = 0.000695183; step 1
# 46:  |F(x)| = 0.000501301; step 1
# 47:  |F(x)| = 0.000146036; step 1
# 48:  |F(x)| = 9.31498e-05; step 1
# 49:  |F(x)| = 0.000108247; step 0.448016
# 50:  |F(x)| = 0.000111469; step 1
# 51:  |F(x)| = 5.0133e-05; step 1
# 52:  |F(x)| = 1.46066e-05; step 1
# 53:  |F(x)| = 1.59579e-05; step 0.394488
# 54:  |F(x)| = 1.69381e-05; step 0.481121
# 55:  |F(x)| = 1.78832e-05; step 1
# 56:  |F(x)| = 7.55255e-06; step 1
# 57:  |F(x)| = 2.00365e-06; step 1
# scipy solver converged in 59 iterations.
# 0:  |F(x)| = 248.92; step 0.34862
# 1:  |F(x)| = 140.995; step 1
# 2:  |F(x)| = 52.8398; step 1
# 3:  |F(x)| = 40.902; step 1
# 4:  |F(x)| = 30.6247; step 1
# 5:  |F(x)| = 7.3362; step 1
# 6:  |F(x)| = 4.10703; step 0.453916
# 7:  |F(x)| = 4.06044; step 0.0431275
# 8:  |F(x)| = 4.04846; step 0.0118557
# 9:  |F(x)| = 9.05401; step 1
# 10:  |F(x)| = 9.69944; step 1
# 11:  |F(x)| = 4.41448; step 1
# 12:  |F(x)| = 1.61364; step 1
# 13:  |F(x)| = 1.66178; step 1
# 14:  |F(x)| = 1.43588; step 1
# 15:  |F(x)| = 0.664361; step 1
# 16:  |F(x)| = 0.174293; step 1
# 17:  |F(x)| = 0.435215; step 1
# 18:  |F(x)| = 0.38864; step 1
# 19:  |F(x)| = 0.153363; step 1
# 20:  |F(x)| = 0.0624606; step 1
# 21:  |F(x)| = 0.0614925; step 0.433955
# 22:  |F(x)| = 0.0648563; step 0.460913
# 23:  |F(x)| = 0.0717414; step 1
# 24:  |F(x)| = 0.0383471; step 1
# 25:  |F(x)| = 0.0113001; step 1
# 26:  |F(x)| = 0.0127786; step 1
# 27:  |F(x)| = 0.0134342; step 1
# 28:  |F(x)| = 0.00645872; step 1
# 29:  |F(x)| = 0.00169302; step 1
# 30:  |F(x)| = 0.00148865; step 0.161784
# 31:  |F(x)| = 0.00153686; step 0.0791263
# 32:  |F(x)| = 0.00155854; step 0.0441853
# 33:  |F(x)| = 0.00156998; step 0.0266633
# 34:  |F(x)| = 0.00157662; step 0.0168746
# 35:  |F(x)| = 0.00158071; step 0.0110116
# 36:  |F(x)| = 0.00158428; step 0.01
# 37:  |F(x)| = 0.00344959; step 1
# 38:  |F(x)| = 0.002779; step 1
# 39:  |F(x)| = 0.00113334; step 1
# 40:  |F(x)| = 0.000471483; step 1
# 41:  |F(x)| = 0.000474564; step 0.479132
# 42:  |F(x)| = 0.000574901; step 1
# 43:  |F(x)| = 0.000360553; step 1
# 44:  |F(x)| = 0.000100896; step 1
# 45:  |F(x)| = 9.63468e-05; step 1
# 46:  |F(x)| = 0.000124407; step 1
# 47:  |F(x)| = 7.24634e-05; step 1
# 48:  |F(x)| = 1.78619e-05; step 1
# 49:  |F(x)| = 1.2744e-05; step 0.428916
# 50:  |F(x)| = 1.33265e-05; step 0.166562
# 51:  |F(x)| = 1.35466e-05; step 0.0901414
# 52:  |F(x)| = 1.36408e-05; step 0.060313
# 53:  |F(x)| = 1.36886e-05; step 0.0466187
# 54:  |F(x)| = 1.37141e-05; step 0.040256
# 55:  |F(x)| = 1.37259e-05; step 0.0381874
# 56:  |F(x)| = 1.37266e-05; step 0.0395366
# 57:  |F(x)| = 1.37143e-05; step 0.0447104
# 58:  |F(x)| = 1.42164e-05; step 0.0556767
# 59:  |F(x)| = 1.49585e-05; step 0.0777102
# 60:  |F(x)| = 1.5997e-05; step 0.125727
# 61:  |F(x)| = 1.75736e-05; step 0.250473
# 62:  |F(x)| = 2.03303e-05; step 1
# 63:  |F(x)| = 1.18315e-05; step 1
# 64:  |F(x)| = 3.47328e-06; step 1
# scipy solver converged in 66 iterations.
# 0:  |F(x)| = 204.88; step 0.540579
# 1:  |F(x)| = 58.7347; step 1
# 2:  |F(x)| = 18.5509; step 0.517796
# 3:  |F(x)| = 16.8226; step 0.109661
# 4:  |F(x)| = 16.3639; step 0.0307072
# 5:  |F(x)| = 16.2167; step 0.01
# 6:  |F(x)| = 45.4982; step 1
# 7:  |F(x)| = 31.6957; step 1
# 8:  |F(x)| = 10.9052; step 1
# 9:  |F(x)| = 5.80675; step 1
# 10:  |F(x)| = 11.8062; step 1
# 11:  |F(x)| = 9.94896; step 1
# 12:  |F(x)| = 4.26935; step 1
# 13:  |F(x)| = 1.79312; step 1
# 14:  |F(x)| = 1.88097; step 1
# 15:  |F(x)| = 1.57565; step 1
# 16:  |F(x)| = 0.626052; step 1
# 17:  |F(x)| = 0.227396; step 1
# 18:  |F(x)| = 0.491543; step 1
# 19:  |F(x)| = 0.416831; step 1
# 20:  |F(x)| = 0.176194; step 1
# 21:  |F(x)| = 0.0653379; step 1
# 22:  |F(x)| = 0.0664817; step 0.446873
# 23:  |F(x)| = 0.0670978; step 0.462691
# 24:  |F(x)| = 0.0779671; step 1
# 25:  |F(x)| = 0.0450875; step 1
# 26:  |F(x)| = 0.0137127; step 1
# 27:  |F(x)| = 0.0130464; step 1
# 28:  |F(x)| = 0.0144028; step 1
# 29:  |F(x)| = 0.00812503; step 1
# 30:  |F(x)| = 0.00198572; step 1
# 31:  |F(x)| = 0.00153788; step 0.322746
# 32:  |F(x)| = 0.00141283; step 0.123283
# 33:  |F(x)| = 0.00144521; step 0.0560987
# 34:  |F(x)| = 0.00145917; step 0.0279303
# 35:  |F(x)| = 0.00146591; step 0.0145674
# 36:  |F(x)| = 0.00147035; step 0.01
# 37:  |F(x)| = 0.00337332; step 1
# 38:  |F(x)| = 0.00291674; step 1
# 39:  |F(x)| = 0.00138234; step 1
# 40:  |F(x)| = 0.000431627; step 1
# 41:  |F(x)| = 0.000533529; step 1
# 42:  |F(x)| = 0.000525166; step 1
# 43:  |F(x)| = 0.000252909; step 1
# 44:  |F(x)| = 7.32937e-05; step 1
# 45:  |F(x)| = 7.69303e-05; step 0.375856
# 46:  |F(x)| = 7.80966e-05; step 0.324273
# 47:  |F(x)| = 8.82452e-05; step 0.485102
# 48:  |F(x)| = 9.13308e-05; step 1
# 49:  |F(x)| = 4.66826e-05; step 1
# 50:  |F(x)| = 1.22155e-05; step 1
# 51:  |F(x)| = 1.0299e-05; step 0.286974
# 52:  |F(x)| = 1.05247e-05; step 0.079077
# 53:  |F(x)| = 1.05476e-05; step 0.0104521
# 54:  |F(x)| = 1.05687e-05; step 0.01
# 55:  |F(x)| = 2.11252e-05; step 1
# 56:  |F(x)| = 1.84798e-05; step 1
# 57:  |F(x)| = 8.87428e-06; step 1
# 58:  |F(x)| = 2.81398e-06; step 1
# scipy solver converged in 60 iterations.
# 0:  |F(x)| = 248.493; step 0.506526
# 1:  |F(x)| = 107.909; step 1
# 2:  |F(x)| = 77.5882; step 1
# 3:  |F(x)| = 54.7739; step 1
# 4:  |F(x)| = 43.3295; step 1
# 5:  |F(x)| = 10.2697; step 1
# 6:  |F(x)| = 5.89537; step 0.418993
# 7:  |F(x)| = 5.63525; step 0.0815522
# 8:  |F(x)| = 5.55404; step 0.0239229
# 9:  |F(x)| = 5.51966; step 0.01
# 10:  |F(x)| = 12.4428; step 1
# 11:  |F(x)| = 14.6179; step 1
# 12:  |F(x)| = 7.38524; step 1
# 13:  |F(x)| = 3.17597; step 1
# 14:  |F(x)| = 1.95623; step 1
# 15:  |F(x)| = 1.88748; step 1
# 16:  |F(x)| = 1.26128; step 1
# 17:  |F(x)| = 0.286441; step 1
# 18:  |F(x)| = 0.236237; step 0.276156
# 19:  |F(x)| = 0.23486; step 0.0162143
# 20:  |F(x)| = 0.505778; step 1
# 21:  |F(x)| = 0.555055; step 1
# 22:  |F(x)| = 0.270187; step 1
# 23:  |F(x)| = 0.100559; step 1
# 24:  |F(x)| = 0.0776215; step 1
# 25:  |F(x)| = 0.081651; step 1
# 26:  |F(x)| = 0.0617959; step 1
# 27:  |F(x)| = 0.0119253; step 1
# 28:  |F(x)| = 0.0105875; step 0.388237
# 29:  |F(x)| = 0.0108688; step 0.435582
# 30:  |F(x)| = 0.0134215; step 1
# 31:  |F(x)| = 0.011361; step 1
# 32:  |F(x)| = 0.00393882; step 1
# 33:  |F(x)| = 0.00167076; step 1
# 34:  |F(x)| = 0.00398591; step 1
# 35:  |F(x)| = 0.00334346; step 1
# 36:  |F(x)| = 0.00178126; step 1
# 37:  |F(x)| = 0.000526456; step 1
# 38:  |F(x)| = 0.000584182; step 1
# 39:  |F(x)| = 0.00048844; step 1
# 40:  |F(x)| = 0.000239114; step 1
# 41:  |F(x)| = 7.0237e-05; step 1
# 42:  |F(x)| = 5.82607e-05; step 0.337026
# 43:  |F(x)| = 6.01994e-05; step 0.131271
# 44:  |F(x)| = 6.09237e-05; step 0.076588
# 45:  |F(x)| = 6.12781e-05; step 0.0535014
# 46:  |F(x)| = 6.14786e-05; step 0.0421762
# 47:  |F(x)| = 6.16006e-05; step 0.0365025
# 48:  |F(x)| = 6.19759e-05; step 0.034213
# 49:  |F(x)| = 6.3788e-05; step 0.0345197
# 50:  |F(x)| = 6.56497e-05; step 0.0374921
# 51:  |F(x)| = 6.77048e-05; step 0.0440534
# 52:  |F(x)| = 7.01558e-05; step 0.0567112
# 53:  |F(x)| = 7.33442e-05; step 0.0818667
# 54:  |F(x)| = 7.79254e-05; step 0.138648
# 55:  |F(x)| = 8.50558e-05; step 0.301179
# 56:  |F(x)| = 9.06151e-05; step 1
# 57:  |F(x)| = 5.1065e-05; step 1
# 58:  |F(x)| = 1.30494e-05; step 1
# 59:  |F(x)| = 9.91091e-06; step 0.356472
# 60:  |F(x)| = 9.37604e-06; step 0.152818
# 61:  |F(x)| = 9.51054e-06; step 0.0802092
# 62:  |F(x)| = 9.56452e-06; step 0.0460799
# 63:  |F(x)| = 9.58965e-06; step 0.0278635
# 64:  |F(x)| = 9.60261e-06; step 0.0173843
# 65:  |F(x)| = 9.60979e-06; step 0.0110593
# 66:  |F(x)| = 9.61568e-06; step 0.01
# 67:  |F(x)| = 1.71493e-05; step 1
# 68:  |F(x)| = 1.54217e-05; step 1
# 69:  |F(x)| = 8.18388e-06; step 1
# 70:  |F(x)| = 2.97151e-06; step 1
# scipy solver converged in 72 iterations.
# 0:  |F(x)| = 296.344; step 0.475194
# 1:  |F(x)| = 175.172; step 1
# 2:  |F(x)| = 100.128; step 1
# 3:  |F(x)| = 73.822; step 1
# 4:  |F(x)| = 62.4782; step 1
# 5:  |F(x)| = 16.6969; step 1
# 6:  |F(x)| = 8.39411; step 0.476576
# 7:  |F(x)| = 7.29278; step 0.255716
# 8:  |F(x)| = 6.78052; step 0.103225
# 9:  |F(x)| = 6.56911; step 0.0422931
# 10:  |F(x)| = 6.48026; step 0.0177958
# 11:  |F(x)| = 6.4304; step 0.01
# 12:  |F(x)| = 14.2612; step 1
# 13:  |F(x)| = 15.2583; step 1
# 14:  |F(x)| = 8.41649; step 1
# 15:  |F(x)| = 3.40051; step 1
# 16:  |F(x)| = 2.25929; step 1
# 17:  |F(x)| = 1.92019; step 1
# 18:  |F(x)| = 1.07147; step 1
# 19:  |F(x)| = 0.269113; step 1
# 20:  |F(x)| = 0.238908; step 0.262122
# 21:  |F(x)| = 0.55569; step 1
# 22:  |F(x)| = 0.567682; step 0.240202
# 23:  |F(x)| = 0.540172; step 1
# 24:  |F(x)| = 0.285667; step 1
# 25:  |F(x)| = 0.103139; step 1
# 26:  |F(x)| = 0.0698926; step 1
# 27:  |F(x)| = 0.0619144; step 1
# 28:  |F(x)| = 0.0485152; step 1
# 29:  |F(x)| = 0.0102518; step 1
# 30:  |F(x)| = 0.00852757; step 0.455518
# 31:  |F(x)| = 0.00823094; step 0.493043
# 32:  |F(x)| = 0.0102213; step 1
# 33:  |F(x)| = 0.00813467; step 1
# 34:  |F(x)| = 0.00258741; step 1
# 35:  |F(x)| = 0.00170502; step 1
# 36:  |F(x)| = 0.00345882; step 1
# 37:  |F(x)| = 0.00303512; step 1
# 38:  |F(x)| = 0.00179232; step 1
# 39:  |F(x)| = 0.000698649; step 1
# 40:  |F(x)| = 0.000492823; step 1
# 41:  |F(x)| = 0.000325808; step 1
# 42:  |F(x)| = 0.000147364; step 1
# 43:  |F(x)| = 3.78945e-05; step 1
# 44:  |F(x)| = 0.000104278; step 1
# 45:  |F(x)| = 0.000104224; step 1
# 46:  |F(x)| = 6.79105e-05; step 1
# 47:  |F(x)| = 2.13725e-05; step 1
# 48:  |F(x)| = 1.42552e-05; step 1
# 49:  |F(x)| = 1.2551e-05; step 0.406334
# 50:  |F(x)| = 1.28278e-05; step 0.458791
# 51:  |F(x)| = 1.34761e-05; step 1
# 52:  |F(x)| = 8.17343e-06; step 1
# 53:  |F(x)| = 3.59947e-06; step 1
# scipy solver converged in 55 iterations.
# #################################### N = 31 ####################################
# ERROR	NN-HF			NN-RO			RO-HF
# min	9.783185967273828e-05	9.84973521204062e-05	2.1025852976751504e-06
# mean	0.16399720797522266	0.16401696559371554	4.332135742813414e-05
# max	2.377925351433393	2.3782499492715954	0.0004552271487244608

# %% [markdown]
# #### 4.6.2 PRNN Error Analysis

# %%
prnn_net.load_best_weights()
_ = ErrorAnalysis.error_analysis_fixed_net(
    prnn_net, test_mu, input_normalization_prnn, output_normalization_prnn
)
# Out:
# #################################### N = 31 ####################################
# ERROR	NN-HF			NN-RO			RO-HF
# min	0.02479488532320272	0.02479282100008037	2.1025852976751504e-06
# mean	0.5434481860998762	0.5434469461462712	4.332135742813414e-05
# max	1.0752578622761382	1.0752479607530125	0.0004552271487244608

# %% [markdown]
# #### 4.6.3 PINN Error Analysis

# %%
pinn_net.load_best_weights()
_ = ErrorAnalysis.error_analysis_fixed_net(
    pinn_net, test_mu, input_normalization_pinn, output_normalization_pinn
)
# Out:
# #################################### N = 31 ####################################
# ERROR	NN-HF			NN-RO			RO-HF
# min	0.02624680560322401	0.02624485624800747	2.1025852976751504e-06
# mean	0.5453848817320021	0.5453844466014897	4.332135742813414e-05
# max	1.0943620661921398	1.0943646696736173	0.0004552271487244608
